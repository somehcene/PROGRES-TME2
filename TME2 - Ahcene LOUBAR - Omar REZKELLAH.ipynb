# %% [markdown]
# # PROGRES - TME2
#
# Fabien Mathieu - fabien.mathieu@normalesup.org
#
# Sébastien Tixeuil - Sebastien.Tixeuil@lip6.fr

# %% [markdown]
# **Binôme : Ahcene LOUBAR, Omar REZKELLAH**

# %% [markdown]
# **Note**:
# - Star exercises (indicated by *) should only be done if all other exercises have been completed. You
# don't have to do them if you do not want.

# %% [markdown]
# # Rules

# %% [markdown]
# 1. Cite your sources
# 2. One file to rule them all
# 3. Explain
# 4. Execute your code
#
#
# https://github.com/balouf/progres/blob/main/rules.ipynb

# %% [markdown]
# # Exercice 1 - Regular Expressions

# %% [markdown]
# Consider the following list:

# %%
L = ['marie.Dupond@gmail.com', 'lucie.Durand@wanadoo.fr', 
'Sophie.Parmentier @@ gmail.com', 'franck.Dupres.gmail.com', 
'pierre.Martin@lip6 .fr ',' eric.Deschamps@gmail.com ']

# %% [markdown]
# - Which of these entries are valid?
# - Use regular expressions to identify valid *gmail* addresses and display them.

# %% [markdown]
# Answer

# %% [markdown]
# The valid entries are ```marie.Dupond@gmail.com```, ```eric.Deschamps@gmail.com``` as they were the only ones that the function true_gmail returned. The function takes a list of strings representing supossedly email adresses, but not all of them are valid, so to make sure we identify the valid ones we'll use the library re (RegEx) to try and match a pattern to each one of them and see which ones are valid.
#
# 1. The function takes a mail_list: a list containing strings that supposedly represent e-mail adresses
# 2. makes sure that all strings in the list are striped from spaces at the start and at the end.
# 3. Defines a pattern:
# * ```[a-zA-Z0-9._%+-]+``` : represents the local part of an e-mail address and it can contain all the uppercase and lowercase letters of the alphabet + digits from 0 to 9 and some special characters.
# * ```@gmail``` : represents an @ followed by gmail simply.
# * ```\.[a-zA-Z]{2,}``` : represents a dot followed by a minimum of two elements that can be all the uppercase and lowercase letters of the alphabet.
# 4. Uses the fullmatch function of the re module to check if each email string present on the emails list matches the pattern.
# 5. Returns the list of valid emails.

# %%
import re 
def true_gmail(mail_list):
    mail_list = [mail.strip() for mail in mail_list]
    pattern_email = r'[a-zA-Z0-9._%+-]+@gmail\.[a-zA-Z]{2,}'
    valid_emails = [email for email in mail_list if re.fullmatch(pattern_email, email)]
    return valid_emails

# %%
true_gmail(L)
# Out:
# ['marie.Dupond@gmail.com', 'eric.Deschamps@gmail.com']

# %% [markdown]
# I heard someone talk about the issue below before, so i guess i have to find a way

# %%
true_gmail([".@gmail.com"])
# Out:
# ['.@gmail.com']

# %% [markdown]
# A solution to this would be to put the ```pattern = r'[a-zA-Z0-9_%+-][a-zA-Z0-9._%+-]+[a-zA-Z0-9_%+-]@gmail\.[a-zA-Z]{2,}'```  would ensure that email strings don't start or end with a dot even tho this is still a bit clumsy i guess.
# I got this information from a fellow student.

# %%
print(re.fullmatch(r'[a-zA-Z0-9_%+-][a-zA-Z0-9._%+-]+[a-zA-Z0-9_%+-]@gmail\.[a-zA-Z]{2,}', ".@gmail.com"))
# Out:
# None

# %% [markdown]
# - Use regular expressions to check if a string ends with a number.

# %% [markdown]
# We want to detect if a string ends with a number so we'll just directly use re.search() and a pattern that matches at least one digit at the end of the string:
# * ```\d+``` : at least one digit
# * ```$``` : at the end of the string

# %%
def ends_with_number(txt):
    return bool(re.search(r'\d+$', txt))

# %%
ends_with_number('to42to')
# Out:
# False

# %%
ends_with_number('to42to666')
# Out:
# True

# %% [markdown]
# - Use regular expressions to remove problematic zeros from an IPv4 address expressed as a
# string. (example: "216.08.094.196" should become "216.8.94.196", but "216.80.140.196"
# should remain "216.80.140.196").

# %% [markdown]
# The point of the normalize_ip() function is to remove leading zeros from complete octets (digits that are delimited by dots) and for that we have to, at first, make a pattern that only cares about complete octets (or words of digits) and for that we can use the special sequence "\b", because it only matches a word that starts with a word character and is delimited at the end by a non-word character such as a dot!
#
# we are interested only in the octets that start with one or two zeros, and then make sure we replace the whole octet with what comes after the zero(s):
#
# * ```\b0+(\d)``` : this unsures we match octets that start with at least one zero followed by a group of digits delimited by a dot.
# * ```r'\1'```: refers to the first capture group from the pattern (\d) the actual digit after the leading zero.
# * ```re.sub()``` : we use this function to replace octets that starts with zeros by the digits that come right after the zeros.

# %% [markdown]
# I used this link https://ttl255.com/regex-and-unix-tools-for-networking-basics/
#
# I also asked gemini about the "\b" special sequence, the response was : "\b est un délimiteur de mot (appelé "word boundary" en anglais). Il ne correspond à aucun caractère particulier, mais marque une position entre : Un caractère "de mot" (comme une lettre, un chiffre ou un underscore _) et un caractère "non-mot" (comme un espace, un point, une virgule, etc.)."

# %%
def normalize_ip(txt):
    return re.sub(r'\b0+(\d)', r'\1', txt)

# %%
normalize_ip("216.0.094.196")
# Out:
# '216.0.94.196'

# %%
normalize_ip("216.08.094.196")
# Out:
# '216.8.94.196'

# %%
normalize_ip("216.80.140.196")
# Out:
# '216.80.140.196'

# %% [markdown]
# - Use regular expressions to transform a date from MM-DD-YYYY format to DD-MM-YYYY
# format. (example "11-06-2020" should become "06-11-2020"). Optionally*, do the same thing using the `datetime` package.

# %% [markdown]
# All we had to do is caplture three groups for day, month and year and then rearrange them by 2nd group with the first one and vice versa.
# * ```(\d{2})-(\d{2})-(\d{4})``` : captures a structure that has the MM-DD-YYYY shape
# * ```re.sub()``` : used to replace (or rearrange in our case)
# * ```r'\2-\1-\3'``` : rearranging the order of the first two groups (replacing the first with the second and the second with the first)

# %%
def switch_md(txt):
    pattern = r'(\d{2})-(\d{2})-(\d{4})'
    return re.sub(pattern, r'\2-\1-\3', txt)

# %%
switch_md("11-06-2020")
# Out:
# '06-11-2020'

# %% [markdown]
# # Exercice 2 - Analyze XML

# %% [markdown]
# - Write a Python code that retrieves the content of the page at:

# %%
import xml.etree.ElementTree as ET
import requests
url = "https://www.w3schools.com/xml/cd_catalog.xml"

# %% [markdown]
# We're doing web scraping for the next few exercices so we are gonna use the requests library a whole bunch, it allows us to acces web data in different formats (XML, HTML... etc)
# I'm not gonna be explaining why i used certain libraries since i refered to Mr Fabien Mattieu's lecture to resolve these exercices.

# %%
response = requests.get(url)
xml_content = response.content
xml_content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<CATALOG>\n  <CD>\n    <TITLE>Empire Burlesque</TITLE>\n    <ARTIST>Bob Dylan</ARTIST>\n    <COUNTRY>USA</COUNTRY>\n    <COMPANY>Columbia</COMPANY>\n    <PRICE>10.90</PRICE>\n    <YEAR>1985</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Hide your heart</TITLE>\n    <ARTIST>Bonnie Tyler</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>CBS Records</COMPANY>\n    <PRICE>9.90</PRICE>\n    <YEAR>1988</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Greatest Hits</TITLE>\n    <ARTIST>Dolly Parton</ARTIST>\n    <COUNTRY>USA</COUNTRY>\n    <COMPANY>RCA</COMPANY>\n    <PRICE>9.90</PRICE>\n    <YEAR>1982</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Still got the blues</TITLE>\n    <ARTIST>Gary Moore</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Virgin records</COMPANY>\n    <PRICE>10.20</PRICE>\n    <YEAR>1990</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Eros</TITLE>\n    <ARTIST>Eros Ramazzotti</ARTIST>\n    <COUNTRY>EU</COUNTRY>\n    <COMPANY>BMG</COMPANY>\n    <PRICE>9.90</PRICE>\n    <YEAR>1997</YEAR>\n  </CD>\n  <CD>\n    <TITLE>One night only</TITLE>\n    <ARTIST>Bee Gees</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Polydor</COMPANY>\n    <PRICE>10.90</PRICE>\n    <YEAR>1998</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Sylvias Mother</TITLE>\n    <ARTIST>Dr.Hook</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>CBS</COMPANY>\n    <PRICE>8.10</PRICE>\n    <YEAR>1973</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Maggie May</TITLE>\n    <ARTIST>Rod Stewart</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Pickwick</COMPANY>\n    <PRICE>8.50</PRICE>\n    <YEAR>1990</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Romanza</TITLE>\n    <ARTIST>Andrea Bocelli</ARTIST>\n    <COUNTRY>EU</COUNTRY>\n    <COMPANY>Polydor</COMPANY>\n    <PRICE>10.80</PRICE>\n    <YEAR>1996</YEAR>\n  </CD>\n  <CD>\n    <TITLE>When a man loves a woman</TITLE>\n    <ARTIST>Percy Sledge</ARTIST>\n    <COUNTRY>USA</COUNTRY>\n    <COMPANY>Atlantic</COMPANY>\n    <PRICE>8.70</PRICE>\n    <YEAR>1987</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Black angel</TITLE>\n    <ARTIST>Savage Rose</ARTIST>\n    <COUNTRY>EU</COUNTRY>\n    <COMPANY>Mega</COMPANY>\n    <PRICE>10.90</PRICE>\n    <YEAR>1995</YEAR>\n  </CD>\n  <CD>\n    <TITLE>1999 Grammy Nominees</TITLE>\n    <ARTIST>Many</ARTIST>\n    <COUNTRY>USA</COUNTRY>\n    <COMPANY>Grammy</COMPANY>\n    <PRICE>10.20</PRICE>\n    <YEAR>1999</YEAR>\n  </CD>\n  <CD>\n    <TITLE>For the good times</TITLE>\n    <ARTIST>Kenny Rogers</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Mucik Master</COMPANY>\n    <PRICE>8.70</PRICE>\n    <YEAR>1995</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Big Willie style</TITLE>\n    <ARTIST>Will Smith</ARTIST>\n    <COUNTRY>USA</COUNTRY>\n    <COMPANY>Columbia</COMPANY>\n    <PRICE>9.90</PRICE>\n    <YEAR>1997</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Tupelo Honey</TITLE>\n    <ARTIST>Van Morrison</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Polydor</COMPANY>\n    <PRICE>8.20</PRICE>\n    <YEAR>1971</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Soulsville</TITLE>\n    <ARTIST>Jorn Hoel</ARTIST>\n    <COUNTRY>Norway</COUNTRY>\n    <COMPANY>WEA</COMPANY>\n    <PRICE>7.90</PRICE>\n    <YEAR>1996</YEAR>\n  </CD>\n  <CD>\n    <TITLE>The very best of</TITLE>\n    <ARTIST>Cat Stevens</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Island</COMPANY>\n    <PRICE>8.90</PRICE>\n    <YEAR>1990</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Stop</TITLE>\n    <ARTIST>Sam Brown</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>A and M</COMPANY>\n    <PRICE>8.90</PRICE>\n    <YEAR>1988</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Bridge of Spies</TITLE>\n    <ARTIST>T\'Pau</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Siren</COMPANY>\n    <PRICE>7.90</PRICE>\n    <YEAR>1987</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Private Dancer</TITLE>\n    <ARTIST>Tina Turner</ARTIST>\n    <COUNTRY>UK</COUNTRY>\n    <COMPANY>Capitol</COMPANY>\n    <PRICE>8.90</PRICE>\n    <YEAR>1983</YEAR>\n  </CD>\n  <CD>\n    <TITLE>Midt om natten</TITLE>\n    <ARTIST>Kim Larsen</ARTIST>\n    <COUNTRY>EU</COUNT ...

# %%
root = ET.fromstring(xml_content)
root
# Out:
# <Element 'CATALOG' at 0x0000026930E6DBC0>

# %% [markdown]
# - Look at the text content and load as xml.

# %% [markdown]
# The XML data is represented by a root element CATALOG that contains all the CDs (elements) in the collection.
# Each CD is represented by a <CD> tag and inside each <CD> element, there are several sub-elements describing various information about the CD such as the <TITLE> or <ARTIST> and a few more.

# %% [markdown]
# - Write a `display_cd` function that displays (i.e. `print`), for a CD: title, artist, country, company, year.
# - Display all CDs.

# %% [markdown]
# we'll first define a function ```display_cd(entry)``` that takes an xml CD element  and displays it's sub elements and their contents
#
# ```ET.fromstring(xml_content)``` converts the XML string into an element tree.
# ```root.findall('CD')``` gets a list of all CD elements.
# ```The display_cd(cd)``` function is then called for each CD element, extracting and printing its details.

# %%
def display_cd(entry):
    title = entry.find('TITLE').text
    artist = entry.find('ARTIST').text
    country = entry.find('COUNTRY').text
    company = entry.find('COMPANY').text
    year = entry.find('YEAR').text
    
    print(f"Title: {title}")
    print(f"Artist: {artist}")
    print(f"Country: {country}")
    print(f"Company: {company}")
    print(f"Year: {year}")
    print("-" * 40)

# %%
for child in root:
    display_cd(child)
# Out:
# Title: Empire Burlesque
# Artist: Bob Dylan
# Country: USA
# Company: Columbia
# Year: 1985
# ----------------------------------------
# Title: Hide your heart
# Artist: Bonnie Tyler
# Country: UK
# Company: CBS Records
# Year: 1988
# ----------------------------------------
# Title: Greatest Hits
# Artist: Dolly Parton
# Country: USA
# Company: RCA
# Year: 1982
# ----------------------------------------
# Title: Still got the blues
# Artist: Gary Moore
# Country: UK
# Company: Virgin records
# Year: 1990
# ----------------------------------------
# Title: Eros
# Artist: Eros Ramazzotti
# Country: EU
# Company: BMG
# Year: 1997
# ----------------------------------------
# Title: One night only
# Artist: Bee Gees
# Country: UK
# Company: Polydor
# Year: 1998
# ----------------------------------------
# Title: Sylvias Mother
# Artist: Dr.Hook
# Country: UK
# Company: CBS
# Year: 1973
# ----------------------------------------
# Title: Maggie May
# Artist: Rod Stewart
# Country: UK
# Company: Pickwick
# Year: 1990
# ----------------------------------------
# Title: Romanza
# Artist: Andrea Bocelli
# Country: EU
# Company: Polydor
# Year: 1996
# ----------------------------------------
# Title: When a man loves a woman
# Artist: Percy Sledge
# Country: USA
# Company: Atlantic
# Year: 1987
# ----------------------------------------
# Title: Black angel
# Artist: Savage Rose
# Country: EU
# Company: Mega
# Year: 1995
# ----------------------------------------
# Title: 1999 Grammy Nominees
# Artist: Many
# Country: USA
# Company: Grammy
# Year: 1999
# ----------------------------------------
# Title: For the good times
# Artist: Kenny Rogers
# Country: UK
# Company: Mucik Master
# Year: 1995
# ----------------------------------------
# Title: Big Willie style
# Artist: Will Smith
# Country: USA
# Company: Columbia
# Year: 1997
# ----------------------------------------
# Title: Tupelo Honey
# Artist: Van Morrison
# Country: UK
# Company: Polydor
# Year: 1971
# ----------------------------------------
# Title: Soulsville
# Artist: Jorn Hoel
# Country: Norway
# Company: WEA
# Year: 1996
# ----------------------------------------
# Title: The very best of
# Artist: Cat Stevens
# Country: UK
# Company: Island
# Year: 1990
# ----------------------------------------
# Title: Stop
# Artist: Sam Brown
# Country: UK
# Company: A and M
# Year: 1988
# ----------------------------------------
# Title: Bridge of Spies
# Artist: T'Pau
# Country: UK
# Company: Siren
# Year: 1987
# ----------------------------------------
# Title: Private Dancer
# Artist: Tina Turner
# Country: UK
# Company: Capitol
# Year: 1983
# ----------------------------------------
# Title: Midt om natten
# Artist: Kim Larsen
# Country: EU
# Company: Medley
# Year: 1983
# ----------------------------------------
# Title: Pavarotti Gala Concert
# Artist: Luciano Pavarotti
# Country: UK
# Company: DECCA
# Year: 1991
# ----------------------------------------
# Title: The dock of the bay
# Artist: Otis Redding
# Country: USA
# Company: Stax Records
# Year: 1968
# ----------------------------------------
# Title: Picture book
# Artist: Simply Red
# Country: EU
# Company: Elektra
# Year: 1985
# ----------------------------------------
# Title: Red
# Artist: The Communards
# Country: UK
# Company: London
# Year: 1987
# ----------------------------------------
# Title: Unchain my heart
# Artist: Joe Cocker
# Country: USA
# Company: EMI
# Year: 1987
# ----------------------------------------

# %% [markdown]
# - Display all 1980s CDs.

# %% [markdown]
# For this function we should think about accessing all CDs through a for loop and use the previous function to display only the cds that were released on the 80s (between 1980 and 1990)
# i made sure i converted the ```find('YEAR')``` to an integer to use for inequalities, befause the find and find all methods return strings.

# %%
def display_80s_cds(root):
    for cd in root.findall('CD'):
        year = int(cd.find('YEAR').text)
        if 1980 <= year <= 1989:
            display_cd(cd)

display_80s_cds(root)
# Out:
# Title: Empire Burlesque
# Artist: Bob Dylan
# Country: USA
# Company: Columbia
# Year: 1985
# ----------------------------------------
# Title: Hide your heart
# Artist: Bonnie Tyler
# Country: UK
# Company: CBS Records
# Year: 1988
# ----------------------------------------
# Title: Greatest Hits
# Artist: Dolly Parton
# Country: USA
# Company: RCA
# Year: 1982
# ----------------------------------------
# Title: When a man loves a woman
# Artist: Percy Sledge
# Country: USA
# Company: Atlantic
# Year: 1987
# ----------------------------------------
# Title: Stop
# Artist: Sam Brown
# Country: UK
# Company: A and M
# Year: 1988
# ----------------------------------------
# Title: Bridge of Spies
# Artist: T'Pau
# Country: UK
# Company: Siren
# Year: 1987
# ----------------------------------------
# Title: Private Dancer
# Artist: Tina Turner
# Country: UK
# Company: Capitol
# Year: 1983
# ----------------------------------------
# Title: Midt om natten
# Artist: Kim Larsen
# Country: EU
# Company: Medley
# Year: 1983
# ----------------------------------------
# Title: Picture book
# Artist: Simply Red
# Country: EU
# Company: Elektra
# Year: 1985
# ----------------------------------------
# Title: Red
# Artist: The Communards
# Country: UK
# Company: London
# Year: 1987
# ----------------------------------------
# Title: Unchain my heart
# Artist: Joe Cocker
# Country: USA
# Company: EMI
# Year: 1987
# ----------------------------------------

# %% [markdown]
# - Display all British CDs.

# %% [markdown]
# This one is not so different from the previous one as we just have to access all CDs one by one through a for loop and check at each iteration is the country is "UK" and display it if it is the case.

# %%
def display_brittish_cds(root):
    for cd in root.findall('CD'):
        country = cd.find('COUNTRY').text
        if country == 'UK' :
            display_cd(cd)

display_brittish_cds(root)
# Out:
# Title: Hide your heart
# Artist: Bonnie Tyler
# Country: UK
# Company: CBS Records
# Year: 1988
# ----------------------------------------
# Title: Still got the blues
# Artist: Gary Moore
# Country: UK
# Company: Virgin records
# Year: 1990
# ----------------------------------------
# Title: One night only
# Artist: Bee Gees
# Country: UK
# Company: Polydor
# Year: 1998
# ----------------------------------------
# Title: Sylvias Mother
# Artist: Dr.Hook
# Country: UK
# Company: CBS
# Year: 1973
# ----------------------------------------
# Title: Maggie May
# Artist: Rod Stewart
# Country: UK
# Company: Pickwick
# Year: 1990
# ----------------------------------------
# Title: For the good times
# Artist: Kenny Rogers
# Country: UK
# Company: Mucik Master
# Year: 1995
# ----------------------------------------
# Title: Tupelo Honey
# Artist: Van Morrison
# Country: UK
# Company: Polydor
# Year: 1971
# ----------------------------------------
# Title: The very best of
# Artist: Cat Stevens
# Country: UK
# Company: Island
# Year: 1990
# ----------------------------------------
# Title: Stop
# Artist: Sam Brown
# Country: UK
# Company: A and M
# Year: 1988
# ----------------------------------------
# Title: Bridge of Spies
# Artist: T'Pau
# Country: UK
# Company: Siren
# Year: 1987
# ----------------------------------------
# Title: Private Dancer
# Artist: Tina Turner
# Country: UK
# Company: Capitol
# Year: 1983
# ----------------------------------------
# Title: Pavarotti Gala Concert
# Artist: Luciano Pavarotti
# Country: UK
# Company: DECCA
# Year: 1991
# ----------------------------------------
# Title: Red
# Artist: The Communards
# Country: UK
# Company: London
# Year: 1987
# ----------------------------------------

# %% [markdown]
# # Exercice 3 - Analyze JSON

# %% [markdown]
# - Write a Python program that gets the file of filming locations in Paris at:

# %%
url = "https://opendata.paris.fr/explore/dataset/lieux-de-tournage-a-paris/download/?format=json&timezone=Europe/Berlin&lang=fr"

# %% [markdown]
# - How many entries have you got?

# %% [markdown]
# https://pynative.com/python-json-load-and-loads-to-parse-json/ i looked at this page to know more about json parsing and serialisation and came to know about json.loads() etc
#
# we've got 12265 entries in our json file, which means we have informations about 12265 filming location in paris

# %%
import json
response = requests.get(url)
locs = json.loads(response.text)
print("total number of entries is :", len(locs))
locs
# Out:
# total number of entries is : 12265
# [{'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '0ff321c5b140a12a8e50a1b212a7c5f5bced91d7',
#   'fields': {'coord_x': 2.37006242,
#    'id_lieu': '2017-751',
#    'adresse_lieu': 'rue du faubourg du temple, 75011 paris',
#    'geo_shape': {'coordinates': [2.370062415669748, 48.8696979988026],
#     'type': 'Point'},
#    'coord_y': 48.869698,
#    'ardt_lieu': '75011',
#    'nom_tournage': '2 Fils (Nouvelle Demande Décor Librairie / Journées interverties)',
#    'nom_realisateur': 'Félix MOATI',
#    'date_debut': '2017-10-19',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'NORD OUEST FILMS',
#    'date_fin': '2017-10-19',
#    'geo_point_2d': [48.8696979988026, 2.370062415669748]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.370062415669748, 48.8696979988026]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a81ecdaf39edd9535d1ccd61d7f32b3c4971e8f1',
#   'fields': {'coord_x': 2.34248745,
#    'id_lieu': '2018-548',
#    'adresse_lieu': 'pont neuf, 75001 paris',
#    'geo_shape': {'coordinates': [2.342487451056846, 48.85849330754624],
#     'type': 'Point'},
#    'coord_y': 48.85849331,
#    'ardt_lieu': '75001',
#    'nom_tournage': 'Vernon Subutex',
#    'nom_realisateur': 'Cathy Verney',
#    'date_debut': '2018-04-25',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2018',
#    'nom_producteur': 'TETRA MEDIA FICTION',
#    'date_fin': '2018-04-26',
#    'geo_point_2d': [48.85849330754624, 2.342487451056846]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.342487451056846, 48.85849330754624]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '94701832da8bebe77df1128bfab30ef3f5064dc4',
#   'fields': {'coord_x': 2.36463505,
#    'id_lieu': '2017-1178',
#    'adresse_lieu': 'quai de jemmapes, 75010 paris',
#    'geo_shape': {'coordinates': [2.3646350537874703, 48.87597363622085],
#     'type': 'Point'},
#    'coord_y': 48.87597364,
#    'ardt_lieu': '75010',
#    'nom_tournage': 'LEBOWITZ CONTRE LEBOWITZ 2',
#    'nom_realisateur': 'Olivier Barma',
#    'date_debut': '2017-06-01',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CHABRAQUE PRODUCTIONS',
#    'date_fin': '2017-06-01',
#    'geo_point_2d': [48.87597363622085, 2.3646350537874703]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3646350537874703, 48.87597363622085]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '1c1813685728a27d5b9131693d6d42f3922cc10d',
#   'fields': {'coord_x': 2.39860034,
#    'id_lieu': '2017-1493',
#    'adresse_lieu': '46 boulevard de charonne, 75020 paris',
#    'geo_shape': {'coordinates': [2.3986003434290892, 48.85154733669693],
#     'type': 'Point'},
#    'coord_y': 48.85154734,
#    'ardt_lieu': '75020',
#    'nom_tournage': 'À jamais fidèle',
#    'nom_realisateur': 'cheyenne carron',
#    'date_debut': '2017-08-24',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Hesiode Productions',
#    'date_fin': '2017-08-25',
#    'geo_point_2d': [48.85154733669693, 2.3986003434290892]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3986003434290892, 48.85154733669693]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'd717a79b214bfa174781bde3b96c7c3fd885ed05',
#   'fields': {'coord_x': 2.38127943,
#    'id_lieu': '2017-327',
#    'adresse_lieu': '8 rue nicole reine-lepaute, 75013 paris',
#    'geo_shape': {'coordinates': [2.3812794291774626, 48.82655664927356],
#     'type': 'Point'},
#    'coord_y': 48.82655665,
#    'ardt_lieu': '75013',
#    'nom_tournage': 'CHRONIQUES PARISIENNES 16',
#    'nom_realisateur': 'ZABOU BREITMAN',
#    'date_debut': '2017-04-18',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'LES FILMS DU KIOSQUE',
#    'date_fin': '2017-04-18',
#    'geo_point_2d': [48.82655664927356, 2.3812794291774626]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3812794291774626, 48.82655664927356]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '3786bf1a44e6242a454f61257d68715af1c1bf73',
#   'fields': {'coord_x': 2.39778751,
#    'id_lieu': '2017-268',
#    'adresse_lieu': '37 route des petits ponts, 75019 paris',
#    'geo_shape': {'coordinates': [2.3977875069644603, 48.893005176977596],
#     'type': 'Point'},
#    'coord_y': 48.89300518,
#    'ardt_lieu': '75019',
#    'nom_tournage': 'LOLYWOOD - DANS TES REVES LE SPORT',
#    'nom_realisateur': 'Matthieu MARES-SAVELLI',
#    'date_debut': '2017-04-13',
#    'type_tournage': 'Série Web',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CAMARILLA PRODUCTION',
#    'date_fin': '2017-04-13',
#    'geo_point_2d': [48.893005176977596, 2.3977875069644603]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3977875069644603, 48.893005176977596]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '6ecf0a7eec3fc48c9a9633d589d0837a1cb1d113',
#   'fields': {'coord_x': 2.36913602,
#    'id_lieu': '2017-1190',
#    'adresse_lieu': 'pont charles de gaulle, 75012 paris',
#    'geo_shape': {'coordinates': [2.3691360159868426, 48.84258570428103],
#     'type': 'Point'},
#    'coord_y': 48.84258571,
#    'ardt_lieu': '75012',
#    'nom_tournage': 'Un homme pressé',
#    'nom_realisateur': 'Hervé Mimran',
#    'date_debut': '2017-05-23',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Albertine Productions',
#    'date_fin': '2017-05-24',
#    'geo_point_2d': [48.84258570428103, 2.3691360159868426]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3691360159868426, 48.84258570428103]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '78cb8396997a18b8df92eb8ee21fa38f106aba15',
#   'fields': {'coord_x': 2.33709787,
#    'id_lieu': '2017-1200',
#    'adresse_lieu': '26 boulevard de clichy, 75018 paris',
#    'geo_shape': {'coordinates': [2.337097873322637, 48.882670376784226],
#     'type': 'Point'},
#    'coord_y': 48.88267038,
#    'ardt_lieu': '75018',
#    'nom_tournage': "L'AMOUR EST UNE FÊTE",
#    'nom_realisateur': 'Cédric ANGER',
#    'date_debut': '2017-06-14',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'SUNRISE FILMS',
#    'date_fin': '2017-06-14',
#    'geo_point_2d': [48.882670376784226, 2.337097873322637]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.337097873322637, 48.882670376784226]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'f616294d4b361cd181c7283a1eb3306596da5541',
#   'fields': {'coord_x': 2.36442236,
#    'id_lieu': '2017-1215',
#    'adresse_lieu': 'quai de valmy, 75010 paris',
#    'geo_shape': {'coordinates': [2.3644223583154886, 48.876569098357535],
#     'type': 'Point'},
#    'coord_y': 48.8765691,
#    'ardt_lieu': '75010',
#    'nom_tournage': 'LEBOWITZ CONTRE LEBOWITZ 2',
#    'date_debut': '2017-05-31',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CHABRAQUE PRODUCTIONS',
#    'date_fin': '2017-05-31',
#    'geo_point_2d': [48.876569098357535, 2.3644223583154886]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3644223583154886, 48.876569098357535]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '52d24cfaae43a6030f0a321df1716c37635dd6a8',
#   'fields': {'coord_x': 2.34608771,
#    'id_lieu': '2018-629',
#    'adresse_lieu': '72 rue de dunkerque, 75009 paris',
#    'geo_shape': {'coordinates': [2.346087705583743, 48.88227218218318],
#     'type': 'Point'},
#    'coord_y': 48.88227218,
#    'ardt_lieu': '75009',
#    'nom_tournage': "Can't Buy me love",
#    'nom_realisateur': 'Renaud Bertrand - Noémie Saglio',
#    'date_debut': '2018-05-15',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2018',
#    'nom_producteur': 'Unrated Studio',
#    'date_fin': '2018-05-15',
#    'geo_point_2d': [48.88227218218318, 2.346087705583743]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.346087705583743, 48.88227218218318]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '43990ca030b98ce5d114ed9e0fb9f5c8c1091f35',
#   'fields': {'coord_x': 2.35378396,
#    'id_lieu': '2018-656',
#    'adresse_lieu': '46 rue du faubourg saint-denis, 75010 paris',
#    'geo_shape': {'coordinates': [2.353783961250403, 48.871601161330965],
#     'type': 'Point'},
#    'coord_y': 48.87160116,
#    'ardt_lieu': '75010',
#    'nom_tournage': 'LE GENDRE IDEAL',
#    'nom_realisateur': 'Hector CABELL REYES',
#    'date_debut': '2018-05-21',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2018',
#    'nom_producteur': 'KABO FILMS',
#    'date_fin': '2018-05-21',
#    'geo_point_2d': [48.871601161330965, 2.353783961250403]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.353783961250403, 48.871601161330965]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '8f3b7b110d3bc2de91f1e17721fc4514ca2b9f9b',
#   'fields': {'coord_x': 2.32648299,
#    'id_lieu': '2017-1533',
#    'adresse_lieu': 'rue tronchet, 75008 paris',
#    'geo_shape': {'coordinates': [2.326482985997865, 48.87278421793338],
#     'type': 'Point'},
#    'coord_y': 48.87278422,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'Les Affamés',
#    'nom_realisateur': 'Léa Frédeval',
#    'date_debut': '2017-07-16',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'LES FILMS DU CLAN',
#    'date_fin': '2017-07-16',
#    'geo_point_2d': [48.87278421793338, 2.326482985997865]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.326482985997865, 48.87278421793338]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'e12817d74896843357554b8d123f4eb8dd11fe3a',
#   'fields': {'coord_x': 2.36564419,
#    'id_lieu': '2017-1536',
#    'adresse_lieu': '142 quai de jemmapes, 75010 paris',
#    'geo_shape': {'coordinates': [2.3656441866110183, 48.876739410796205],
#     'type': 'Point'},
#    'coord_y': 48.87673941,
#    'ardt_lieu': '75010',
#    'nom_tournage': 'LES BEAUX ESPRITS',
#    'nom_realisateur': 'VIANNEY LEBASQUE',
#    'date_debut': '2017-07-21',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'MES PRODUCTIONS',
#    'date_fin': '2017-07-22',
#    'geo_point_2d': [48.876739410796205, 2.3656441866110183]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3656441866110183, 48.876739410796205]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '48379844f5af21fca115fd12c651d5725b575304',
#   'fields': {'coord_x': 2.39242343,
#    'id_lieu': '2017-1538',
#    'adresse_lieu': '14t rue frédérick lemaître, 75020 paris',
#    'geo_shape': {'coordinates': [2.3924234275751726, 48.8741144391816],
#     'type': 'Point'},
#    'coord_y': 48.87411444,
#    'ardt_lieu': '75020',
#    'nom_tournage': 'nOX',
#    'nom_realisateur': 'mabrouk el Mechri',
#    'date_debut': '2017-07-18',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Gaumont Télévision c/o Gaumont Production Télévision',
#    'date_fin': '2017-07-18',
#    'geo_point_2d': [48.8741144391816, 2.3924234275751726]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3924234275751726, 48.8741144391816]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'cea9bb5b757dea4c1dda8b6ec89c48f2cad7a5f0',
#   'fields': {'coord_x': 2.3022059,
#    'id_lieu': '2017-1540',
#    'adresse_lieu': 'cours albert ier, 75008 paris',
#    'geo_shape': {'coordinates': [2.3022058997720047, 48.864406963921084],
#     'type': 'Point'},
#    'coord_y': 48.86440696,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'UNDER THE EIFFEL TOWER',
#    'nom_realisateur': 'ARCHIE BORDERS',
#    'date_debut': '2017-07-18',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'KANZAMAN FRANCE',
#    'date_fin': '2017-07-18',
#    'geo_point_2d': [48.864406963921084, 2.3022058997720047]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3022058997720047, 48.864406963921084]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '5c198d62ee38d8940d120efe712cc486e0da468d',
#   'fields': {'coord_x': 2.33165128,
#    'id_lieu': '2017-1543',
#    'adresse_lieu': 'avenue du général lemonnier, 75001 paris',
#    'geo_shape': {'coordinates': [2.3316512810012355, 48.86314441257238],
#     'type': 'Point'},
#    'coord_y': 48.86314441,
#    'ardt_lieu': '75001',
#    'nom_tournage': 'Taxi 5',
#    'nom_realisateur': 'Franck Gastambide',
#    'date_debut': '2017-07-28',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'T 5 Productions',
#    'date_fin': '2017-07-28',
#    'geo_point_2d': [48.86314441257238, 2.3316512810012355]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3316512810012355, 48.86314441257238]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '49ff0fe251886a7bb1903f683642503dd68d556f',
#   'fields': {'coord_x': 2.35302854,
#    'id_lieu': '2017-288',
#    'adresse_lieu': 'rue martel, 75010 paris',
#    'geo_shape': {'coordinates': [2.353028536322006, 48.873991253103675],
#     'type': 'Point'},
#    'coord_y': 48.87399125,
#    'ardt_lieu': '75010',
#    'nom_tournage': 'CHRONIQUES PARISIENNES',
#    'nom_realisateur': 'ZABOU BREITMAN',
#    'date_debut': '2017-04-07',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'LES FILMS DU KIOSQUE',
#    'date_fin': '2017-04-07',
#    'geo_point_2d': [48.873991253103675, 2.353028536322006]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.353028536322006, 48.873991253103675]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'c5187417c14075aee7389f6fce7fcce828103d15',
#   'fields': {'coord_x': 2.34326304,
#    'id_lieu': '2017-140',
#    'adresse_lieu': 'quai des orfèvres, 75001 paris',
#    'geo_shape': {'coordinates': [2.3432630419377345, 48.85510452788805],
#     'type': 'Point'},
#    'coord_y': 48.85510453,
#    'ardt_lieu': '75001',
#    'nom_tournage': 'BIG BANG',
#    'nom_realisateur': 'Cécilia Rouaud',
#    'date_debut': '2017-03-29',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'FIRELIGHT Big Bang',
#    'date_fin': '2017-03-29',
#    'geo_point_2d': [48.85510452788805, 2.3432630419377345]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3432630419377345, 48.85510452788805]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'f64e6b8c324a3cd785b07ade485b125cf43afa3e',
#   'fields': {'coord_x': 2.3281098,
#    'id_lieu': '2017-1055',
#    'adresse_lieu': '25 rue du bac, 75007 paris',
#    'geo_shape': {'coordinates': [2.328109801855801, 48.85778012113944],
#     'type': 'Point'},
#    'coord_y': 48.85778012,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'THANKSGIVING',
#    'nom_realisateur': 'NICOLAS SAADA',
#    'date_debut': '2017-11-21',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CAPA DRAMA',
#    'date_fin': '2017-11-21',
#    'geo_point_2d': [48.85778012113944, 2.328109801855801]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.328109801855801, 48.85778012113944]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'd8e77ea2886e57bf5d95d5a7c71a4d67b5eac0a6',
#   'fields': {'coord_x': 2.29750439,
#    'id_lieu': '2017-1061',
#    'adresse_lieu': 'rue de galliera, 75116 paris',
#    'geo_shape': {'coordinates': [2.297504389310135, 48.865760689593685],
#     'type': 'Point'},
#    'coord_y': 48.86576069,
#    'ardt_lieu': '75116',
#    'nom_tournage': 'CURIOSA',
#    'date_debut': '2017-11-30',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CURIOSA FILMS',
#    'date_fin': '2017-11-30',
#    'geo_point_2d': [48.865760689593685, 2.297504389310135]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.297504389310135, 48.865760689593685]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '25c8586650055ac314abee9545465dfe7978e2d1',
#   'fields': {'coord_x': 2.32051039,
#    'id_lieu': '2017-1066',
#    'adresse_lieu': "15 rue d'edimbourg, 75008 paris",
#    'geo_shape': {'coordinates': [2.320510393574338, 48.87935282992029],
#     'type': 'Point'},
#    'coord_y': 48.87935283,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'Skam',
#    'nom_realisateur': 'David Hourrègue',
#    'date_debut': '2017-11-29',
#    'type_tournage': 'Série Web',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Gétévé Productions',
#    'date_fin': '2017-11-29',
#    'geo_point_2d': [48.87935282992029, 2.320510393574338]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.320510393574338, 48.87935282992029]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '86d055053b1ba6e6c59e2cbdc8e7ece9073b01f4',
#   'fields': {'coord_x': 2.28460587,
#    'id_lieu': '2018-683',
#    'adresse_lieu': 'place de costa rica, 75016 paris',
#    'geo_shape': {'coordinates': [2.2846058671570257, 48.85867153281226],
#     'type': 'Point'},
#    'coord_y': 48.85867153,
#    'ardt_lieu': '75016',
#    'nom_tournage': 'QUAND TU DANSES',
#    'nom_realisateur': 'Ladislas Chollat',
#    'date_debut': '2018-06-05',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2018',
#    'nom_producteur': 'EMPREINTE CINÉMA',
#    'date_fin': '2018-06-05',
#    'geo_point_2d': [48.85867153281226, 2.2846058671570257]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.2846058671570257, 48.85867153281226]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '4f936d43d78bb19129f0b6922cea8b844d8820b2',
#   'fields': {'coord_x': 2.3455565,
#    'id_lieu': '2018-458',
#    'adresse_lieu': '4 rue turgot, 75009 paris',
#    'geo_shape': {'coordinates': [2.3455564994312605, 48.88006953202473],
#     'type': 'Point'},
#    'coord_y': 48.88006953,
#    'ardt_lieu': '75009',
#    'nom_tournage': "Can't Buy me love",
#    'nom_realisateur': 'Noémie Saglio - Renaud Bertrand',
#    'date_debut': '2018-04-10',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2018',
#    'nom_producteur': 'Unrated Studio',
#    'date_fin': '2018-04-11',
#    'geo_point_2d': [48.88006953202473, 2.3455564994312605]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3455564994312605, 48.88006953202473]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a95e4ddf5bf357420301614eb093b9bb084fe8b2',
#   'fields': {'coord_x': 2.34738367,
#    'id_lieu': '2017-1451',
#    'adresse_lieu': '23 rue clovis, 75005 paris',
#    'geo_shape': {'coordinates': [2.3473836669749217, 48.84635809643975],
#     'type': 'Point'},
#    'coord_y': 48.8463581,
#    'ardt_lieu': '75005',
#    'nom_tournage': "L'échappée",
#    'nom_realisateur': 'Mathias Pardo',
#    'date_debut': '2017-07-10',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'CHIFOUMI PRODUCTIONS',
#    'date_fin': '2017-07-11',
#    'geo_point_2d': [48.84635809643975, 2.3473836669749217]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3473836669749217, 48.84635809643975]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '8f0a5e6415dadb227029a3b885a34eaef3c32e2a',
#   'fields': {'coord_x': 2.3114027,
#    'id_lieu': '2017-1297',
#    'adresse_lieu': 'place vauban, 75007 paris',
#    'geo_shape': {'coordinates': [2.3114026975791027, 48.85386076340029],
#     'type': 'Point'},
#    'coord_y': 48.85386076,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'LOVE ADDICT',
#    'nom_realisateur': 'FRANK BELLOCQ',
#    'date_debut': '2017-05-31',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'MY FAMILY',
#    'date_fin': '2017-05-31',
#    'geo_point_2d': [48.85386076340029, 2.3114026975791027]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3114026975791027, 48.85386076340029]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '3148be064ac8f7e217f73fa613b2a068b5962efc',
#   'fields': {'coord_x': 2.35253286,
#    'id_lieu': '2017-161',
#    'adresse_lieu': '59 rue monge, 75005 paris',
#    'geo_shape': {'coordinates': [2.3525328589336305, 48.84433785331593],
#     'type': 'Point'},
#    'coord_y': 48.84433785,
#    'ardt_lieu': '75005',
#    'nom_tournage': 'JE NE SUIS PAS UN HOMME FACILE',
#    'nom_realisateur': 'ELEONORE POURRIAT',
#    'date_debut': '2017-03-20',
#    'type_tournage': 'Téléfilm',
#    'annee_tournage': '2017',
#    'nom_producteur': 'FILM INVADERS',
#    'date_fin': '2017-03-20',
#    'geo_point_2d': [48.84433785331593, 2.3525328589336305]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3525328589336305, 48.84433785331593]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '38aeb684d354c400bf3c39e4a5b1827f576464df',
#   'fields': {'coord_x': 2.36275565,
#    'id_lieu': '2017-1099',
#    'adresse_lieu': '11 boulevard henri iv, 75004 paris',
#    'geo_shape': {'coordinates': [2.3627556489385335, 48.85138965299323],
#     'type': 'Point'},
#    'coord_y': 48.85138965,
#    'ardt_lieu': '75004',
#    'nom_tournage': 'PHILHARMONIA',
#    'nom_realisateur': 'LOUIS CHOQUETTE',
#    'date_debut': '2017-12-15',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'MERLIN PRODUCTIONS',
#    'date_fin': '2017-12-15',
#    'geo_point_2d': [48.85138965299323, 2.3627556489385335]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3627556489385335, 48.85138965299323]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'd4d29aa5addb2f2fd2ae4e07bc7309c44bea2de2',
#   'fields': {'coord_x': 2.33695119,
#    'id_lieu': '2017-1116',
#    'adresse_lieu': '76 rue de seine, 75006 paris',
#    'geo_shape': {'coordinates': [2.3369511865525268, 48.85194135734028],
#     'type': 'Point'},
#    'coord_y': 48.85194136,
#    'ardt_lieu': '75006',
#    'nom_tournage': 'MADE IN CHINA',
#    'nom_realisateur': 'Julien ABRAHAM',
#    'date_debut': '2017-12-14',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'MONTAUK FILMS',
#    'date_fin': '2017-12-14',
#    'geo_point_2d': [48.85194135734028, 2.3369511865525268]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3369511865525268, 48.85194135734028]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '2053d4cb32f83f009f24add76f41ba4daee9caec',
#   'fields': {'coord_x': 2.38522297,
#    'id_lieu': '2017-1565',
#    'adresse_lieu': 'rue piat, 75020 paris',
#    'geo_shape': {'coordinates': [2.385222968759945, 48.871775612101125],
#     'type': 'Point'},
#    'coord_y': 48.87177561,
#    'ardt_lieu': '75020',
#    'nom_tournage': 'Comme des rois',
#    'nom_realisateur': 'Xabi Molia',
#    'date_debut': '2017-01-27',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': "Moteur S'il Vous Plaît",
#    'date_fin': '2017-01-27',
#    'geo_point_2d': [48.871775612101125, 2.385222968759945]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.385222968759945, 48.871775612101125]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a15caa1b94840eca851d4e72c7d91c11ed2a1278',
#   'fields': {'coord_x': 2.31390097,
#    'id_lieu': '2018-475',
#    'adresse_lieu': '6 rue masseran, 75007 paris',
#    'geo_shape': {'coordinates': [2.3139009713188043, 48.848754523402114],
#     'type': 'Point'},
#    'coord_y': 48.84875452,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'PLAY',
#    'nom_realisateur': 'ANTHONY MARCIANO',
#    'date_debut': '2018-04-10',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2018',
#    'nom_producteur': 'CHAPTER 2',
#    'date_fin': '2018-04-10',
#    'geo_point_2d': [48.848754523402114, 2.3139009713188043]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3139009713188043, 48.848754523402114]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'fd0be6a29aaf5cd44ffbb6b66339a110f364f397',
#   'fields': {'coord_x': 2.31240258,
#    'id_lieu': '2018-476',
#    'adresse_lieu': 'place du président mithouard, 75007 paris',
#    'geo_shape': {'coordinates': [2.3124025780023962, 48.85045564197077],
#     'type': 'Point'},
#    'coord_y': 48.85045564,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'PLAY',
#    'nom_realisateur': 'ANTHONY MARCIANO',
#    'date_debut': '2018-04-10',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2018',
#    'nom_producteur': 'CHAPTER 2',
#    'date_fin': '2018-04-10',
#    'geo_point_2d': [48.85045564197077, 2.3124025780023962]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3124025780023962, 48.85045564197077]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'b24518e511e4b94e8180126de5c0681ab903e91d',
#   'fields': {'coord_x': 2.38316151,
#    'id_lieu': '2019-1746',
#    'adresse_lieu': 'passage miriam makeba, 75012 paris',
#    'geo_shape': {'coordinates': [2.383161510837496, 48.843709666213215],
#     'type': 'Point'},
#    'coord_y': 48.84370967,
#    'ardt_lieu': '75012',
#    'nom_tournage': "PARENT D'ELEVE",
#    'nom_realisateur': 'Noémie SAGLIO',
#    'date_debut': '2019-12-16',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2019',
#    'nom_producteur': 'RECTANGLE PRODUCTIONS',
#    'date_fin': '2019-12-16',
#    'geo_point_2d': [48.843709666213215, 2.383161510837496]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.383161510837496, 48.843709666213215]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '9737a8d80c5d1dcdb4fbeb8231a0cea87d1c8f15',
#   'fields': {'coord_x': 2.35505389,
#    'id_lieu': '2019-1755',
#    'adresse_lieu': 'pont de la tournelle, 75005 paris',
#    'geo_shape': {'coordinates': [2.3550538904017637, 48.85005374557193],
#     'type': 'Point'},
#    'coord_y': 48.85005375,
#    'ardt_lieu': '75005',
#    'nom_tournage': 'PROFILAGE EPISODES 101/102',
#    'nom_realisateur': 'ALEXANDRE LAURENT',
#    'date_debut': '2019-12-14',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2019',
#    'nom_producteur': 'BEAUBOURG AUDIOVISUEL',
#    'date_fin': '2019-12-15',
#    'geo_point_2d': [48.85005374557193, 2.3550538904017637]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3550538904017637, 48.85005374557193]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '2d685666fb344ff84b1843b6096b4134522272c1',
#   'fields': {'coord_x': 2.3022059,
#    'id_lieu': '2017-1302',
#    'adresse_lieu': 'cours albert ier, 75008 paris',
#    'geo_shape': {'coordinates': [2.3022058997720047, 48.864406963921084],
#     'type': 'Point'},
#    'coord_y': 48.86440696,
#    'ardt_lieu': '75008',
#    'nom_tournage': "Eiffel i'm in love 2",
#    'nom_realisateur': 'Rizal Mantovani',
#    'date_debut': '2017-06-05',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'IFILMFRANCE',
#    'date_fin': '2017-06-06',
#    'geo_point_2d': [48.864406963921084, 2.3022058997720047]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3022058997720047, 48.864406963921084]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '278f064cff9bf9c30e46cca0084ec5f86fe3017b',
#   'fields': {'coord_x': 2.29801602,
#    'id_lieu': '2017-1305',
#    'adresse_lieu': '132 boulevard de grenelle, 75015 paris',
#    'geo_shape': {'coordinates': [2.2980160245127372, 48.84881771334906],
#     'type': 'Point'},
#    'coord_y': 48.84881771,
#    'ardt_lieu': '75015',
#    'nom_tournage': "Eiffel i'm in love 2",
#    'nom_realisateur': 'Rizal Mantovani',
#    'date_debut': '2017-06-04',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'IFILMFRANCE',
#    'date_fin': '2017-06-04',
#    'geo_point_2d': [48.84881771334906, 2.2980160245127372]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.2980160245127372, 48.84881771334906]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'c91df851340fdf8fb4d914f31c49ab21f30a050d',
#   'fields': {'coord_x': 2.3397304,
#    'id_lieu': '2017-1306',
#    'adresse_lieu': '9 rue norvins, 75018 paris',
#    'geo_shape': {'coordinates': [2.3397304042044595, 48.8869774949019],
#     'type': 'Point'},
#    'coord_y': 48.8869775,
#    'ardt_lieu': '75018',
#    'nom_tournage': "Eiffel i'm in love 2",
#    'nom_realisateur': 'Rizal Mantovani',
#    'date_debut': '2017-06-07',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'IFILMFRANCE',
#    'date_fin': '2017-06-07',
#    'geo_point_2d': [48.8869774949019, 2.3397304042044595]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3397304042044595, 48.8869774949019]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '1a18125e11ef91163df82158ab8e5139b71ec1a8',
#   'fields': {'coord_x': 2.34043401,
#    'id_lieu': '2017-1309',
#    'adresse_lieu': 'place du calvaire, 75018 paris',
#    'geo_shape': {'coordinates': [2.340434007628884, 48.886230182245065],
#     'type': 'Point'},
#    'coord_y': 48.88623018,
#    'ardt_lieu': '75018',
#    'nom_tournage': "Eiffel i'm in love 2",
#    'nom_realisateur': 'Rizal Mantovani',
#    'date_debut': '2017-06-08',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'IFILMFRANCE',
#    'date_fin': '2017-06-08',
#    'geo_point_2d': [48.886230182245065, 2.340434007628884]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.340434007628884, 48.886230182245065]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '7b9f7af6f41a8f84903ffd3a183036cc796d3338',
#   'fields': {'coord_x': 2.36588439,
#    'id_lieu': '2017-1331',
#    'adresse_lieu': '16 rue du faubourg du temple, 75011 paris',
#    'geo_shape': {'coordinates': [2.365884386537487, 48.868239655478924],
#     'type': 'Point'},
#    'coord_y': 48.86823966,
#    'ardt_lieu': '75011',
#    'nom_tournage': 'One Woman',
#    'nom_realisateur': 'Maxime Taris',
#    'date_debut': '2017-06-13',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2017',
#    'nom_producteur': 'La Fémis',
#    'date_fin': '2017-06-13',
#    'geo_point_2d': [48.868239655478924, 2.365884386537487]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.365884386537487, 48.868239655478924]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'f8154d96bf3184758fd5745915257830acbd8324',
#   'fields': {'coord_x': 2.29546872,
#    'id_lieu': '2017-1341',
#    'adresse_lieu': 'avenue gustave eiffel, 75007 paris',
#    'geo_shape': {'coordinates': [2.2954687202053736, 48.8579898753801],
#     'type': 'Point'},
#    'coord_y': 48.85798988,
#    'ardt_lieu': '75007',
#    'nom_tournage': "L'extraordinaire voyage du Fakir",
#    'nom_realisateur': 'Ken Scott',
#    'date_debut': '2017-07-19',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Brio Films',
#    'date_fin': '2017-07-20',
#    'geo_point_2d': [48.8579898753801, 2.2954687202053736]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.2954687202053736, 48.8579898753801]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '8132dd62bcf86b28472e57bed05c4c9d757a0f28',
#   'fields': {'coord_x': 2.3243698,
#    'id_lieu': '2017-494',
#    'adresse_lieu': 'place gabriel péri, 75008 paris',
#    'geo_shape': {'coordinates': [2.3243698026886626, 48.87516942711818],
#     'type': 'Point'},
#    'coord_y': 48.87516943,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'VOLTAIRE',
#    'nom_realisateur': 'Stephen Woolfenden',
#    'date_debut': '2017-10-18',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'PENINSULA FILM',
#    'date_fin': '2017-10-18',
#    'geo_point_2d': [48.87516942711818, 2.3243698026886626]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3243698026886626, 48.87516942711818]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a90b78bf0aa8651f9eb61fb438439df1aa14f0cc',
#   'fields': {'coord_x': 2.32345939,
#    'id_lieu': '2017-523',
#    'adresse_lieu': 'place de la madeleine, 75008 paris',
#    'geo_shape': {'coordinates': [2.32345938874116, 48.869746169180495],
#     'type': 'Point'},
#    'coord_y': 48.86974617,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'SUN',
#    'nom_realisateur': 'Jonathan Desoindre',
#    'date_debut': '2017-09-21',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2017',
#    'nom_producteur': 'Rouge International',
#    'date_fin': '2017-09-21',
#    'geo_point_2d': [48.869746169180495, 2.32345938874116]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.32345938874116, 48.869746169180495]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '16db68261ffa17d1c49718e3ecf5af26af60155f',
#   'fields': {'coord_x': 2.34328164,
#    'id_lieu': '2020-169',
#    'adresse_lieu': "rue de l'hirondelle, 75006 paris",
#    'geo_shape': {'coordinates': [2.3432816437650095, 48.853544287028086],
#     'type': 'Point'},
#    'coord_y': 48.85354429,
#    'ardt_lieu': '75006',
#    'nom_tournage': 'TRUE STORY',
#    'nom_realisateur': 'Ludovic  HUDSON',
#    'date_debut': '2020-03-05',
#    'type_tournage': 'Série Web',
#    'annee_tournage': '2020',
#    'nom_producteur': 'IDZ',
#    'date_fin': '2020-03-06',
#    'geo_point_2d': [48.853544287028086, 2.3432816437650095]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3432816437650095, 48.853544287028086]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'b0f264609b7daffac73771ecda582a24c4115820',
#   'fields': {'coord_x': 2.33666553,
#    'id_lieu': '2020-180',
#    'adresse_lieu': '39 rue des abbesses, 75018 paris',
#    'geo_shape': {'coordinates': [2.3366655251025907, 48.88511012290494],
#     'type': 'Point'},
#    'coord_y': 48.88511012,
#    'ardt_lieu': '75018',
#    'nom_tournage': 'BELLE BELLE BELLE',
#    'nom_realisateur': 'ANNE DEPETRINI',
#    'date_debut': '2020-03-09',
#    'type_tournage': 'Téléfilm',
#    'annee_tournage': '2020',
#    'nom_producteur': 'felicita films',
#    'date_fin': '2020-03-09',
#    'geo_point_2d': [48.88511012290494, 2.3366655251025907]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3366655251025907, 48.88511012290494]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '81307c00a051e0d2ccf79e8f8f1cd1fbc0a1ba4e',
#   'fields': {'coord_x': 2.38535478,
#    'id_lieu': '2020-184',
#    'adresse_lieu': '1 rue maillard, 75011 paris',
#    'geo_shape': {'coordinates': [2.385354777983584, 48.85800940437682],
#     'type': 'Point'},
#    'coord_y': 48.85800941,
#    'ardt_lieu': '75011',
#    'nom_tournage': 'ARSENE LUPIN',
#    'nom_realisateur': 'MARCELA SAID',
#    'date_debut': '2020-03-11',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2020',
#    'nom_producteur': 'GAUMONT PRODUCTION TELEVISION',
#    'date_fin': '2020-03-12',
#    'geo_point_2d': [48.85800940437682, 2.385354777983584]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.385354777983584, 48.85800940437682]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a264f216d64a5f167cc434b3ca4f373b79b89597',
#   'fields': {'coord_x': 2.285782,
#    'id_lieu': '2016-317',
#    'adresse_lieu': '22\xa0 SQUARE\xa0 ALBONI',
#    'geo_shape': {'coordinates': [2.285781999385937, 48.85704999958906],
#     'type': 'Point'},
#    'coord_y': 48.85705,
#    'ardt_lieu': '75016',
#    'nom_tournage': 'DJANGO MELODIES',
#    'nom_realisateur': 'ETIENNE COMAR',
#    'date_debut': '2016-04-19',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'CURIOSA FILMS',
#    'date_fin': '2016-04-19',
#    'geo_point_2d': [48.85704999958906, 2.285781999385937]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.285781999385937, 48.85704999958906]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'ccb0607bcef86c02d6626184f9a765136cc36526',
#   'fields': {'coord_x': 2.326873,
#    'id_lieu': '2016-339',
#    'adresse_lieu': '7\xa0 PLACE\xa0 DE CLICHY',
#    'geo_shape': {'coordinates': [2.3268729995247956, 48.883746999585185],
#     'type': 'Point'},
#    'coord_y': 48.883747,
#    'ardt_lieu': '75017',
#    'nom_tournage': 'JEUNE FEMME',
#    'nom_realisateur': 'LEONOR SERRAILLE',
#    'date_debut': '2016-02-26',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'BLUE MONDAY PRODUCTIONS',
#    'date_fin': '2016-02-26',
#    'geo_point_2d': [48.883746999585185, 2.3268729995247956]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3268729995247956, 48.883746999585185]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '490441f46d24fc9906540308d83de860c58748e4',
#   'fields': {'coord_x': 2.341215,
#    'id_lieu': '2016-347',
#    'adresse_lieu': "46\xa0 RUE\xa0 DE LA TOUR D'AUVERGNE",
#    'geo_shape': {'coordinates': [2.3412149996119074, 48.87975099984729],
#     'type': 'Point'},
#    'coord_y': 48.879751,
#    'ardt_lieu': '75009',
#    'nom_tournage': 'MARIAGE BLANC',
#    'nom_realisateur': 'TAREK BOUDALI',
#    'date_debut': '2016-09-02',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'AXEL FILMS',
#    'date_fin': '2016-09-02',
#    'geo_point_2d': [48.87975099984729, 2.3412149996119074]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3412149996119074, 48.87975099984729]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'c6b985c84ac5b3898a34991210750158204840a0',
#   'fields': {'coord_x': 2.37793919,
#    'id_lieu': '2021-1026',
#    'adresse_lieu': '27 rue edouard pailleron, 75019 paris',
#    'geo_shape': {'coordinates': [2.3779391890831594, 48.881120583747396],
#     'type': 'Point'},
#    'coord_y': 48.88112058,
#    'ardt_lieu': '75019',
#    'nom_tournage': "L'ÉCOLE EST À NOUS",
#    'nom_realisateur': 'ALEXANDRE CASTAGNETTI',
#    'date_debut': '2021-07-12',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2021',
#    'nom_producteur': 'MANDARIN ET COMPAGNIE',
#    'date_fin': '2021-07-12',
#    'geo_point_2d': [48.881120583747396, 2.3779391890831594]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3779391890831594, 48.881120583747396]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '05194e1e8edb8551bb0fc94e1708b4032ea9e2a3',
#   'fields': {'coord_x': 2.406785,
#    'id_lieu': '2016-33',
#    'adresse_lieu': 'RUE\xa0 DU CAPITAINE FERBER',
#    'geo_shape': {'coordinates': [2.406785000659756, 48.86661200022147],
#     'type': 'Point'},
#    'coord_y': 48.866612,
#    'ardt_lieu': '75020',
#    'nom_tournage': '10%/SAISON 2',
#    'nom_realisateur': 'JEANNE HERRY',
#    'date_debut': '2016-09-30',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2016',
#    'nom_producteur': 'MON VOISIN PRODUCTIONS',
#    'date_fin': '2016-09-30',
#    'geo_point_2d': [48.86661200022147, 2.406785000659756]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.406785000659756, 48.86661200022147]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '528961fe8c48918f12be8d3c042680570abe5699',
#   'fields': {'coord_x': 2.348461,
#    'id_lieu': '2016-1257',
#    'adresse_lieu': '34\xa0 RUE\xa0 DE LA MONTAGNE SAINTE GENEVIEVE',
#    'geo_shape': {'coordinates': [2.3484609995811687, 48.84802400007241],
#     'type': 'Point'},
#    'coord_y': 48.848024,
#    'ardt_lieu': '75005',
#    'nom_tournage': 'GC5',
#    'nom_realisateur': 'GUILLAUME CANET',
#    'date_debut': '2016-02-18',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'LES PRODUCTIONS DU TRESOR',
#    'date_fin': '2016-02-18',
#    'geo_point_2d': [48.84802400007241, 2.3484609995811687]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3484609995811687, 48.84802400007241]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '17e2835d6059bcbf97ed16a33ff49044ec2839fb',
#   'fields': {'coord_x': 2.289632,
#    'id_lieu': '2016-1262',
#    'adresse_lieu': '84\xa0 AVENUE\xa0 KLEBER',
#    'geo_shape': {'coordinates': [2.289631999541639, 48.866722999676995],
#     'type': 'Point'},
#    'coord_y': 48.866723,
#    'ardt_lieu': '75016',
#    'nom_tournage': 'CHERCHEZ LA FEMME',
#    'nom_realisateur': 'SOU ABADI',
#    'date_debut': '2016-05-02',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'THE FILM',
#    'date_fin': '2016-05-05',
#    'geo_point_2d': [48.866722999676995, 2.289631999541639]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.289631999541639, 48.866722999676995]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '3299b931b755226ab04c7cb144e05061fff729ca',
#   'fields': {'coord_x': 2.34322288,
#    'id_lieu': '2019-635',
#    'adresse_lieu': '51 rue des ecoles, 75005 paris',
#    'geo_shape': {'coordinates': [2.343222884836869, 48.84997992490092],
#     'type': 'Point'},
#    'coord_y': 48.84997993,
#    'ardt_lieu': '75005',
#    'nom_tournage': 'En attendant qui ? Mai',
#    'nom_realisateur': 'Marc RECUENCO',
#    'date_debut': '2019-06-23',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2019',
#    'nom_producteur': 'SerialBstudio',
#    'date_fin': '2019-06-23',
#    'geo_point_2d': [48.84997992490092, 2.343222884836869]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.343222884836869, 48.84997992490092]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'ee2be5de95c47747fa5569fd493a2cbdc7da4d73',
#   'fields': {'coord_x': 2.31806583,
#    'id_lieu': '2019-638',
#    'adresse_lieu': '101 rue des dames, 75017 paris',
#    'geo_shape': {'coordinates': [2.318065825697751, 48.88293095286766],
#     'type': 'Point'},
#    'coord_y': 48.88293095,
#    'ardt_lieu': '75017',
#    'nom_tournage': 'En attendant qui ? Mai',
#    'nom_realisateur': 'Marc RECUENCO',
#    'date_debut': '2019-06-13',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2019',
#    'nom_producteur': 'SerialBstudio',
#    'date_fin': '2019-06-13',
#    'geo_point_2d': [48.88293095286766, 2.318065825697751]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.318065825697751, 48.88293095286766]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '28b09843332b0b0c0c06cbad5a78678e3e2bb400',
#   'fields': {'coord_x': 2.38535478,
#    'id_lieu': '2019-1590',
#    'adresse_lieu': '1 rue maillard, 75011 paris',
#    'geo_shape': {'coordinates': [2.385354777983584, 48.85800940437682],
#     'type': 'Point'},
#    'coord_y': 48.85800941,
#    'ardt_lieu': '75011',
#    'nom_tournage': "J'IRAI MOURIR DANS LES CARPATES",
#    'nom_realisateur': 'ANTOINE DE MAXIMY',
#    'date_debut': '2019-12-02',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2019',
#    'nom_producteur': 'ROUGE INTERNATIONAL',
#    'date_fin': '2019-12-03',
#    'geo_point_2d': [48.85800940437682, 2.385354777983584]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.385354777983584, 48.85800940437682]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '732695dfb791583a6877c7d40783a56cfa78cf37',
#   'fields': {'coord_x': 2.34215347,
#    'id_lieu': '2019-1593',
#    'adresse_lieu': '17 place dauphine, 75001 paris',
#    'geo_shape': {'coordinates': [2.342153474335441, 48.85644810065937],
#     'type': 'Point'},
#    'coord_y': 48.8564481,
#    'ardt_lieu': '75001',
#    'nom_tournage': 'SOOF 3',
#    'nom_realisateur': 'ANNE DE CLERCQ',
#    'date_debut': '2019-11-20',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2019',
#    'nom_producteur': 'Soof BV P/a',
#    'date_fin': '2019-11-20',
#    'geo_point_2d': [48.85644810065937, 2.342153474335441]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.342153474335441, 48.85644810065937]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'c2bfeebdfd68559173819c038c7175c97fca912d',
#   'fields': {'coord_x': 2.342895,
#    'id_lieu': '2016-363',
#    'adresse_lieu': 'PARVIS\xa0 DU SACRE COEUR',
#    'geo_shape': {'coordinates': [2.342894999902618, 48.886198999983236],
#     'type': 'Point'},
#    'coord_y': 48.886199,
#    'ardt_lieu': '75018',
#    'nom_tournage': 'DANIEL',
#    'nom_realisateur': 'CYRIL MENNEGUN',
#    'date_debut': '2016-05-27',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'UNITE DE PRODUCTION',
#    'date_fin': '2016-05-27',
#    'geo_point_2d': [48.886198999983236, 2.342894999902618]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.342894999902618, 48.886198999983236]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '62b6bcf5620b517880b66aa59adc53cc5df15667',
#   'fields': {'coord_x': 2.36509,
#    'id_lieu': '2016-1884',
#    'adresse_lieu': 'BOULEVARD\xa0 VINCENT AURIOL',
#    'geo_shape': {'coordinates': [2.3650900003041224, 48.834130000130514],
#     'type': 'Point'},
#    'coord_y': 48.83413,
#    'ardt_lieu': '75013',
#    'nom_tournage': 'LA FETE EST FINIE',
#    'nom_realisateur': 'MARIE GAREL WEISS',
#    'date_debut': '2016-10-13',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'ELZEVIR FILMS',
#    'date_fin': '2016-10-13',
#    'geo_point_2d': [48.834130000130514, 2.3650900003041224]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3650900003041224, 48.834130000130514]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'f5cbbc716f5b7a13830f191d182c8c546cc737c9',
#   'fields': {'coord_x': 2.338886,
#    'id_lieu': '2016-71',
#    'adresse_lieu': "RUE\xa0 DE L'ABREUVOIR",
#    'geo_shape': {'coordinates': [2.338886000242545, 48.888211000406386],
#     'type': 'Point'},
#    'coord_y': 48.888211,
#    'ardt_lieu': '75018',
#    'nom_tournage': 'BEFIKRE',
#    'nom_realisateur': 'ADITYA CHOPRA',
#    'date_debut': '2016-02-25',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'FIRSTEP',
#    'date_fin': '2016-02-25',
#    'geo_point_2d': [48.888211000406386, 2.338886000242545]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.338886000242545, 48.888211000406386]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '25b4a7330ed4940eef76b414e71bd2bd86249347',
#   'fields': {'coord_x': 2.339595,
#    'id_lieu': '2016-73',
#    'adresse_lieu': 'RUE\xa0 DE LA BOURSE',
#    'geo_shape': {'coordinates': [2.3395950001936208, 48.869551999972366],
#     'type': 'Point'},
#    'coord_y': 48.869552,
#    'ardt_lieu': '75002',
#    'nom_tournage': 'JUST DIVORCED',
#    'nom_realisateur': 'MAXIME GOVARE',
#    'date_debut': '2016-11-05',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'LES IMPRODUCTIBLES',
#    'date_fin': '2016-11-05',
# ...
#    'nom_tournage': 'LA PAGE BLANCHE',
#    'nom_realisateur': 'Murielle MAGELLAN',
#    'date_debut': '2021-06-29',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2021',
#    'nom_producteur': 'PARTNERS IN CRIME',
#    'date_fin': '2021-06-30',
#    'geo_point_2d': [48.88983646810342, 2.3642768036544823]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3642768036544823, 48.88983646810342]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '336e57e3d64c1218ecf85a3b606d72f0a1df0a39',
#   'fields': {'coord_x': 2.33978604,
#    'id_lieu': '2021-890',
#    'adresse_lieu': '2 rue poulbot, 75018 paris',
#    'geo_shape': {'coordinates': [2.3397860358007843, 48.88691793342549],
#     'type': 'Point'},
#    'coord_y': 48.88691793,
#    'ardt_lieu': '75018',
#    'nom_tournage': 'LA PAGE BLANCHE',
#    'nom_realisateur': 'Murielle MAGELLAN',
#    'date_debut': '2021-06-29',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2021',
#    'nom_producteur': 'PARTNERS IN CRIME',
#    'date_fin': '2021-06-29',
#    'geo_point_2d': [48.88691793342549, 2.3397860358007843]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3397860358007843, 48.88691793342549]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '09fc3848ecdbe0eb963d24d886da7053416c994a',
#   'fields': {'coord_x': 2.360048,
#    'id_lieu': '2016-1142',
#    'adresse_lieu': '15\xa0 RUE\xa0 POLIVEAU',
#    'geo_shape': {'coordinates': [2.360048000624602, 48.840245999846665],
#     'type': 'Point'},
#    'coord_y': 48.840246,
#    'ardt_lieu': '75005',
#    'nom_tournage': 'DEMAIN ET TOUS LES AUTRES JOURS (2)',
#    'nom_realisateur': 'NOVEMIE LVOVSKY',
#    'date_debut': '2016-05-02',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'F COMME FILM',
#    'date_fin': '2016-05-02',
#    'geo_point_2d': [48.840245999846665, 2.360048000624602]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.360048000624602, 48.840245999846665]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '99cb090ab2c01c0ff8503933f2dd3d553bfa416d',
#   'fields': {'coord_x': 2.317319,
#    'id_lieu': '2016-1157',
#    'adresse_lieu': '63\xa0 BOULEVARD\xa0 DES BATIGNOLLES',
#    'geo_shape': {'coordinates': [2.3173190003771333, 48.88126200024609],
#     'type': 'Point'},
#    'coord_y': 48.881262,
#    'ardt_lieu': '75008',
#    'nom_tournage': 'LA MONNAIE DE LEUR PIECE',
#    'nom_realisateur': 'ANNE LE NY',
#    'date_debut': '2016-12-07',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'MOVE MOVIE',
#    'date_fin': '2016-12-08',
#    'geo_point_2d': [48.88126200024609, 2.3173190003771333]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3173190003771333, 48.88126200024609]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '07f35c8b27159e8a437f9706181dfe73e530ea22',
#   'fields': {'coord_x': 2.35843,
#    'id_lieu': '2016-1172',
#    'adresse_lieu': "83/87\xa0 AVENUE\xa0 D'ITALIE",
#    'geo_shape': {'coordinates': [2.3584300000162193, 48.8240379999288],
#     'type': 'Point'},
#    'coord_y': 48.824038,
#    'ardt_lieu': '75013',
#    'nom_tournage': 'MAMAN A TORT',
#    'nom_realisateur': 'MARC FITOUSSI',
#    'date_debut': '2016-01-07',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'AVENUE B',
#    'date_fin': '2016-01-08',
#    'geo_point_2d': [48.8240379999288, 2.3584300000162193]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3584300000162193, 48.8240379999288]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '9785672860e973421ba5e62cc1c2f21a400b8d84',
#   'fields': {'coord_x': 2.364076,
#    'id_lieu': '2016-1175',
#    'adresse_lieu': '12\xa0 RUE\xa0 DE TORCY/CHANTIER GCC',
#    'geo_shape': {'coordinates': [2.3640760000293866, 48.89125400021145],
#     'type': 'Point'},
#    'coord_y': 48.891254,
#    'ardt_lieu': '75018',
#    'nom_tournage': "SI J'ETAIS UN HOMME",
#    'nom_realisateur': 'AUDREY DANA',
#    'date_debut': '2016-04-06',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'CURIOSA FILMS',
#    'date_fin': '2016-04-09',
#    'geo_point_2d': [48.89125400021145, 2.3640760000293866]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3640760000293866, 48.89125400021145]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'f8df83388d5b80ab3a77071ba96e978244e4640b',
#   'fields': {'coord_x': 2.350685,
#    'id_lieu': '2016-1188',
#    'adresse_lieu': 'PONT\xa0 AU CHANGE',
#    'geo_shape': {'coordinates': [2.3506849995613157, 48.853792000102295],
#     'type': 'Point'},
#    'coord_y': 48.853792,
#    'ardt_lieu': '75004',
#    'nom_tournage': 'BARBARA',
#    'nom_realisateur': 'MATHIEU AMALRIC',
#    'date_debut': '2016-11-28',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'WAITING FOR CINEMA',
#    'date_fin': '2016-11-28',
#    'geo_point_2d': [48.853792000102295, 2.3506849995613157]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3506849995613157, 48.853792000102295]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '19cadf7f03801b1c7374a30022830527b32c3357',
#   'fields': {'coord_x': 2.359355,
#    'id_lieu': '2016-270',
#    'adresse_lieu': '1\xa0 RUE\xa0 RENE PANHARD',
#    'geo_shape': {'coordinates': [2.3593549995397, 48.8387789995482],
#     'type': 'Point'},
#    'coord_y': 48.838779,
#    'ardt_lieu': '75013',
#    'nom_tournage': 'JE VOULAIS JUSTE RENTRER CHEZ MOI',
#    'nom_realisateur': 'YVES RENIER',
#    'date_debut': '2016-12-07',
#    'type_tournage': 'Téléfilm',
#    'annee_tournage': '2016',
#    'nom_producteur': 'CHABRAQUE PRODUCTIONS',
#    'date_fin': '2016-12-09',
#    'geo_point_2d': [48.8387789995482, 2.3593549995397]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3593549995397, 48.8387789995482]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '24391c088eedec9118c80edb08e2a2b0e908b0a0',
#   'fields': {'coord_x': 2.356798,
#    'id_lieu': '2016-287',
#    'adresse_lieu': "28\xa0 RUE\xa0 GEOFFROY L'ASNIER",
#    'geo_shape': {'coordinates': [2.3567979999991637, 48.85503299977159],
#     'type': 'Point'},
#    'coord_y': 48.855033,
#    'ardt_lieu': '75004',
#    'nom_tournage': 'RODIN',
#    'nom_realisateur': 'JACQUES DOILLON',
#    'date_debut': '2016-05-29',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'LES FILMS DU LENDEMAIN',
#    'date_fin': '2016-06-03',
#    'geo_point_2d': [48.85503299977159, 2.3567979999991637]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3567979999991637, 48.85503299977159]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'a085c1c354f0a073d09c8e5de34800fdbd1babd4',
#   'fields': {'coord_x': 2.307613,
#    'id_lieu': '2016-1785',
#    'adresse_lieu': '59\xa0 AVENUE\xa0 DE SEGUR',
#    'geo_shape': {'coordinates': [2.3076129998652455, 48.84901399957857],
#     'type': 'Point'},
#    'coord_y': 48.849014,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'ALICE NEVERS LE JUGE EST UNE FEMME/86 ET 87',
#    'nom_realisateur': 'CHRISTOPHE DELPIAS',
#    'date_debut': '2016-12-01',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2016',
#    'nom_producteur': 'EGO PRODUCTION',
#    'date_fin': '2016-12-01',
#    'geo_point_2d': [48.84901399957857, 2.3076129998652455]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3076129998652455, 48.84901399957857]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '5eadd048dca52c634d8b7a066d23324ea731d4b9',
#   'fields': {'coord_x': 2.3489005,
#    'id_lieu': '2021-910',
#    'adresse_lieu': '6 parvis notre-dame place jean-paul ii, 75004 paris',
#    'geo_shape': {'coordinates': [2.3489004994869047, 48.85299075549731],
#     'type': 'Point'},
#    'coord_y': 48.85299076,
#    'ardt_lieu': '75004',
#    'nom_tournage': 'NOTRE-DAME, LA PART DU FEU',
#    'nom_realisateur': 'HERVÉ HADMAR',
#    'date_debut': '2021-08-03',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2021',
#    'nom_producteur': 'CHEYENNE FEDERATION',
#    'date_fin': '2021-08-04',
#    'geo_point_2d': [48.85299075549731, 2.3489004994869047]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3489004994869047, 48.85299075549731]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '394fc0f64785d0419437c5545b71739debf1d1e3',
#   'fields': {'coord_x': 2.3246033,
#    'id_lieu': '2021-924',
#    'adresse_lieu': '153 rue legendre, 75017 paris',
#    'geo_shape': {'coordinates': [2.3246033024275965, 48.89065560271433],
#     'type': 'Point'},
#    'coord_y': 48.8906556,
#    'ardt_lieu': '75017',
#    'nom_tournage': 'Rue des dames',
#    'nom_realisateur': 'Hamé et Ekoué',
#    'date_debut': '2021-07-16',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2021',
#    'nom_producteur': 'LA RUMEUR FILME',
#    'date_fin': '2021-07-17',
#    'geo_point_2d': [48.89065560271433, 2.3246033024275965]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3246033024275965, 48.89065560271433]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '2e61be7e3f608aaf044965a73afd6f05a738d562',
#   'fields': {'coord_x': 2.40295492,
#    'id_lieu': '2021-926',
#    'adresse_lieu': '24 rue louis braille, 75012 paris',
#    'geo_shape': {'coordinates': [2.4029549197177715, 48.83964555275171],
#     'type': 'Point'},
#    'coord_y': 48.83964555,
#    'ardt_lieu': '75012',
#    'nom_tournage': 'Rue des dames',
#    'nom_realisateur': 'Hamé et Ekoué',
#    'date_debut': '2021-07-06',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2021',
#    'nom_producteur': 'LA RUMEUR FILME',
#    'date_fin': '2021-07-06',
#    'geo_point_2d': [48.83964555275171, 2.4029549197177715]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.4029549197177715, 48.83964555275171]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'c6f756567f3e2f47e39fb16aad52eff718c81b2d',
#   'fields': {'coord_x': 2.28246777,
#    'id_lieu': '2021-936',
#    'adresse_lieu': '4 square du trocadéro, 75116 paris',
#    'geo_shape': {'coordinates': [2.28246776528642, 48.86254204666922],
#     'type': 'Point'},
#    'coord_y': 48.86254205,
#    'ardt_lieu': '75116',
#    'nom_tournage': 'Servicé Volé',
#    'nom_realisateur': 'Jérôme FOULON',
#    'date_debut': '2021-06-30',
#    'type_tournage': 'Téléfilm',
#    'annee_tournage': '2021',
#    'nom_producteur': 'PACHLI Productions',
#    'date_fin': '2021-06-30',
#    'geo_point_2d': [48.86254204666922, 2.28246776528642]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.28246776528642, 48.86254204666922]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '104333352dbbdd14bdf2eb28061bcd565f3ca1ed',
#   'fields': {'coord_x': 2.46184926,
#    'id_lieu': '2021-938',
#    'adresse_lieu': 'avenue de fontenay, 75012 paris',
#    'geo_shape': {'coordinates': [2.46184925817886, 48.84102141459116],
#     'type': 'Point'},
#    'coord_y': 48.84102142,
#    'ardt_lieu': '75012',
#    'nom_tournage': 'Le Remplaçant 3-4',
#    'nom_realisateur': 'Nicolas Guicheteau',
#    'date_debut': '2021-07-05',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2021',
#    'nom_producteur': 'Exilene Films',
#    'date_fin': '2021-07-06',
#    'geo_point_2d': [48.84102141459116, 2.46184925817886]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.46184925817886, 48.84102141459116]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '5d446dd024d2abf85dff086fe14182b228b3e1dd',
#   'fields': {'coord_x': 2.32057235,
#    'id_lieu': '2021-951',
#    'adresse_lieu': '16 rue gauthey, 75017 paris',
#    'geo_shape': {'coordinates': [2.3205723541711643, 48.89171181022207],
#     'type': 'Point'},
#    'coord_y': 48.89171181,
#    'ardt_lieu': '75017',
#    'nom_tournage': 'NOTRE-DAME, LA PART DU FEU',
#    'nom_realisateur': 'HERVÉ HADMAR',
#    'date_debut': '2021-07-05',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2021',
#    'nom_producteur': 'CHEYENNE FEDERATION',
#    'date_fin': '2021-07-06',
#    'geo_point_2d': [48.89171181022207, 2.3205723541711643]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3205723541711643, 48.89171181022207]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '00626b2fb6cd379bb2a862916394399e09fbe315',
#   'fields': {'coord_x': 2.311245,
#    'id_lieu': '2016-2709',
#    'adresse_lieu': '70\xa0 AVENUE\xa0 DE BRETEUUIL',
#    'geo_shape': {'coordinates': [2.3112449996417066, 48.84825099961249],
#     'type': 'Point'},
#    'coord_y': 48.848251,
#    'ardt_lieu': '75007',
#    'nom_tournage': 'LA NUIT A DEVORE LE MONDE',
#    'nom_realisateur': 'DOMINIQUE ROCHER',
#    'date_debut': '2016-11-07',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'HAUT ET COURT',
#    'date_fin': '2016-11-11',
#    'geo_point_2d': [48.84825099961249, 2.3112449996417066]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3112449996417066, 48.84825099961249]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '7c534cffce96c7046f5df149e3263a2a312c5c4e',
#   'fields': {'coord_x': 2.393375,
#    'id_lieu': '2016-2740',
#    'adresse_lieu': '7\xa0 RUE\xa0 SONIA DELAUNAY',
#    'geo_shape': {'coordinates': [2.3933749995441427, 48.855329999711984],
#     'type': 'Point'},
#    'coord_y': 48.85533,
#    'ardt_lieu': '75011',
#    'nom_tournage': 'JUSTE UN REGARD',
#    'nom_realisateur': 'LUDOVIC COLBEAU',
#    'date_debut': '2016-11-16',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2016',
#    'nom_producteur': 'VAB',
#    'date_fin': '2016-11-16',
#    'geo_point_2d': [48.855329999711984, 2.3933749995441427]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3933749995441427, 48.855329999711984]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': '2500c0b7ec3ed20410b20438de328b943b7f1669',
#   'fields': {'coord_x': 2.31023012,
#    'id_lieu': '2021-691',
#    'adresse_lieu': '16 avenue franklin d. roosevelt, 75008 paris',
#    'geo_shape': {'coordinates': [2.310230116659458, 48.871293501485695],
#     'type': 'Point'},
#    'coord_y': 48.8712935,
#    'ardt_lieu': '75008',
#    'nom_tournage': "L'amour (presque) Parfait",
#    'nom_realisateur': 'Pascale Pouzadoux',
#    'date_debut': '2021-06-04',
#    'type_tournage': 'Série TV',
#    'annee_tournage': '2021',
#    'nom_producteur': 'PM SA',
#    'date_fin': '2021-06-05',
#    'geo_point_2d': [48.871293501485695, 2.310230116659458]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.310230116659458, 48.871293501485695]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  {'datasetid': 'lieux-de-tournage-a-paris',
#   'recordid': 'de4b11a95e01525de72347a6921b6a5d0fcc5e38',
#   'fields': {'coord_x': 2.364755,
#    'id_lieu': '2016-1796',
#    'adresse_lieu': 'RUE\xa0 NATIONALE/DR VICTOR HUTINEL',
#    'geo_shape': {'coordinates': [2.3647550003848212, 48.831791999605514],
#     'type': 'Point'},
#    'coord_y': 48.831792,
#    'ardt_lieu': '75013',
#    'nom_tournage': 'GANGSTERDAM',
#    'nom_realisateur': 'ROMAIN LEVY',
#    'date_debut': '2016-08-26',
#    'type_tournage': 'Long métrage',
#    'annee_tournage': '2016',
#    'nom_producteur': 'LES PRODUCTIONS DU TRESOR',
#    'date_fin': '2016-08-26',
#    'geo_point_2d': [48.831791999605514, 2.3647550003848212]},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3647550003848212, 48.831791999605514]},
#   'record_timestamp': '2024-01-31T13:40:46.402+01:00'},
#  ...]

# %% [markdown]
# - Analyze the JSON file: what is its structure?
# - Write a function that converts an entry in a string that shows director, title, district, start date, end date, and geographic coordinates.
# - Convert all entries in strings (warning: some entries may have issues).
# - Display the first 20 entries.

# %% [markdown]
# I basically just loaded the json file content into a list where every element is an entry, and each entry represents a filming location. Every element has a dictionary like structure (just like every json file since it uses the key:value concept) which we can see above in the first element i displayed.
#
# i ran into so many keyerrors while trying to do this function, i had to ask chatgpt and it gave me the .get() method that helped handeling missing values by replacing them with strings that say "unknown director" for a missing nom_réalisateur value.

# %%
def display_loc(entry):
    return f'"{entry["fields"]["nom_tournage"]}" by {entry["fields"].get("nom_realisateur", "Unknown director")}, from {entry["fields"].get("date_debut", "Unknown data")} to {entry["fields"].get("date_fin", "Unknown data")}, in {entry["fields"].get("ardt_lieu", "Unknown place")} ({entry["fields"]["geo_point_2d"][0]}, {entry["fields"]["geo_point_2d"][1]})'

# %%
all_entries = [display_loc(e) for e in locs]
print('\n'.join(all_entries[:20]))
# Out:
# "2 Fils (Nouvelle Demande Décor Librairie / Journées interverties)" by Félix MOATI, from 2017-10-19 to 2017-10-19, in 75011 (48.8696979988026, 2.370062415669748)
# "Vernon Subutex" by Cathy Verney, from 2018-04-25 to 2018-04-26, in 75001 (48.85849330754624, 2.342487451056846)
# "LEBOWITZ CONTRE LEBOWITZ 2" by Olivier Barma, from 2017-06-01 to 2017-06-01, in 75010 (48.87597363622085, 2.3646350537874703)
# "À jamais fidèle" by cheyenne carron, from 2017-08-24 to 2017-08-25, in 75020 (48.85154733669693, 2.3986003434290892)
# "CHRONIQUES PARISIENNES 16" by ZABOU BREITMAN, from 2017-04-18 to 2017-04-18, in 75013 (48.82655664927356, 2.3812794291774626)
# "LOLYWOOD - DANS TES REVES LE SPORT" by Matthieu MARES-SAVELLI, from 2017-04-13 to 2017-04-13, in 75019 (48.893005176977596, 2.3977875069644603)
# "Un homme pressé" by Hervé Mimran, from 2017-05-23 to 2017-05-24, in 75012 (48.84258570428103, 2.3691360159868426)
# "L'AMOUR EST UNE FÊTE" by Cédric ANGER, from 2017-06-14 to 2017-06-14, in 75018 (48.882670376784226, 2.337097873322637)
# "LEBOWITZ CONTRE LEBOWITZ 2" by Unknown director, from 2017-05-31 to 2017-05-31, in 75010 (48.876569098357535, 2.3644223583154886)
# "Can't Buy me love" by Renaud Bertrand - Noémie Saglio, from 2018-05-15 to 2018-05-15, in 75009 (48.88227218218318, 2.346087705583743)
# "LE GENDRE IDEAL" by Hector CABELL REYES, from 2018-05-21 to 2018-05-21, in 75010 (48.871601161330965, 2.353783961250403)
# "Les Affamés" by Léa Frédeval, from 2017-07-16 to 2017-07-16, in 75008 (48.87278421793338, 2.326482985997865)
# "LES BEAUX ESPRITS" by VIANNEY LEBASQUE, from 2017-07-21 to 2017-07-22, in 75010 (48.876739410796205, 2.3656441866110183)
# "nOX" by mabrouk el Mechri, from 2017-07-18 to 2017-07-18, in 75020 (48.8741144391816, 2.3924234275751726)
# "UNDER THE EIFFEL TOWER" by ARCHIE BORDERS, from 2017-07-18 to 2017-07-18, in 75008 (48.864406963921084, 2.3022058997720047)
# "Taxi 5" by Franck Gastambide, from 2017-07-28 to 2017-07-28, in 75001 (48.86314441257238, 2.3316512810012355)
# "CHRONIQUES PARISIENNES" by ZABOU BREITMAN, from 2017-04-07 to 2017-04-07, in 75010 (48.873991253103675, 2.353028536322006)
# "BIG BANG" by Cécilia Rouaud, from 2017-03-29 to 2017-03-29, in 75001 (48.85510452788805, 2.3432630419377345)
# "THANKSGIVING" by NICOLAS SAADA, from 2017-11-21 to 2017-11-21, in 75007 (48.85778012113944, 2.328109801855801)
# "CURIOSA" by Unknown director, from 2017-11-30 to 2017-11-30, in 75116 (48.865760689593685, 2.297504389310135)

# %% [markdown]
# - A same movie can have multiple shooting locations. Make a list of movies, where each entry contains the movie title, its director, and shootings locations (district, start date, end date).
# - How many movies do you have?
# - Write a function that converts a movie into a string that shows director, title, and shootings.
# - Convert all movies in strings.
# - Display the first 20 entries.

# %% [markdown]
# What i understood from this part was that we had to create new data about the movies rather than locations using the locs list and so we had to have for each movie that exists in our database the director, movie title and the different locations it was shot in. The issue was that we knew from previous parts of this exercice that this database had a few (or a lot) of missing data for certain fields so we know we'll have to handle them later after we get a lot of key errors.
#
# An approach is to create a dictionary where each key is a movie title and then each value is a dictionary where the keys are 'director' that has a string value, 'locations' whose value is a list of tuples that look like: (district, start date, end date). The first thing that comes to mind is to naively use a for loop that loops through locs and and fills the previously declared dictionary and check at the start of every iteration if the movie is already in the dictionary, if yes then we'll just have to append the new location and the start and end date as a tuple in the locations list. else we just create a new movie key and fill it.

# %%
movies = dict()

for entry in locs:
    movie_title = entry['fields']['nom_tournage']
    if movie_title not in movies:
        if 'nom_realisateur' in entry['fields']:
            movies[movie_title] = {'title': movie_title,
            'director': entry['fields']['nom_realisateur'],
            'locations': []
        }
        else:
            movies[movie_title] = {'title': movie_title,
                    'director': 'Inconnu',
                    'locations': []
        }
    if 'ardt_lieu' in entry['fields']:
        movies[movie_title]['locations'].append((entry['fields']['ardt_lieu'], 
                                                entry['fields'].get('date_debut', 'Date inconnue'),
                                                entry['fields'].get('date_fin', 'Date inconnue')
        ))
    #movies[movie_title]['locations'].append(( entry['fields']['ardt_lieu'], entry['fields']['date_debut'], entry['fields']['date_fin']))
  
movies = [m for m in movies.values()]

# %% [markdown]
# As predicted many key errors occured due to missing data, and i handled them with simple if statements and the .get() method.

# %%
movies
# Out:
# [{'title': '2 Fils (Nouvelle Demande Décor Librairie / Journées interverties)',
#   'director': 'Félix MOATI',
#   'locations': [('75011', '2017-10-19', '2017-10-19'),
#    ('75011', '2017-10-19', '2017-10-19')]},
#  {'title': 'Vernon Subutex',
#    ('75005', '2019-07-29', '2019-07-29'),
#    ('75004', '2019-07-30', '2019-07-30'),
#    ('75116', '2019-07-30', '2019-07-30')]},
#  {'title': "À l'Abordage",
#   'director': 'Guillaume Brac',
#   'locations': [('75019', '2019-08-05', '2019-08-05'),
#    ('75014', '2019-08-08', '2019-08-09'),
#    ('75014', '2019-08-06', '2019-08-06'),
#    ('75014', '2019-08-06', '2019-08-06')]},
#  {'title': 'Gott du kannst ein Arsch sein',
#   'director': 'Andre Erkau',
#   'locations': [('75018', '2019-10-02', '2019-10-03'),
#    ('75018', '2019-10-02', '2019-10-03'),
#    ('75018', '2019-10-02', '2019-10-02'),
#    ('75005', '2019-10-03', '2019-10-03'),
#    ('75018', '2019-10-02', '2019-10-03'),
#    ('75008', '2019-10-03', '2019-10-04'),
#    ('75015', '2019-10-03', '2019-10-04'),
#    ('75008', '2019-10-03', '2019-10-03')]},
#  {'title': 'MERVEILLES A MONTFERMEIL',
#   'director': 'Jeanne Balibar',
#   'locations': [('75011', '2018-07-10', '2018-07-10'),
#    ('75011', '2018-07-10', '2018-07-10'),
#    ('75011', '2018-07-10', '2018-07-10'),
#    ('75011', '2018-07-10', '2018-07-10')]},
#  {'title': 'La Tour de Nesle',
#   'director': 'Noël HERPE',
#   'locations': [('75011', '2018-11-23', '2018-12-19')]},
#  {'title': 'BALTHAZAR 9,10',
#   'director': 'VINCENT JAMAIN',
#   'locations': [('75015', '2019-04-17', '2019-04-17'),
#    ('75015', '2019-04-17', '2019-04-17')]},
#  {'title': 'ALICE NEVERS E114-115 (Partie 1/3)',
#   'director': 'JEAN-CHRISTOPHE DELPIAS',
#   'locations': [('75004', '2019-10-16', '2019-10-16'),
#    ('75004', '2019-10-16', '2019-10-16'),
#    ('75004', '2019-10-16', '2019-10-16'),
#    ('75007', '2019-10-18', '2019-10-18')]},
#  {'title': 'La Vie Absurde',
#   'director': 'Joachim Delmotte et Matthieu Moerlen',
#   'locations': [('75018', '2018-06-26', '2018-06-26')]},
#  {'title': 'Je Te Promets (Saison 2)',
#   'director': 'Marilou Berry et Renaud Bertrand',
#   'locations': [('75008', '2021-09-10', '2021-09-11'),
#    ('75001', '2021-10-04', '2021-10-04'),
#    ('75008', '2021-09-13', '2021-09-14'),
#    ('75008', '2021-09-13', '2021-09-14'),
#    ('75002', '2021-10-04', '2021-10-05'),
#    ('75008', '2021-09-10', '2021-09-10'),
#    ('75008', '2021-09-13', '2021-09-14')]},
#  {'title': 'ANTI-SQUAT',
#   'director': 'Nicolas SILHOL',
#   'locations': [('75012', '2021-12-08', '2021-12-08'),
#    ('75012', '2021-12-07', '2021-12-07'),
#    ('75020', '2021-12-15', '2021-12-17'),
#    ('75018', '2021-12-09', '2021-12-10')]},
#  {'title': 'APACHE',
#   'director': 'ROMAIN QUIROT',
#   'locations': [('75018', '2021-11-29', '2021-11-29'),
#    ('75116', '2021-11-25', '2021-11-25')]},
#  {'title': "L'Opéra saison 2",
#   'director': 'Stéphane DEMOUSTIER - Cécile DUCROCQ',
#   'locations': [('75009', '2021-12-09', '2021-12-11'),
#    ('75011', '2021-12-14', '2021-12-14'),
#    ('75019', '2021-12-16', '2021-12-18'),
#    ('75012', '2021-12-11', '2021-12-11'),
#    ('75019', '2021-12-16', '2021-12-17')]},
#  {'title': "DANS L'ENFER DES FOYERS",
#   'director': 'Akim Isker',
#   'locations': [('75018', '2020-11-06', '2020-11-06'),
#    ('75009', '2020-11-06', '2020-11-06'),
#    ('75018', '2020-11-20', '2020-11-21')]},
#  {'title': 'LE MONDE DE DEMAIN',
#   'director': 'Katell QUILLEVERE et Hélier CISTERNE',
#   'locations': [('75012', '2021-02-26', '2021-02-26'),
#    ('75013', '2021-03-08', '2021-03-09'),
#    ('75012', '2021-05-28', '2021-05-29'),
#    ('75010', '2021-05-18', '2021-05-19'),
#    ('75013', '2021-03-09', '2021-03-10'),
#    ('75012', '2021-02-26', '2021-02-26'),
#    ('75020', '2021-03-05', '2021-03-05'),
#    ('75019', '2021-05-18', '2021-05-18'),
#    ('75011', '2021-03-02', '2021-03-03'),
#    ('75011', '2021-03-03', '2021-03-03'),
#    ('75019', '2021-05-21', '2021-05-22')]},
#  {'title': "UNE FEMME D'EXCEPTION",
#   'director': 'ERIC GUIRADO',
#   'locations': [('75017', '2016-08-16', '2016-08-16'),
#    ('75017', '2016-08-16', '2016-08-16'),
#    ('75016', '2016-09-07', '2016-09-07'),
#    ('75019', '2016-09-08', '2016-09-08'),
#    ('75019', '2016-09-08', '2016-09-08'),
#    ('75019', '2016-09-08', '2016-09-08'),
#    ('75016', '2016-09-07', '2016-09-07'),
#    ('75020', '2016-09-29', '2016-09-29'),
#    ('75019', '2016-10-05', '2016-10-05'),
#    ('75017', '2016-10-06', '2016-10-06')]},
#  {'title': 'HAWAII',
#   'director': 'Mélissa Drigeard',
#   'locations': [('75009', '2021-08-07', '2021-08-07'),
#    ('75009', '2021-08-07', '2021-08-07')]},
#  {'title': 'LA LICORNE',
#   'director': 'AVRIL BESSON',
#   'locations': [('75018', '2016-11-02', '2016-11-02'),
#    ('75018', '2016-11-02', '2016-11-02'),
#    ('75018', '2016-11-02', '2016-11-02'),
#    ('75018', '2016-11-02', '2016-11-02'),
#    ('75018', '2016-11-02', '2016-11-02')]},
#  {'title': 'LUMIERE AMOUREUSE',
#   'director': 'FRANCHIN DOM',
#   'locations': [('75004', '2016-06-13', '2016-06-13'),
#    ('75009', '2016-06-07', '2016-06-07'),
#    ('75018', '2016-06-14', '2016-06-14'),
#    ('75004', '2016-06-13', '2016-06-13'),
#    ('75018', '2016-06-14', '2016-06-14'),
#    ('75005', '2016-06-07', '2016-06-07'),
#    ('75007', '2016-06-14', '2016-06-14')]},
#  {'title': 'Notre Dame Brûle',
#   'director': 'Jean-Jacques Annaud',
#   'locations': [('75008', '2021-08-18', '2021-08-19'),
#    ('75008', '2021-08-19', '2021-08-19'),
#    ('75008', '2021-08-18', '2021-08-18')]},
#  {'title': 'Les héritiers',
#   'director': 'Jean Marc Brondolo',
#   'locations': [('75008', '2020-12-08', '2020-12-08'),
#    ('75116', '2020-12-08', '2020-12-09'),
#    ('75001', '2020-12-09', '2020-12-10'),
#    ('75007', '2020-12-11', '2020-12-12'),
#    ('75020', '2020-11-20', '2020-11-20'),
#    ('75116', '2020-12-02', '2020-12-03'),
#    ('75001', '2020-12-11', '2020-12-11')]},
#  {'title': 'Joueurs',
#   'director': 'Marie Monge',
#   'locations': [('75002', '2017-11-14', '2017-11-15'),
#    ('75002', '2017-11-08', '2017-11-08'),
#    ('75010', '2017-11-08', '2017-11-08'),
#    ('75002', '2017-11-13', '2017-11-14'),
#    ('75010', '2017-11-07', '2017-11-07'),
#    ('75010', '2017-11-09', '2017-11-09')]},
#  {'title': 'CHRONIQUES PARISIENNES 22',
#   'director': 'ZABOU BREITMAN',
#   'locations': [('75010', '2017-05-19', '2017-05-19')]},
#  {'title': 'ALICE NEVERS episodes 92, 93 saison 14',
#   'director': 'ERIC LE ROUX',
#   'locations': [('75013', '2017-04-15', '2017-04-15'),
#    ('75012', '2017-04-20', '2017-04-20'),
#    ('75008', '2017-04-14', '2017-04-14'),
#    ('75001', '2017-04-24', '2017-04-24')]},
#  {'title': 'CHRONIQUES PARISIENNES 11',
#   'director': 'ZABOU BREITMAN',
#   'locations': [('75007', '2017-03-20', '2017-03-20'),
#    ('75006', '2017-03-20', '2017-03-20'),
#    ('75007', '2017-03-20', '2017-03-20'),
#    ('75015', '2017-03-16', '2017-03-16'),
#    ('75006', '2017-03-20', '2017-03-20')]},
#  {'title': 'Bicycle Revolution',
#   'director': 'Marc-Aurèle Vecchione',
#   'locations': [('75012', '2017-12-21', '2017-12-21'),
#    ('75012', '2017-12-14', '2017-12-14')]},
#  {'title': 'Un tour chez ma fille (UTCMF)',
#   'director': 'Eric Lavaine',
#   'locations': [('75009', '2020-01-06', '2020-01-06'),
#    ('75009', '2020-01-02', '2020-01-02'),
#    ('75009', '2020-01-02', '2020-01-06')]},
#  {'title': 'A PERFECT ENEMY',
#   'director': 'KIKE MAILLO',
#   'locations': [('75020', '2020-01-14', '2020-01-15'),
#    ('75019', '2020-01-13', '2020-01-13'),
#    ('75007', '2020-01-16', '2020-01-16')]},
#  {'title': 'Je te veux, moi non plus',
#   'director': 'Inès Reg, Kevin Debonne',
#   'locations': [('75116', '2020-07-28', '2020-07-28'),
#    ('75001', '2020-07-31', '2020-07-31'),
#    ('75116', '2020-07-28', '2020-07-28'),
#    ('75001', '2020-07-31', '2020-07-31')]},
#  {'title': 'JOSEPHINE ANGE GARDIEN 112/113',
#   'director': 'NICOLAS HERDT',
#   'locations': [('75019', '2020-08-27', '2020-08-28'),
#    ('75018', '2020-09-03', '2020-09-04'),
#    ('75012', '2020-08-25', '2020-08-26'),
#    ('75018', '2020-09-03', '2020-09-03'),
#    ('75009', '2020-08-21', '2020-08-21')]},
#  {'title': 'Ca ne va pas Supermarché',
#   'director': 'Pierre Briois et Théo Galampoix',
#   'locations': [('75014', '2020-08-23', '2020-08-23'),
#    ('75014', '2020-08-23', '2020-08-23'),
#    ('75014', '2020-08-23', '2020-08-23')]},
#  {'title': 'Les Fantasmes',
#   'director': 'David et Stéphane FOENKINOS',
#   'locations': [('75014', '2020-09-08', '2020-09-08'),
#    ('75013', '2020-09-21', '2020-09-22'),
#    ('75013', '2020-09-21', '2020-09-22')]},
#  {'title': 'POURQUOI JE VIS',
#   'director': 'Laurent TUEL',
#   'locations': [('75016', '2020-02-03', '2020-02-03')]},
#  {'title': 'EYE ON JULIET',
#   'director': 'KIM NGUYEN',
#   'locations': [('75006', '2016-07-19', '2016-07-19'),
#    ('75001', '2016-07-19', '2016-07-19'),
#    ('75001', '2016-07-19', '2016-07-19')]},
#  {'title': 'Paye ton crush',
#   'director': 'Camille Landru / Esteban Vial',
#   'locations': [('75018', '2021-05-26', '2021-05-26')]},
#  {'title': 'Vite et Bien',
#   'director': 'Maka Sidibé',
#   'locations': [('75012', '2021-07-18', '2021-07-18'),
#    ('75012', '2021-07-17', '2021-07-17'),
#    ('75012', '2021-07-17', '2021-07-17')]},
#  {'title': 'Murder Mystery 2',
#   'director': 'Jérémy Garelick',
#   'locations': [('75116', '2022-04-01', '2022-04-03'),
#    ('75009', '2022-02-24', '2022-02-27'),
#    ('75116', '2022-03-16', '2022-03-18'),
#    ('75013', '2022-03-22', '2022-03-23'),
#    ('75004', '2022-03-30', '2022-04-02'),
#    ('75009', '2022-02-19', '2022-02-21'),
#    ('75007', '2022-03-08', '2022-03-12'),
#    ('75007', '2022-03-17', '2022-03-21')]},
#  {'title': 'ECHO',
#   'director': 'Olivier Barma',
#   'locations': [('75009', '2022-06-15', '2022-06-17')]},
#  {'title': 'UNE NUIT A',
#   'director': 'Alex Lutz',
#   'locations': [('75116', '2022-06-27', '2022-06-28'),
#    ('75016', '2022-06-29', '2022-06-29'),
#    ('75016', '2022-06-28', '2022-06-29'),
#    ('75116', '2022-07-06', '2022-07-07'),
#    ('75016', '2022-06-28', '2022-06-29')]},
#  {'title': 'La Vie Pour de Vrai',
#   'director': 'Dany Boon',
#   'locations': [('75001', '2022-07-15', '2022-07-15'),
#    ('75011', '2022-07-21', '2022-07-22'),
#    ('75001', '2022-07-15', '2022-07-15'),
#    ('75011', '2022-07-21', '2022-07-22'),
#    ('75116', '2022-08-01', '2022-08-02'),
#    ('75011', '2022-07-25', '2022-07-30'),
#    ('75007', '2022-07-18', '2022-07-18')]},
#  {'title': '66-5',
#   'director': 'Danielle Arbid',
#   'locations': [('75008', '2022-07-15', '2022-07-16'),
#    ('75017', '2022-08-10', '2022-08-11'),
#    ('75014', '2022-07-16', '2022-07-16')]},
#  {'title': 'SPELLBOUND',
#   'director': 'Alexander JACOB - Annie BRADLEY - Robert BURKE',
#   'locations': [('75012', '2022-08-10', '2022-08-10'),
#    ('75001', '2022-08-29', '2022-08-30'),
#    ('75011', '2022-08-10', '2022-08-10'),
#    ('75012', '2022-08-10', '2022-08-10'),
#    ('75011', '2022-08-30', '2022-08-30'),
#    ('75012', '2022-08-30', '2022-09-01'),
#    ('75002', '2022-09-01', '2022-09-02')]},
#  {'title': 'CHASSE GARDÉE',
#   'director': 'FREDERIC FORESTIER, ANTONIN FOURLON',
#   'locations': [('75012', '2022-08-18', '2022-08-20'),
#    ('75018', '2022-08-17', '2022-08-17'),
#    ('75016', '2022-08-20', '2022-08-20'),
#    ('75008', '2022-08-20', '2022-08-20')]},
#  {'title': 'EMILY IN PARIS S3',
#   'director': 'Andrew Felmming, Erin Ehrlich, Katina Medina Mora',
#   'locations': [('75008', '2022-08-24', '2022-08-24')]},
#  {'title': 'La Grande Odalisque',
#   'director': 'Mélanie Laurent',
#   'locations': [('75016', '2022-09-13', '2022-09-13'),
#    ('75116', '2022-10-29', '2022-11-02'),
#    ('75013', '2022-09-12', '2022-09-13')]},
#  {'title': 'JE NE SUIS PAS UN HÉROS',
#   'director': 'Rudy Milstein',
#   'locations': [('75008', '2022-10-04', '2022-10-04'),
#    ('75017', '2022-10-04', '2022-10-04'),
#    ('75010', '2022-10-07', '2022-10-08'),
#    ('75116', '2022-09-28', '2022-09-28'),
#    ('75116', '2022-08-30', '2022-08-30'),
#    ('75010', '2022-10-08', '2022-10-08'),
#    ('75010', '2022-10-07', '2022-10-09')]},
#  {'title': 'La plus grosse caméra du monde',
#   'director': 'Quentin Dupieux',
#   'locations': [('75005', '2022-11-08', '2022-11-08'),
#    ('75116', '2022-11-08', '2022-11-08')]},
#  {'title': 'Les Rois de la piste',
#   'director': 'Thierry Klifa',
#   'locations': [('75014', '2022-11-08', '2022-11-08'),
#    ('75012', '2022-11-10', '2022-11-10')]},
#  {'title': 'PAS DE VAGUE',
#   'director': 'TEDDY LUSSI-MODESTE',
#   'locations': [('75019', '2022-11-10', '2022-11-10'),
#    ('75019', '2022-11-10', '2022-11-10'),
#    ('75019', '2022-11-21', '2022-11-21'),
#    ('75019', '2022-11-10', '2022-11-11')]},
#  {'title': 'Baron noir',
#   'director': 'Antoine Chevrollier - Ziad Doueiri',
#   'locations': [('75007', '2017-09-28', '2017-09-28'),
#    ('75011', '2017-10-14', '2017-10-14'),
#    ('75011', '2017-10-02', '2017-10-02'),
#    ('75116', '2017-09-30', '2017-09-30'),
#    ('75005', '2017-09-28', '2017-09-28'),
#    ('75011', '2017-10-02', '2017-10-02'),
#    ('75012', '2017-10-12', '2017-10-12'),
#    ('75011', '2017-10-14', '2017-10-14'),
#    ('75007', '2017-09-29', '2017-09-29'),
#    ('75007', '2017-10-12', '2017-10-13'),
#    ('75001', '2017-10-02', '2017-10-02'),
#    ('75017', '2017-10-06', '2017-10-06'),
#    ('75007', '2017-10-12', '2017-10-13'),
#    ('75011', '2017-10-02', '2017-10-02')]},
#  {'title': 'NAMASTE ENGLAND',
#   'director': 'Vipul Shah',
#   'locations': [('75010', '2018-05-15', '2018-05-15')]},
#  {'title': 'Les tuche 3',
#   'director': 'Olivier Baroux',
#   'locations': [('75016', '2017-08-05', '2017-08-05'),
#    ('75001', '2017-06-14', '2017-06-14'),
#    ('75007', '2017-08-08', '2017-08-08'),
#    ('75116', '2017-08-07', '2017-08-08'),
#    ('75007', '2017-06-14', '2017-06-14'),
#    ('75008', '2017-08-05', '2017-08-05'),
#    ('75004', '2017-06-14', '2017-06-14'),
#    ('75116', '2017-08-08', '2017-08-08')]},
#  {'title': 'CHRIST(OFF)',
#   'director': 'PIERRE DUDAN',
#   'locations': [('75005', '2017-07-11', '2017-07-11'),
#    ('75005', '2017-07-11', '2017-07-11')]},
#  {'title': 'BK web - Wooper dog',
#   'director': 'Inconnu',
#   'locations': [('75004', '2018-03-09', '2018-03-09')]},
#  {'title': 'Soumission - Le film',
#   'director': 'Titus Selge',
#   'locations': [('75005', '2017-10-09', '2017-10-09'),
#    ('75005', '2017-10-09', '2017-10-09'),
#    ('75009', '2017-10-14', '2017-10-14'),
#    ('75013', '2017-10-10', '2017-10-10'),
#    ('75013', '2017-10-10', '2017-10-10')]},
#  {'title': "J'ACCUSE",
#   'director': 'Roman Polanski',
#   'locations': [('75009', '2019-02-13', '2019-02-15'),
#    ('75009', '2019-02-13', '2019-02-15'),
#    ('75007', '2018-11-26', '2018-11-26'),
#    ('75006', '2019-03-04', '2019-03-04'),
#    ('75007', '2018-11-26', '2018-11-26'),
#    ('75009', '2019-01-31', '2019-02-01'),
#    ('75015', '2019-02-21', '2019-02-22'),
#    ('75015', '2019-02-25', '2019-02-25'),
#    ('75015', '2019-02-26', '2019-02-27'),
#    ('75015', '2019-02-22', '2019-02-22'),
#    ('75001', '2019-01-29', '2019-01-29'),
#    ('75007', '2018-11-26', '2018-11-26'),
#    ('75016', '2019-02-20', '2019-02-21')]},
#  ...]

# %%
len(movies)
# Out:
# 1476

# %% [markdown]
# I asked chat gpt to tell me what to do to display the locations cause as easy as it looks (and actually is) i couldn't figure out how to loop inside the join, i didn't even know it was possible.

# %%
def display_movie(movie):
    return f'"{movie["title"]}", by {movie["director"]}. Shootings: {"; ".join(f"{location[0]} from {location[1]} to {location[2]}" for location in movie["locations"])}'

# %%
all_movie_displays = [display_movie(m) for m in movies]
print('\n'.join(all_movie_displays[:20]))
# Out:
# "2 Fils (Nouvelle Demande Décor Librairie / Journées interverties)", by Félix MOATI. Shootings: 75011 from 2017-10-19 to 2017-10-19; 75011 from 2017-10-19 to 2017-10-19
# "Vernon Subutex", by Cathy Verney. Shootings: 75001 from 2018-04-25 to 2018-04-26; 75019 from 2018-05-22 to 2018-05-22; 75019 from 2018-05-25 to 2018-05-25; 75010 from 2018-05-03 to 2018-05-06; 75011 from 2018-03-19 to 2018-03-19; 75011 from 2018-06-01 to 2018-06-02; 75014 from 2018-06-05 to 2018-06-14; 75014 from 2018-06-13 to 2018-06-13; 75019 from 2018-05-22 to 2018-05-22; 75009 from 2018-04-11 to 2018-04-11; 75007 from 2018-06-13 to 2018-06-15; 75012 from 2018-03-23 to 2018-03-23; 75011 from 2018-04-04 to 2018-04-04; 75016 from 2018-03-30 to 2018-03-30; 75004 from 2018-03-20 to 2018-03-20; 75004 from 2018-04-26 to 2018-04-27; 75012 from 2018-08-28 to 2018-08-30; 75011 from 2018-03-19 to 2018-03-19; 75002 from 2
    if 'ardt_lieu' in m['fields']:
        districts.append(m["fields"]["ardt_lieu"])
districts = set(districts)

stats = {district: 0 for district in districts}
for m in locs: 
    if 'ardt_lieu' in m['fields']:
        stats[m["fields"]["ardt_lieu"]] += 1

# %% [markdown]
# i looked up on google how to use the lambda function to sort dictionaries (i knew from previous data science projets that it was used often for tasks like these): https://www.freecodecamp.org/news/sort-dictionary-by-value-in-python/

# %%
stats = dict(sorted(stats.items(), key=lambda item: item[1], reverse=True))

# %%
stats
# Out:
# {'75018': 1043,
#  '75008': 798,
#  '75010': 749,
#  '75019': 745,
#  '75001': 722,
#  '75004': 670,
#  '75013': 658,
#  '75007': 657,
#  '75009': 642,
#  '75011': 641,
#  '75005': 640,
#  '75016': 614,
#  '75012': 596,
#  '75020': 587,
#  '75006': 471,
#  '75116': 421,
#  '75017': 378,
#  '75015': 363,
#  '75014': 321,
#  '75002': 297,
#  '75003': 236,
#  '93500': 6,
#  '94320': 4,
#  '93200': 1,
#  '92220': 1,
#  '93000': 1,
#  '92170': 1,
#  '93320': 1}

# %% [markdown]
# # Exercice 4 - Analyze CSV

# %% [markdown]
# - Write a Python code retrieves the file of the most loaned titles in libraries in Paris at:

# %%
url = "https://opendata.paris.fr/explore/dataset/les-titres-les-plus-pretes/download/?format=csv&timezone=Europe/Berlin&lang=en&use_labels_for_header=true&csv_separator=%3B"

# %% [markdown]
# As we previously did a requests.get() will get us the csv file aswell

# %%
import requests as s
import pandas as pd 
from io import StringIO

response = s.get(url).text

# %%
response
# Out:
# 'Type de document;Prêts 2022;Titre;Auteur;Nombre de localisations;Nombre de prêt total;Nombre d\'exemplaires\r\nBande dessinée jeunesse;1064;Razzia;Sobral,  Patrick;47;2938;67\r\nBande dessinée jeunesse;1024;Touche pas à mon veau;Guibert,  Emmanuel;45;2296;71\r\nBande dessinée jeunesse;1016;Max et Lili vont chez papy et mamie;Saint-Mars,  Dominique de;50;5554;103\r\nBande dessinée jeunesse;938;Lili veut un petit chat;Saint-Mars,  Dominique de;51;5789;80\r\nBande dessinée jeunesse;921;Max et Lili font du camping;Saint-Mars,  Dominique de;52;5658;83\r\nBande dessinée jeunesse;901;Lili trouve sa maîtresse méchante;Saint-Mars,  Dominique de;40;4694;72\r\nBande dessinée jeunesse;869;J\'irai où tu iras;Lyfoung,  Patricia;51;4707;76\r\nBande dessinée jeunesse;861;Les nerfs à vif;Nob;48;2837;62\r\nBande dessinée jeunesse;839;Je crois que je t\'aime;Lyfoung,  Patricia;52;3878;70\r\nBande dessinée jeunesse;799;Attention tornade;Cazenove,  Christophe;42;2366;56\r\nBande dessinée jeunesse;779;Max et Lili se posent des questions sur Dieu;Saint-Mars,  Dominique de;48;4823;87\r\nBande dessinée jeunesse;776;Game over. 13. Toxic affair;Midam;36;2652;48\r\nBande dessinée jeunesse;774;Les Schtroumpfs et la tempête blanche;Jost,  Alain;44;975;49\r\nBande dessinée jeunesse;760;On a marché sur la lune;Hergé;60;5674;87\r\nBande dessinée jeunesse;748;Astérix chez les Bretons;Goscinny,  René;41;
# We have a csv file in the form of a string, which means we have tabular data where each row of the table is separated by "\r\n" and elements in a row are separated but a semicolon in the case.
# let's print a few lines (a few hundred characters in the whole string)

# %%
print(response[:349])
# Out:
# Type de document;Prêts 2022;Titre;Auteur;Nombre de localisations;Nombre de prêt total;Nombre d'exemplaires
# Bande dessinée jeunesse;1064;Razzia;Sobral,  Patrick;47;2938;67
# Bande dessinée jeunesse;1024;Touche pas à mon veau;Guibert,  Emmanuel;45;2296;71
# Bande dessinée jeunesse;1016;Max et Lili vont chez papy et mamie;Saint-Mars,  Dominique de;50;

# %% [markdown]
# We already have the CSV content stored as a text object in memory. To efficiently process this data, we'll use the StringIO module from the io library, which allows us to treat the text object as if it were an actual file. Once we do this, we can easily load the data into a pandas DataFrame, which is a powerful tool for working with tabular data. This approach uses pandas, a library I'm most comfortable with for handling and analyzing such data.

# %%
with StringIO(response) as csvfile:
    books = pd.read_csv(csvfile, sep=';')
books
# Out:
#             Type de document  Prêts 2022                                Titre  \
# 0    Bande dessinée jeunesse        1064                               Razzia
# 1    Bande dessinée jeunesse        1024                Touche pas à mon veau
# 2    Bande dessinée jeunesse        1016  Max et Lili vont chez papy et mamie
# 3    Bande dessinée jeunesse         938              Lili veut un petit chat
# 4    Bande dessinée jeunesse         921          Max et Lili font du camping
# ..                       ...         ...                                  ...
# 837  Bande dessinée jeunesse         572       Aventure au pays des samouraïs
# 838  Bande dessinée jeunesse         566         Yakari et la tueuse des mers
# 839  Bande dessinée jeunesse         555                           Naruto. 59
# 840  Bande dessinée jeunesse         554                La famille avant tout
# 841           Livre jeunesse         549                         La prophétie
#
#                         Auteur  Nombre de localisations  Nombre de prêt total  \
# 0             Sobral,  Patrick                       47                  2938
# 1           Guibert,  Emmanuel                       45                  2296
# 2    Saint-Mars,  Dominique de                       50                  5554
# 3    Saint-Mars,  Dominique de                       51                  5789
# 4    Saint-Mars,  Dominique de                       52                  5658
# ..                         ...                      ...                   ...
# 837             Oda,  Eiichir?                       48                  1511
# 838                        Job                       43                  3677
# 839        Kishimoto,  Masashi                       44                  2735
# 840           Morel,  Marylise                       39                  2285
# 841         Sutherland,  T. T.                       48                  1799
#
#      Nombre d'exemplaires
# 0                      67
# 1                      71
# 2                     103
# 3                      80
# 4                      83
# ..                    ...
# 837                    54
# 838                    47
# 839                    53
# 840                    44
# 841                    62
#
# [842 rows x 7 columns]

# %% [markdown]
# One of the great features of pandas DataFrames is how easy it is to identify and count missing data. We can achieve this by generating a boolean array using the .isnull() (or .isna()) function, which marks missing values (NaN) as True and present values as False. By applying the .sum() function to this boolean array along the columns (using axis=0), pandas will return the total count of missing values for each column. This gives us a quick and efficient way to see which columns contain missing data and how many values are missing in each.

# %%
print(books.isnull().sum())
# Out:
# Type de document            0
# Prêts 2022                  0
# Titre                       0
# Auteur                     15
# Nombre de localisations     0
# Nombre de prêt total        0
# Nombre d'exemplaires        0
# dtype: int64

# %%
print(f'The percentage of missing values within the "Auteur" column is: {(books.isnull().sum().sum() / len(books)) * 100:.2f}%')
# Out:
# The percentage of missing values within the "Auteur" column is: 1.78%

# %% [markdown]
# The rows with missing data in the 'Auteur' column make up only 1.78% of the total, so removing them wouldn't have a significant impact. However, there are alternatives to dropping rows, such as filling the missing values with statistical measures like the mean or median, depending on the context.

# %%
books = books.dropna(subset=['Auteur'])

# %% [markdown]
# - Analyze the resulting CSV file to display, for all entries: title, author, and total number of loans.

# %% [markdown]
# Let's first of all look at a whole row first :

# %%
books.iloc[0,:]
# Out:
# Type de document           Bande dessinée jeunesse
# Prêts 2022                                    1064
# Titre                                       Razzia
# Auteur                            Sobral,  Patrick
# Nombre de localisations                         47
# Nombre de prêt total                          2938
# Nombre d'exemplaires                            67
# Name: 0, dtype: object

# %% [markdown]
# We want to display the book title, the author(s), and the number of loans, which correspond to the 3rd, 4th, and 6th columns in our dataset. To achieve this, we'll use the .iterrows() method on our DataFrame.
# This method takes a DataFrame (or a portion of a dataframe) and returns an iterator that goes over each row and returns the row index along with the data for that row, thus allowing us to easily access column data within each row using their numerical index positions.

# %%
def disp_book(book):
    return f'"{book[2]}", by {book[3]} ({book[5]} loans)'

# %%
print('\n'.join( [disp_book(row) for  _, row in books.iloc[:20].iterrows()]))
# Out:
# "Razzia", by Sobral,  Patrick (2938 loans)
# "Touche pas à mon veau", by Guibert,  Emmanuel (2296 loans)
# "Max et Lili vont chez papy et mamie", by Saint-Mars,  Dominique de (5554 loans)
# "Lili veut un petit chat", by Saint-Mars,  Dominique de (5789 loans)
# "Max et Lili font du camping", by Saint-Mars,  Dominique de (5658 loans)
# "Lili trouve sa maîtresse méchante", by Saint-Mars,  Dominique de (4694 loans)
# "J'irai où tu iras", by Lyfoung,  Patricia (4707 loans)
# "Les nerfs à vif", by Nob (2837 loans)
# "Je crois que je t'aime", by Lyfoung,  Patricia (3878 loans)
# "Attention tornade", by Cazenove,  Christophe (2366 loans)
# "Max et Lili se posent des questions sur Dieu", by Saint-Mars,  Dominique de (4823 loans)
# "Game over. 13. Toxic affair", by Midam (2652 loans)
# "Les Schtroumpfs et la tempête blanche", by Jost,  Alain (975 loans)
# "On a marché sur la lune", by Hergé (5674 loans)
# "Astérix chez les Bretons", by Goscinny,  René (3014 loans)
# "Parvati", by Ogaki,  Philippe (2616 loans)
# "Les Schtroumpfs et l'arbre d'or", by Culliford,  Thierry (3460 loans)
# "La décision : roman", by Tuil,  Karine (976 loans)
# "Les cahiers d'Esther. 4. Histoires de mes 13 ans", by Sattouf,  Riad (2171 loans)
# "Salut, les zinzins !", by Cohen,  Jacqueline (4565 loans)

# %% [markdown]
# - Display for each type of document (there can be several entries for the same type of document), the total number of loans for this type.

# %% [markdown]
# I decided to make a list of all the different document types, and then use that list in a loop. For each type, I filter the 'Type de document' column to only get the rows that match the current type. Then, I grab the 'Nombre de prêt total' for those rows and sum them up to find the total loans for that type.

# %%
type = list(set(books["Type de document"]))
stats = dict()
for t in type:
    total_loans = books[books["Type de document"] == t]["Nombre de prêt total"].sum()
    stats[t] = total_loans

# %%
stats
# Out:
# {'Bande dessinée jeunesse': 2281634,
#  'Bande dessinée ado': 29819,
#  'Livre jeunesse': 102273,
#  'Bande dessinée adulte': 59726,
#  'Livre sonore jeunesse': 10630,
#  'Musique jeunesse': 4792,
#  'Livre adulte': 41731,
#  'Jeux de société prêtable': 1792}

# %% [markdown]
# - Display titles in order of profitability (in descending order of the number of loans per copy).

# %% [markdown]
# What I understood from this question is that profitability means the number of loans per copy. So, to make things clearer, I created a new column called 'profitability,' which is just the total number of loans ('Nombre de prêts total') divided by the number of copies ('Nombre d'exemplaires'). After that, I sorted the books by this new 'profitability' column in descending order using the sort_values() method.

# %%
books["profitability"] = books["Nombre de prêt total"] / books["Nombre d'exemplaires"]
# Out:
# C:\Users\msii\AppData\Local\Temp\ipykernel_27084\3837385550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books["profitability"] = books["Nombre de prêt total"] / books["Nombre d'exemplaires"]

# %% [markdown]
# The issue here is that i do not have the expected results, even tho i do not see where i did wrong.

# %%
books
# Out:
#             Type de document  Prêts 2022                                Titre  \
# 0    Bande dessinée jeunesse        1064                               Razzia
# 1    Bande dessinée jeunesse        1024                Touche pas à mon veau
# 2    Bande dessinée jeunesse        1016  Max et Lili vont chez papy et mamie
# 3    Bande dessinée jeunesse         938              Lili veut un petit chat
# 4    Bande dessinée jeunesse         921          Max et Lili font du camping
# ..                       ...         ...                                  ...
# 837  Bande dessinée jeunesse         572       Aventure au pays des samouraïs
# 838  Bande dessinée jeunesse         566         Yakari et la tueuse des mers
# 839  Bande dessinée jeunesse         555                           Naruto. 59
# 840  Bande dessinée jeunesse         554                La famille avant tout
# 841           Livre jeunesse         549                         La prophétie
#
#                         Auteur  Nombre de localisations  Nombre de prêt total  \
# 0             Sobral,  Patrick                       47                  2938
# 1           Guibert,  Emmanuel                       45                  2296
# 2    Saint-Mars,  Dominique de                       50                  5554
# 3    Saint-Mars,  Dominique de                       51                  5789
# 4    Saint-Mars,  Dominique de                       52                  5658
# ..                         ...                      ...                   ...
# 837             Oda,  Eiichir?                       48                  1511
# 838                        Job                       43                  3677
# 839        Kishimoto,  Masashi                       44                  2735
# 840           Morel,  Marylise                       39                  2285
# 841         Sutherland,  T. T.                       48                  1799
#
#      Nombre d'exemplaires  profitability
# 0                      67      43.850746
# 1                      71      32.338028
# 2                     103      53.922330
# 3                      80      72.362500
# 4                      83      68.168675
# ..                    ...            ...
# 837                    54      27.981481
# 838                    47      78.234043
# 839                    53      51.603774
# 840                    44      51.931818
# 841                    62      29.016129
#
# [827 rows x 8 columns]

# %%
sorted_books = books.sort_values(by='profitability', ascending=False)

# %%
print('\n'.join( [disp_book(row) for _, row in sorted_books[:20].iterrows()]))
# Out:
# "Un enfant chez les schtroumpfs", by Díaz Vizoso,  Miguel (4504 loans)
# "Mon meilleur ami", by Verron,  Laurent (4662 loans)
# "Les vacances infernales", by Cohen,  Jacqueline (5014 loans)
# "Bande de sauvages !", by Cohen,  Jacqueline (5761 loans)
# "Trop, c'est trop !", by Cohen,  Jacqueline (4504 loans)
# "Les fous du mercredi", by Cohen,  Jacqueline (5169 loans)
# "Ca va chauffer !", by Cohen,  Jacqueline (4071 loans)
# "Ca roule !", by Cohen,  Jacqueline (5763 loans)
# "Salut, les zinzins !", by Cohen,  Jacqueline (4565 loans)
# "Les deux terreurs", by Cohen,  Jacqueline (3999 loans)
# "Subliiiimes !", by Cohen,  Jacqueline (5007 loans)
# "Un copieur sachant copier", by Godi,  Bernard (3481 loans)
# "A l'attaque !", by Cohen,  Jacqueline (4353 loans)
# "Tom-Tom et l'impossible Nana", by Cohen,  Jacqueline (5832 loans)
# "Abracada...boum !", by Cohen,  Jacqueline (4149 loans)
# "Poux, papous et pas papous", by Cohen,  Jacqueline (4466 loans)
# "Ici Radio-casserole", by Cohen,  Jacqueline (3584 loans)
# "Tremblez, carcasses !", by Cohen,  Jacqueline (4275 loans)
# "La menace Schtroumpf", by Parthoens,  Luc (3834 loans)
# "La salsa des saucisses", by Cohen,  Jacqueline (4511 loans)

# %% [markdown]
# # Exercice 5 * - Analyze HTML

# %% [markdown]
# - Write a Python program that gets the content of the Wikipedia page at:

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density"

# %% [markdown]
# It goes the same way as the previous exercices, we'll use the requests library and the get method to access the content of a web page via it's URL.
# HTML web pages much like XML file, the print function gives us a structured view of the page since the requests function retrieves the raw data.

# %%
page = s.get(url)
print(page.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of countries and dependencies by population density - Wikipedia</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"71dba243-3383-48ee-b4c1-43ebd369e799","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_and_dependencies_by_population_density","wgTitle":"List of countries and dependencies by population density","wgCurRevisionId":1251741146,"wgRevisionId":1251741146,"wgArticleId":79370,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with Italian-language sources (it)","CS1 Italian-language sources (it)","CS1 maint: url-status","CS1 Spanish-language sources (es)","Articles with short description","Short description is different from Wikidata","Lists of countries by population density"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":
# "List_of_countries_and_dependencies_by_population_density","wgRelevantArticleId":79370,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":50000,"wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q176310","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness"
# ,"brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.js",
# "ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.quicksurveys.init","ext.growthExperiments.SuggestedEditSession","wikibase.sidebar.tracking"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022">
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta name="ResourceLoaderDynamicStyles" content="">
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022">
# <meta name="generator" content="MediaWiki 1.43.0-wmf.27">
# <meta name="referrer" content="origin">
# <meta name="referrer" content="origin-when-cross-origin">
# <meta name="robots" content="max-image-preview:standard">
# <meta name="format-detection" content="telephone=no">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/1200px-Population_density_map_of_the_world.svg.png">
# <meta property="og:image:width" content="1200">
# <meta property="og:image:height" content="847">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/800px-Population_density_map_of_the_world.svg.png">
# <meta property="og:image:width" content="800">
# <meta property="og:image:height" content="565">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/640px-Population_density_map_of_the_world.svg.png">
# <meta property="og:image:width" content="640">
# <meta property="og:image:height" content="452">
# <meta name="viewport" content="width=1120">
# <meta property="og:title" content="List of countries and dependencies by population density - Wikipedia">
# <meta property="og:type" content="website">
# <link rel="preconnect" href="//upload.wikimedia.org">
# <link rel="alternate" media="only screen and (max-width: 640px)" href="//en.m.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density">
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=edit">
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">
# <link rel="icon" href="/static/favicon/wikipedia.ico">
# <link rel="search" type="application/opensearchdescription+xml" href="/w/rest.php/v1/search" title="Wikipedia (en)">
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd">
# <link rel="canonical" href="https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density">
# <link rel="license" href="https://creativecommons.org/licenses/by-sa/4.0/deed.en">
# <link rel="alternate" type="application/atom+xml" title="Wikipedia Atom feed" href="/w/index.php?title=Special:RecentChanges&amp;feed=atom">
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <link rel="dns-prefetch" href="//login.wikimedia.org">
# </head>
# <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_countries_and_dependencies_by_population_density rootpage-List_of_countries_and_dependencies_by_population_density skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# 	<header class="vector-header mw-header">
# 		<div class="vector-header-start">
# 			<nav class="vector-main-menu-landmark" aria-label="Site">
#
# <div id="vector-main-menu-dropdown" class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right"  >
# 	<input type="checkbox" id="vector-main-menu-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-main-menu-dropdown" class="vector-dropdown-checkbox "  aria-label="Main menu"  >
# 	<label id="vector-main-menu-dropdown-label" for="vector-main-menu-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
#
# <span class="vector-dropdown-label-text">Main menu</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 				<div id="vector-main-menu-unpinned-container" class="vector-unpinned-container">
#
# <div id="vector-main-menu" class="vector-main-menu vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned"
# 	data-feature-name="main-menu-pinned"
# 	data-pinnable-element-id="vector-main-menu"
# 	data-pinned-container-id="vector-main-menu-pinned-container"
# 	data-unpinned-container-id="vector-main-menu-unpinned-container"
# >
# 	<div class="vector-pinnable-header-label">Main menu</div>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">hide</button>
# </div>
#
#
# <div id="p-navigation" class="vector-menu mw-portlet mw-portlet-navigation"  >
# 	<div class="vector-menu-heading">
# 		Navigation
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="n-mainpage-description" class="mw-list-item"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z"><span>Main page</span></a></li><li id="n-contents" class="mw-list-item"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li id="n-currentevents" class="mw-list-item"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li id="n-randompage" class="mw-list-item"><a href="/wiki/Special:Random" title="Visit a randomly selected article [x]" accesskey="x"><span>Random article</span></a></li><li id="n-aboutsite" class="mw-list-item"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li id="n-contactpage" class="mw-list-item"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
#
# <div id="p-interaction" class="vector-menu mw-portlet mw-portlet-interaction"  >
# 	<div class="vector-menu-heading">
# 		Contribute
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="n-help" class="mw-list-item"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li id="n-introduction" class="mw-list-item"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li id="n-portal" class="mw-list-item"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li id="n-recentchanges" class="mw-list-item"><a href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]" accesskey="r"><span>Recent changes</span></a></li><li id="n-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# </div>
#
# 				</div>
#
# 	</div>
# </div>
#
# 		</nav>
#
# <a href="/wiki/Main_Page" class="mw-logo">
# 	<img class="mw-logo-icon" src="/static/images/icons/wikipedia.png" alt="" aria-hidden="true" height="50" width="50">
# 	<span class="mw-logo-container skin-invert">
# 		<img class="mw-logo-wordmark" alt="Wikipedia" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;">
# 		<img class="mw-logo-tagline" alt="The Free Encyclopedia" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" width="117" height="13" style="width: 7.3125em; height: 0.8125em;">
# 	</span>
# </a>
#
# 		</div>
# 		<div class="vector-header-end">
#
# <div id="p-search" role="search" class="vector-search-box-vue  vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box">
# 	<a href="/wiki/Special:Search" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" title="Search Wikipedia [f]" accesskey="f"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
#
# <span>Search</span>
# 	</a>
# 	<div class="vector-typeahead-search-container">
# 		<div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# 			<form action="/w/index.php" id="searchform" class="cdx-search-input cdx-search-input--has-end-button">
# 				<div id="simpleSearch" class="cdx-search-input__input-wrapper"  data-search-loc="header-moved">
# 					<div class="cdx-text-input cdx-text-input--has-start-icon">
# 						<input
# 							class="cdx-text-input__input"
# 							 type="search" name="search" placeholder="Search Wikipedia" aria-label="Search Wikipedia" autocapitalize="sentences" title="Search Wikipedia [f]" accesskey="f" id="searchInput"
# 							>
# 						<span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# 					</div>
# 					<input type="hidden" name="title" value="Special:Search">
# 				</div>
# 				<button class="cdx-button cdx-search-input__end-button">Search</button>
# 			</form>
# 		</div>
# 	</div>
# </div>
#
# 			<nav class="vector-user-links vector-user-links-wide" aria-label="Personal tools">
# 	<div class="vector-user-links-main">
#
# <div id="p-vector-user-menu-preferences" class="vector-menu mw-portlet emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-vector-user-menu-userpage" class="vector-menu mw-portlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
# 			<li id="ca-sitesupport" class="mw-list-item user-links-collapsible-item"><a data-mw="interface" href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation" class=""><span>Donate</span></a>
# </li>
#
#
# 		</ul>
#
# 	</div>
# </div>
#
# 	<nav class="vector-appearance-landmark" aria-label="Appearance">
#
# <div id="vector-appearance-dropdown" class="vector-dropdown "  title="Change the appearance of the page&#039;s font size, width, and color" >
# 	<input type="checkbox" id="vector-appearance-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-appearance-dropdown" class="vector-dropdown-checkbox "  aria-label="Appearance"  >
# 	<label id="vector-appearance-dropdown-label" for="vector-appearance-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-appearance mw-ui-icon-wikimedia-appearance"></span>
#
# <span class="vector-dropdown-label-text">Appearance</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 			<div id="vector-appearance-unpinned-container" class="vector-unpinned-container">
#
# 			</div>
#
# 	</div>
# </div>
#
# 	</nav>
#
# <div id="p-vector-user-menu-notifications" class="vector-menu mw-portlet emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-vector-user-menu-overflow" class="vector-menu mw-portlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
# 			<li id="pt-createaccount-2" class="user-links-collapsible-item mw-list-item user-links-collapsible-item"><a data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+countries+and+dependencies+by+population+density" title="You are encouraged to create an account and log in; however, it is not mandatory" class=""><span>Create account</span></a>
# </li>
# <li id="pt-login-2" class="user-links-collapsible-item mw-list-item user-links-collapsible-item"><a data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+countries+and+dependencies+by+population+density" title="You&#039;re encouraged to log in; however, it&#039;s not mandatory. [o]" accesskey="o" class=""><span>Log in</span></a>
# </li>
#
#
# 		</ul>
#
# 	</div>
# </div>
#
# 	</div>
#
# <div id="vector-user-links-dropdown" class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out"  title="Log in and more options" >
# 	<input type="checkbox" id="vector-user-links-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-user-links-dropdown" class="vector-dropdown-checkbox "  aria-label="Personal tools"  >
# 	<label id="vector-user-links-dropdown-label" for="vector-user-links-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
#
# <span class="vector-dropdown-label-text">Personal tools</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
#
# <div id="p-personal" class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item"  title="User menu" >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="pt-createaccount" class="user-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+countries+and+dependencies+by+population+density" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a></li><li id="pt-login" class="user-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+countries+and+dependencies+by+population+density" title="You&#039;re encouraged to log in; however, it&#039;s not mandatory. [o]" accesskey="o"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-user-menu-anon-editor" class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor"  >
# 	<div class="vector-menu-heading">
# 		Pages for logged out editors <a href="/wiki/Help:Introduction" aria-label="Learn more about editing"><span>learn more</span></a>
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="pt-anoncontribs" class="mw-list-item"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y"><span>Contributions</span></a></li><li id="pt-anontalk" class="mw-list-item"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n"><span>Talk</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
# 	</div>
# </div>
#
# </nav>
#
# 		</div>
# 	</header>
# </div>
# <div class="mw-page-container">
# 	<div class="mw-page-container-inner">
# 		<div class="vector-sitenotice-container">
# 			<div id="siteNotice"><!-- CentralNotice --></div>
# 		</div>
# 		<div class="vector-column-start">
# 			<div class="vector-main-menu-container">
# 		<div id="mw-navigation">
# 			<nav id="mw-panel" class="vector-main-menu-landmark" aria-label="Site">
# 				<div id="vector-main-menu-pinned-container" class="vector-pinned-container">
#
# 				</div>
# 		</nav>
# 		</div>
# 	</div>
# 	<div class="vector-sticky-pinned-container">
# 				<nav id="mw-panel-toc" aria-label="Contents" data-event-name="ui.sidebar-toc" class="mw-table-of-contents-container vector-toc-landmark">
# 					<div id="vector-toc-pinned-container" class="vector-pinned-container">
# 					<div id="vector-toc" class="vector-toc vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned"
# 	data-feature-name="toc-pinned"
# 	data-pinnable-element-id="vector-toc"
#
#
# >
# 	<h2 class="vector-pinnable-header-label">Contents</h2>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
#
#
# 	<ul class="vector-toc-contents" id="mw-panel-toc-list">
# 		<li id="toc-mw-content-text"
# 			class="vector-toc-list-item vector-toc-level-1">
# 			<a href="#" class="vector-toc-link">
# 				<div class="vector-toc-text">(Top)</div>
# 			</a>
# 		</li>
# 		<li id="toc-List"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#List">
# 			<div class="vector-toc-text">
# 				<span class="vector-toc-numb">1</span>
# 				<span>List</span>
# 			</div>
# 		</a>
#
# 		<ul id="toc-List-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-See_also"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#See_also">
# 			<div class="vector-toc-text">
# 				<span class="vector-toc-numb">2</span>
# 				<span>See also</span>
# 			</div>
# 		</a>
#
# 		<ul id="toc-See_also-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-Notes"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#Notes">
# 			<div class="vector-toc-text">
# 				<span class="vector-toc-numb">3</span>
# 				<span>Notes</span>
# 			</div>
# 		</a>
#
# 		<ul id="toc-Notes-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-References"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#References">
# 			<div class="vector-toc-text">
# 				<span class="vector-toc-numb">4</span>
# 				<span>References</span>
# 			</div>
# 		</a>
#
# 		<ul id="toc-References-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# </ul>
# </div>
#
# 					</div>
# 		</nav>
# 			</div>
# 		</div>
# 		<div class="mw-content-container">
# 			<main id="content" class="mw-body">
# 				<header class="mw-body-header vector-page-titlebar">
# 					<nav aria-label="Contents" class="vector-toc-landmark">
#
# <div id="vector-page-titlebar-toc" class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left"  >
# 	<input type="checkbox" id="vector-page-titlebar-toc-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-page-titlebar-toc" class="vector-dropdown-checkbox "  aria-label="Toggle the table of contents"  >
# 	<label id="vector-page-titlebar-toc-label" for="vector-page-titlebar-toc-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
#
# <span class="vector-dropdown-label-text">Toggle the table of contents</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 							<div id="vector-page-titlebar-toc-unpinned-container" class="vector-unpinned-container">
# 			</div>
#
# 	</div>
# </div>
#
# 					</nav>
# 					<h1 id="firstHeading" class="firstHeading mw-first-heading"><span class="mw-page-title-main">List of countries and dependencies by population density</span></h1>
#
# <div id="p-lang-btn" class="vector-dropdown mw-portlet mw-portlet-lang"  >
# 	<input type="checkbox" id="p-lang-btn-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-p-lang-btn" class="vector-dropdown-checkbox mw-interlanguage-selector" aria-label="Go to an article in another language. Available in 74 languages"   >
# 	<label id="p-lang-btn-label" for="p-lang-btn-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-74" aria-hidden="true"  ><span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
#
# <span class="vector-dropdown-label-text">74 languages</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
# 		<div class="vector-menu-content">
#
# 			<ul class="vector-menu-content-list">
#
# 				<li class="interlanguage-link interwiki-af mw-list-item"><a href="https://af.wikipedia.org/wiki/Lys_van_lande_volgens_bevolkingsdigtheid" title="Lys van lande volgens bevolkingsdigtheid – Afrikaans" lang="af" hreflang="af" data-title="Lys van lande volgens bevolkingsdigtheid" data-language-autonym="Afrikaans" data-language-local-name="Afrikaans" class="interlanguage-link-target"><span>Afrikaans</span></a></li><li class="interlanguage-link interwiki-als mw-list-item"><a href="https://als.wikipedia.org/wiki/Liste_unabh%C3%A4ngiger_Staaten_nach_Bev%C3%B6lkerungsdichte" title="Liste unabhängiger Staaten nach Bevölkerungsdichte – Alemannic" lang="gsw" hreflang="gsw" data-title="Liste unabhängiger Staaten nach Bevölkerungsdichte" data-language-autonym="Alemannisch" data-language-local-name="Alemannic" class="interlanguage-link-target"><span>Alemannisch</span></a></li><li class="interlanguage-link interwiki-ar mw-list-item"><a href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A7%D9%84%D8%A8%D9%84%D8%AF%D8%A7%D9%86_%D9%88%D8%A7%D9%84%D8%AA%D8%A8%D8%B9%D9%8A%D8%A7%D8%AA_%D8%AD%D8%B3%D8%A8_%D8%A7%D9%84%D9%83%D8%AB%D8%A7%D9%81%D8%A9_%D8%A7%D9%84%D8%B3%D9%83%D8%A7%D9%86%D9%8A%D8%A9" title="قائمة البلدان والتبعيات حسب الكثافة السكانية – Arabic" lang="ar" hreflang="ar" data-title="قائمة البلدان والتبعيات حسب الكثافة السكانية" data-language-autonym="العربية" data-language-local-name="Arabic" class="interlanguage-link-target"><span>العربية</span></a></li><li class="interlanguage-link interwiki-az mw-list-item"><a href="https://az.wikipedia.org/wiki/%C6%8Fhali_s%C4%B1xl%C4%B1%C4%9F%C4%B1na_g%C3%B6r%C9%99_%C3%B6lk%C9%99l%C9%99rin_siyah%C4%B1s%C4%B1" title="Əh
class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q176310#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>
# 		</div>
#
# 	</div>
# </div>
# </header>
# 				<div class="vector-page-toolbar">
# 					<div class="vector-page-toolbar-container">
# 						<div id="left-navigation">
# 							<nav aria-label="Namespaces">
#
# <div id="p-associated-pages" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-nstab-main" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/List_of_countries_and_dependencies_by_population_density" title="View the content page [c]" accesskey="c"><span>Article</span></a></li><li id="ca-talk" class="vector-tab-noicon mw-list-item"><a href="/wiki/Talk:List_of_countries_and_dependencies_by_population_density" rel="discussion" title="Discuss improvements to the content page [t]" accesskey="t"><span>Talk</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="vector-variants-dropdown" class="vector-dropdown emptyPortlet"  >
# 	<input type="checkbox" id="vector-variants-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-variants-dropdown" class="vector-dropdown-checkbox " aria-label="Change language variant"   >
# 	<label id="vector-variants-dropdown-label" for="vector-variants-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" aria-hidden="true"  ><span class="vector-dropdown-label-text">English</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
#
# <div id="p-variants" class="vector-menu mw-portlet mw-portlet-variants emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# 	</div>
# </div>
#
# 							</nav>
# 						</div>
# 						<div id="right-navigation" class="vector-collapsible">
# 							<nav aria-label="Views">
#
# <div id="p-views" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-view" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/List_of_countries_and_dependencies_by_population_density"><span>Read</span></a></li><li id="ca-edit" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=edit" title="Edit this page [e]" accesskey="e"><span>Edit</span></a></li><li id="ca-history" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=history" title="Past revisions of this page [h]" accesskey="h"><span>View history</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# 							</nav>
#
# 							<nav class="vector-page-tools-landmark" aria-label="Page tools">
#
# <div id="vector-page-tools-dropdown" class="vector-dropdown vector-page-tools-dropdown"  >
# 	<input type="checkbox" id="vector-page-tools-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-page-tools-dropdown" class="vector-dropdown-checkbox "  aria-label="Tools"  >
# 	<label id="vector-page-tools-dropdown-label" for="vector-page-tools-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" aria-hidden="true"  ><span class="vector-dropdown-label-text">Tools</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 									<div id="vector-page-tools-unpinned-container" class="vector-unpinned-container">
#
# <div id="vector-page-tools" class="vector-page-tools vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned"
# 	data-feature-name="page-tools-pinned"
# 	data-pinnable-element-id="vector-page-tools"
# 	data-pinned-container-id="vector-page-tools-pinned-container"
# 	data-unpinned-container-id="vector-page-tools-unpinned-container"
# >
# 	<div class="vector-pinnable-header-label">Tools</div>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">hide</button>
# </div>
#
#
# <div id="p-cactions" class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items"  title="More options" >
# 	<div class="vector-menu-heading">
# 		Actions
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-more-view" class="selected vector-more-collapsible-item mw-list-item"><a href="/wiki/List_of_countries_and_dependencies_by_population_density"><span>Read</span></a></li><li id="ca-more-edit" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=edit" title="Edit this page [e]" accesskey="e"><span>Edit</span></a></li><li id="ca-more-history" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=history"><span>View history</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-tb" class="vector-menu mw-portlet mw-portlet-tb"  >
# 	<div class="vector-menu-heading">
# 		General
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="t-whatlinkshere" class="mw-list-item"><a href="/wiki/Special:WhatLinksHere/List_of_countries_and_dependencies_by_population_density" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j"><span>What links here</span></a></li><li id="t-recentchangeslinked" class="mw-list-item"><a href="/wiki/Special:RecentChangesLinked/List_of_countries_and_dependencies_by_population_density" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k"><span>Related changes</span></a></li><li id="t-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u"><span>Upload file</span></a></li><li id="t-specialpages" class="mw-list-item"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q"><span>Special pages</span></a></li><li id="t-permalink" class="mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;oldid=1251741146" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li id="t-info" class="mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li id="t-cite" class="mw-list-item"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_countries_and_dependencies_by_population_density&amp;id=1251741146&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li id="t-urlshortener" class="mw-list-item"><a href="/w/index.php?title=Special:UrlShortener&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_countries_and_dependencies_by_population_density"><span>Get shortened URL</span></a></li><li id="t-urlshortener-qrcode" class="mw-list-item"><a href="/w/index.php?title=Special:QrCode&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_countries_and_dependencies_by_population_density"><span>Download QR code</span></a></li><li id="t-wikibase" class="mw-list-item"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q176310" title="Structured data on this page hosted by Wikidata [g]" accesskey="g"><span>Wikidata item</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-coll-print_export" class="vector-menu mw-portlet mw-portlet-coll-print_export"  >
# 	<div class="vector-menu-heading">
# 		Print/export
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="coll-download-as-rl" class="mw-list-item"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_countries_and_dependencies_by_population_density&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li id="t-print" class="mw-list-item"><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;printable=yes" title="Printable version of this page [p]" accesskey="p"><span>Printable version</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-wikibase-otherprojects" class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects emptyPortlet"  >
# 	<div class="vector-menu-heading">
# 		In other projects
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
# </div>
#
# 									</div>
#
# 	</div>
# </div>
#
# 							</nav>
# 						</div>
# 					</div>
# 				</div>
# 				<div class="vector-column-end">
# 					<div class="vector-sticky-pinned-container">
# 						<nav class="vector-page-tools-landmark" aria-label="Page tools">
# 							<div id="vector-page-tools-pinned-container" class="vector-pinned-container">
#
# 							</div>
# 		</nav>
# 						<nav class="vector-appearance-landmark" aria-label="Appearance">
# 							<div id="vector-appearance-pinned-container" class="vector-pinned-container">
# 				<div id="vector-appearance" class="vector-appearance vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-appearance-pinnable-header vector-pinnable-header-pinned"
# 	data-feature-name="appearance-pinned"
# 	data-pinnable-element-id="vector-appearance"
# 	data-pinned-container-id="vector-appearance-pinned-container"
# 	data-unpinned-container-id="vector-appearance-unpinned-container"
# >
# 	<div class="vector-pinnable-header-label">Appearance</div>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-appearance.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-appearance.unpin">hide</button>
# </div>
#
#
# </div>
#
# 							</div>
# 		</nav>
# 					</div>
# 				</div>
# 				<div id="bodyContent" class="vector-body" aria-labelledby="firstHeading" data-mw-ve-target-container>
# 					<div class="vector-body-before-content">
# 							<div class="mw-indicators">
# 		</div>
#
# 						<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>
# 					</div>
# 					<div id="contentSub"><div id="mw-content-subtitle"></div></div>
#
#
# 					<div id="mw-content-text" class="mw-body-content"><div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr"><p class="mw-empty-elt">
# </p>
# <figure typeof="mw:File/Thumb"><a href="/wiki/File:Population_density_map_of_the_world.svg" class="mw-file-description"><img src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/350px-Population_density_map_of_the_world.svg.png" decoding="async" width="350" height="247" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/525px-Population_density_map_of_the_world.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Population_density_map_of_the_world.svg/700px-Population_density_map_of_the_world.svg.png 2x" data-file-width="850" data-file-height="600" /></a><figcaption> <a href="/wiki/Population_density" title="Population density">Population density</a> (people per km<sup>2</sup>) by country</figcaption></figure>
# <p>This is a <b>list of countries and dependencies ranked by population density</b>, sorted by inhabitants per <a href="/wiki/Square_kilometre" title="Square kilometre">square kilometre</a> or <a href="/wiki/Square_mile" title="Square mile">square mile</a>. The list includes <a href="/wiki/Sovereign_state" title="Sovereign state">sovereign states</a> and self-governing <a href="/wiki/Dependent_territory" title="Dependent territory">dependent territories</a> based upon the <a href="/wiki/International_Organization_for_Standardization" title="International Organization for Standardization">ISO</a> standard <a href="/wiki/ISO_3166-1" title="ISO 3166-1">ISO 3166-1</a>. The list also includes <a href="/wiki/List_of_states_with_limited_recognition" title="List of states with limited recognition">unrecognized</a> but <i><a href="/wiki/De_facto" title="De facto">de facto</a></i> independent countries. The figures in the table are based on areas including internal bodies of water such as bays, lakes, reservoirs and rivers. The list does not include entities not on <a href="/wiki/ISO_3166-1" title="ISO 3166-1">ISO 3166-1</a>, except for <a href="/wiki/List_of_states_with_limited_recognition" title="List of states with limited recognition">states with limited recognition</a>. Thus constituent countries that are not included on <a href="/wiki/ISO_3166-1" title="ISO 3166-1">ISO 3166-1</a>, and other entities not on <a href="/wiki/ISO_3166-1" title="ISO 3166-1">ISO 3166-1</a> like the <a href="/wiki/European_Union" title="European Union">European Union</a>, are not included.
# </p><p>Unless otherwise noted, areas and populations are sourced from the <a href="/wiki/United_Nations" title="United Nations">United Nations</a> World Population Prospects, which uses the latest censuses and official figures, as well as figures from the <a href="/wiki/United_Nations_Department_of_Economic_and_Social_Affairs" title="United Nations Department of Economic and Social Affairs">United Nations Department of Economic and Social Affairs</a>. Data is current as of 2023.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3"><span class="cite-bracket">&#91;</span>a<span class="cite-bracket">&#93;</span></a></sup>
# </p>
# <meta property="mw:PageProp/toc" />
# <div class="mw-heading mw-heading2"><h2 id="List">List</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;action=edit&amp;section=1" title="Edit section: List"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>
# <ul><li>Links for each location go to the relevant <a href="/wiki/Demography" title="Demography">demography</a> page, when available.</li>
# <li><a href="/wiki/Dependent_territory" title="Dependent territory">Dependencies</a> are shown with their parent states in parentheses.</li></ul>
# ...
# <li><a href="/wiki/International_Innovation_Index" title="International Innovation Index">International Innovation Index</a></li>
# <li><a href="/wiki/List_of_countries_by_literacy_rate" title="List of countries by literacy rate">Literacy rate</a></li>
# <li><a href="/wiki/Programme_for_the_International_Assessment_of_Adult_Competencies" title="Programme for the International Assessment of Adult Competencies">Programme for the International Assessment of Adult Competencies</a></li>
# <li><a href="/wiki/Programme_for_International_Student_Assessment" title="Programme for International Student Assessment">Programme for International Student Assessment</a> (PISA)</li>
# <li><a href="/wiki/Progress_in_International_Reading_Literacy_Study" title="Progress in International Reading Literacy Study">Progress in International Reading Literacy Study</a> (PIRLS)</li>
# <li><a href="/wiki/Trends_in_International_Mathematics_and_Science_Study" title="Trends in International Mathematics and Science Study">Trends in International Mathematics and Science Study</a> (TIMSS)</li>
# <li><a href="/wiki/List_of_countries_by_tertiary_education_attainment" title="List of countries by tertiary education attainment">Tertiary education attainment</a></li>
# <li><a href="/wiki/World_Intellectual_Property_Indicators" title="World Intellectual Property Indicators">World Intellectual Property Indicators</a></li></ul>
# </div></td></tr><tr><th scope="row" class="navbox-group" style="width:1%"><a href="/wiki/Demographic_economics" title="Demographic economics">Economic</a></th><td class="navbox-list-with-group navbox-list navbox-even" style="width:100%;padding:0"><div style="padding:0 0.25em">
# <ul><li><a href="/wiki/List_of_countries_by_share_of_population_with_access_to_financial_services" title="List of countries by share of population with access to financial services">Access to financial services</a></li>
# <li><a href="/wiki/List_of_development_aid_sovereign_state_donors" title="List of development aid sovereign state donors">Development aid donors</a>
# <ul><li><a href="/wiki/List_of_sovereign_states_by_Official_Development_Assistance_received" title="List of sovereign states by Official Development Assistance received">Official Development Assistance received</a></li></ul></li>
# <li><a href="/wiki/List_of_countries_by_employment_rate" class="mw-redirect" title="List of countries by employment rate">Employment rate</a></li>
# <li><a href="/wiki/List_of_countries_by_irrigated_land_area" title="List of countries by irrigated land area">Irrigated land area</a></li>
# <li><a href="/wiki/Human_Development_Index" title="Human Development Index">Human Development Index</a>
# <ul><li><a href="/wiki/List_of_countries_by_Human_Development_Index" title="List of countries by Human Development Index">by country</a></li>
# <li><a href="/wiki/List_of_countries_by_inequality-adjusted_Human_Development_Index" title="List of countries by inequality-adjusted Human Development Index">inequality-adjusted</a></li>
# <li><a href="/wiki/List_of_countries_by_planetary_pressures%E2%80%93adjusted_Human_Development_Index" title="List of countries by planetary pressures–adjusted Human Development Index">planetary pressures–adjusted HDI</a></li></ul></li>
# <li><a href="/wiki/Human_Poverty_Index" title="Human Poverty Index">Human Poverty Index</a></li>
# <li><a href="/wiki/List_of_countries_by_imports" title="List of countries by imports">Imports</a></li>
# <li><a href="/wiki/List_of_countries_by_exports" title="List of countries by exports">Exports</a></li>
# <li><a href="/wiki/List_of_countries_by_income_equality" title="List of countries by income equality">Income equality</a></li>
# <li><a href="/wiki/List_of_countries_by_labour_force" title="List of countries by labour force">Labour force</a></li>
# <li><a href="/wiki/List_of_countries_by_share_of_income_of_the_richest_one_percent" title="List of countries by share of income of the richest one percent">Share of income of top 1%</a></li>
# <li><a href="/wiki/List_of_countries_by_number_of_millionaires" title="List of countries by number of millionaires">Number of millionaires (US dollars)</a></li>
# <li><a href="/wiki/List_of_countries_by_number_of_billionaires" title="List of countries by number of billionaires">Number of billionaires (US dollars)</a></li>
# <li><a href="/wiki/List_of_countries_by_percentage_of_population_living_in_poverty" title="List of countries by percentage of population living in poverty">Percentage living in poverty</a></li>
# <li><a href="/wiki/List_of_countries_by_public_sector_size" title="List of countries by public sector size">Public sector</a></li>
# <li><a href="/wiki/List_of_countries_by_unemployment_rate" title="List of countries by unemployment rate">Unemployment rate</a></li>
# <li><a href="/wiki/List_of_countries_by_wealth_inequality" class="mw-redirect" title="List of countries by wealth inequality">Wealth inequality</a></li></ul>
# </div></td></tr><tr><td class="navbox-abovebelow" colspan="2"><div><div class="hlist" style="text-align:center">
# <ul><li><a href="/wiki/List_of_international_rankings" title="List of international rankings">List of international rankings</a></li>
# <li><a href="/wiki/Lists_by_country" title="Lists by country">Lists by country</a></li></ul>
# </div></div></td></tr></tbody></table></div>
# <!--
# NewPP limit report
# Parsed by mw‐web.eqiad.main‐685877499b‐4rjgh
# Cached time: 20241018023513
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 2.263 seconds
# Real time usage: 3.085 seconds
# Preprocessor visited node count: 13525/1000000
# Post‐expand include size: 294544/2097152 bytes
# Template argument size: 3929/2097152 bytes
# Highest expansion depth: 9/100
# Expensive parser function count: 249/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 137000/5000000 bytes
# Lua time usage: 1.197/10.000 seconds
# Lua memory usage: 22068317/52428800 bytes
# Lua Profile:
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::expandTemplate      380 ms       30.6%
#     recursiveClone <mwInit.lua:45>                                   200 ms       16.1%
#     ?                                                                100 ms        8.1%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::callParserFunction       80 ms        6.5%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::getExpensiveData       80 ms        6.5%
#     gettable <Module:CountryData:20>                                  60 ms        4.8%
#     MediaWiki\Extension\Scribunto\Engines\LuaSandbox\LuaSandboxCallback::getExpandedArgument       60 ms        4.8%
#     type                                                              40 ms        3.2%
#     lookup <Module:Convert:687>                                       40 ms        3.2%
#     collection <Module:Convert:209>                                   40 ms        3.2%
#     [others]                                                         160 ms       12.9%
# Number of Wikibase entities loaded: 0/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00% 2553.788      1 -total
#  44.54% 1137.508    249 Template:Flagg
#  16.20%  413.694    504 Template:Convert
#   8.32%  212.509      2 Template:Reflist
#   6.92%  176.700      1 Template:Sort_under
#   6.83%  174.467     26 Template:Cite_web
#   4.91%  125.492      8 Template:Efn
#   4.64%  118.470      1 Template:Short_description
#   3.87%   98.711      1 Template:In_lang
#   3.37%   86.158      1 Template:Population_country_lists
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:79370-0!canonical and timestamp 20241018023513 and revision id 1251741146. Rendering was triggered because: page-view
#  -->
# </div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" width="1" height="1" style="border: none; position: absolute;"></noscript>
# <div class="printfooter" data-nosnippet="">Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;oldid=1251741146">https://en.wikipedia.org/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;oldid=1251741146</a>"</div></div>
# 					<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Category</a>: <ul><li><a href="/wiki/Category:Lists_of_countries_by_population_density" title="Category:Lists of countries by population density">Lists of countries by population density</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Articles_with_Italian-language_sources_(it)" title="Category:Articles with Italian-language sources (it)">Articles with Italian-language sources (it)</a></li><li><a href="/wiki/Category:CS1_Italian-language_sources_(it)" title="Category:CS1 Italian-language sources (it)">CS1 Italian-language sources (it)</a></li><li><a href="/wiki/Category:CS1_maint:_url-status" title="Category:CS1 maint: url-status">CS1 maint: url-status</a></li><li><a href="/wiki/Category:CS1_Spanish-language_sources_(es)" title="Category:CS1 Spanish-language sources (es)">CS1 Spanish-language sources (es)</a></li><li><a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a></li><li><a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a></li></ul></div></div>
# 				</div>
# 			</main>
#
# 		</div>
# 		<div class="mw-footer-container">
#
# <footer id="footer" class="mw-footer" >
# 	<ul id="footer-info">
# 	<li id="footer-info-lastmod"> This page was last edited on 17 October 2024, at 20:39<span class="anonymous-show">&#160;(UTC)</span>.</li>
# 	<li id="footer-info-copyright">Text is available under the <a href="/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" title="Wikipedia:Text of the Creative Commons Attribution-ShareAlike 4.0 International License">Creative Commons Attribution-ShareAlike 4.0 License</a>;
# additional terms may apply. By using this site, you agree to the <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use" class="extiw" title="foundation:Special:MyLanguage/Policy:Terms of Use">Terms of Use</a> and <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy" class="extiw" title="foundation:Special:MyLanguage/Policy:Privacy policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a rel="nofollow" class="external text" href="https://wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
#
# 	<ul id="footer-places">
# 	<li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a></li>
# 	<li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# 	<li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# 	<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 	<li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Code of Conduct</a></li>
# 	<li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# 	<li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# 	<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">Cookie statement</a></li>
# 	<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=List_of_countries_and_dependencies_by_population_density&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# </ul>
#
# 	<ul id="footer-icons" class="noprint">
# 	<li id="footer-copyrightico"><a href="https://wikimediafoundation.org/" class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled"><img src="/static/images/footer/wikimedia-button.svg" width="84" height="29" alt="Wikimedia Foundation" loading="lazy"></a></li>
# 	<li id="footer-poweredbyico"><a href="https://www.mediawiki.org/" class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled"><img src="/w/resources/assets/poweredby_mediawiki.svg" alt="Powered by MediaWiki" width="88" height="31" loading="lazy"></a></li>
# </ul>
#
# </footer>
#
# 		</div>
# 	</div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# 	<ul></ul>
# </div><script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-685877499b-qcbcf","wgBackendResponseTime":134,"wgPageParseReport":{"limitreport":{"cputime":"2.263","walltime":"3.085","ppvisitednodes":{"value":13525,"limit":1000000},"postexpandincludesize":{"value":294544,"limit":2097152},"templateargumentsize":{"value":3929,"limit":2097152},"expansiondepth":{"value":9,"limit":100},"expensivefunctioncount":{"value":249,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":137000,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00% 2553.788      1 -total"," 44.54% 1137.508    249 Template:Flagg"," 16.20%  413.694    504 Template:Convert","  8.32%  212.509      2 Template:Reflist","  6.92%  176.700      1 Template:Sort_under","  6.83%  174.467     26 Template:Cite_web","  4.91%  125.492      8 Template:Efn","  4.64%  118.470      1 Template:Short_description","  3.87%   98.711      1 Template:In_lang","  3.37%   86.158      1 Template:Population_country_lists"]},"scribunto":{"limitreport-timeusage":{"value":"1.197","limit":"10.000"},"limitreport-memusage":{"value":22068317,"limit":52428800},"limitreport-profile":[["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::expandTemplate","380","30.6"],["recursiveClone \u003CmwInit.lua:45\u003E","200","16.1"],["?","100","8.1"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::callParserFunction","80","6.5"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::getExpensiveData","80","6.5"],["gettable \u003CModule:CountryData:20\u003E","60","4.8"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::getExpandedArgument","60","4.8"],["type","40","3.2"],["lookup \u003CModule:Convert:687\u003E","40","3.2"],["collection \u003CModule:Convert:209\u003E","40","3.2"],["[others]","160","12.9"]]},"cachereport":{"origin":"mw-web.eqiad.main-685877499b-4rjgh","timestamp":"20241018023513","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"List of countries and dependencies by population density","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_countries_and_dependencies_by_population_density","sameAs":"http:\/\/www.wikidata.org\/entity\/Q176310","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q176310","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2002-09-02T00:04:19Z","dateModified":"2024-10-17T20:39:11Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/c\/c1\/Population_density_map_of_the_world.svg","headline":"Wikimedia list article"}</script>
# </body>
# </html>

# %% [markdown]
# - Display all the countries mentioned in the table.

# %% [markdown]
# I couldn't just print the entire webpage's HTML code and manually search for the specific line containing the country names. The best approach is to open the URL and inspect the page using the browser's developer tools. By doing so, we can view the Document Object Model (DOM), which is a structured version of the webpage's HTML. To find the specific elements, we can hover over parts of the page with the mouse, and the corresponding HTML code will be highlighted, allowing us to locate the relevant section.

# %% [markdown]
# I asked chatgpt for help here especially for the lambda function.

# %%
from bs4 import BeautifulSoup as Soup
soup = Soup(page.text, "html.parser")
table = soup.find_all("a", title=lambda t: t and t.startswith("Demographics of"))
countries = [c.text for c in table if c.text.strip()]

# %% [markdown]
# I can see that the last two elements aren't real countries so we'll just get rid of them.

# %%
countries[-2:]
# Out:
# ['Demographics of the world', 'Antarctica']

# %%
countries = countries[:-2]
countries
# Out:
# ['Macau',
#  'Monaco',
#  'Singapore',
#  'Hong Kong',
#  'Gibraltar',
#  'Bahrain',
#  'Maldives',
#  'Malta',
#  'Vatican City',
#  'Sint Maarten',
#  'Bermuda',
#  'Bangladesh',
#  'Guernsey',
#  'Jersey',
#  'Mayotte',
#  'Palestine',
#  'Taiwan',
#  'Mauritius',
#  'Barbados',
#  'Nauru',
#  'Saint Martin',
#  'Aruba',
#  'San Marino',
#  'Rwanda',
#  'South Korea',
#  'Lebanon',
#  'Saint Barthélemy',
#  'Burundi',
#  'Tuvalu',
#  'India',
#  'Curaçao',
#  'Netherlands',
#  'Haiti',
#  'Israel',
#  'Réunion',
#  'Philippines',
#  'Belgium',
#  'Comoros',
#  'Grenada',
#  'Puerto Rico',
#  'Martinique',
#  'Sri Lanka',
#  'Japan',
#  'Guam',
#  'El Salvador',
#  'Pakistan',
#  'Trinidad and Tobago',
#  'Vietnam',
#  'Saint Lucia',
#  'U.S. Virgin Islands',
#  'United Kingdom',
#  'Saint Vincent and the Grenadines',
#  'Cayman Islands',
#  'Jamaica',
#  'Luxembourg',
#  'Liechtenstein',
#  'Gambia',
#  'Nigeria',
#  'Kuwait',
#  'Guadeloupe',
#  'São Tomé and Príncipe',
#  'Seychelles',
#  'Qatar',
#  'Germany',
#  'Dominican Republic',
#  'Marshall Islands',
#  'Malawi',
#  'American Samoa',
#  'North Korea',
#  'Antigua and Barbuda',
#  'Switzerland',
#  'Nepal',
#  'British Virgin Islands',
#  'Uganda',
#  'Italy',
#  'Kiribati',
#  'Saint Kitts and Nevis',
#  'Anguilla',
#  'Andorra',
#  'Guatemala',
#  'Micronesia',
#  'Togo',
#  'Tokelau',
#  'Kosovo',
#  'China',
#  'Cape Verde',
#  'Isle of Man',
#  'Indonesia',
#  'Tonga',
#  'Ghana',
#  'Thailand',
#  'Denmark',
#  'Cyprus',
#  'United Arab Emirates',
#  'Transnistria',
#  'Czech Republic',
#  'Jordan',
#  'Syria',
#  'Sierra Leone',
#  'Poland',
#  'Azerbaijan',
#  'Benin',
#  'Slovakia',
#  'France',
#  'Ethiopia',
#  'Northern Cyprus',
#  'Egypt',
#  'Portugal',
#  'Turkey',
#  'Hungary',
#  'Northern Mariana Islands',
#  'Austria',
#  'Iraq',
#  'Slovenia',
#  'Malaysia',
#  'Costa Rica',
#  'Cuba',
#  'Moldova',
#  'France',
#  'Albania',
#  'Dominica',
#  'Spain',
#  'Honduras',
#  'Cambodia',
#  'Armenia',
#  'Kenya',
#  'East Timor',
#  'Senegal',
#  'Ivory Coast',
#  'Burkina Faso',
#  'French Polynesia',
#  'Romania',
#  'North Macedonia',
#  'Wallis and Futuna',
#  'Serbia',
#  'Myanmar',
#  'Samoa',
#  'Brunei',
#  'Greece',
#  'Uzbekistan',
#  'Lesotho',
#  'Tunisia',
#  'Ireland',
#  'Cook Islands',
#  'Tajikistan',
#  'Tanzania',
#  'Croatia',
#  'Ecuador',
#  'Eswatini',
#  'Mexico',
#  'Yemen',
#  'Afghanistan',
#  'Bosnia and Herzegovina',
#  'Akrotiri and Dhekelia',
#  'Equatorial Guinea',
#  'Ukraine',
#  'Bulgaria',
#  'Cameroon',
#  'Guinea-Bissau',
#  'Panama',
#  'Guinea',
#  'Norfolk Island',
#  'Iran',
#  'Nicaragua',
#  'Georgia',
#  'Morocco',
#  'Madagascar',
#  'Fiji',
#  'South Africa',
#  'Djibouti',
#  'Liberia',
#  'Turks and Caicos Islands',
#  'Easter Island',
#  'Belarus',
#  'Colombia',
#  'Montenegro',
#  'DR Congo',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'Cocos (Keeling) Islands',
#  'Zimbabwe',
#  'Montserrat',
#  'Mozambique',
#  'Lithuania',
#  'Palau',
#  'Faroe Islands',
#  'United States',
#  'Kyrgyzstan',
#  'Laos',
#  'Venezuela',
#  'Eritrea',
#  'Bahamas',
#  'Angola',
#  'Somaliland',
#  'Estonia',
#  'Somalia',
#  'Latvia',
#  'Abkhazia',
#  'Vanuatu',
#  'Zambia',
#  'Sudan',
#  'Peru',
#  'Chile',
#  'Solomon Islands',
#  'Brazil',
#  'Sweden',
#  'Saint Pierre and Miquelon',
#  'Papua New Guinea',
#  'Niger',
#  'Bhutan',
#  'Uruguay',
#  'New Zealand',
#  'Algeria',
#  'Åland',
#  'Mali',
#  'Belize',
#  'Congo',
#  'South Sudan',
#  'Saudi Arabia',
#  'Finland',
#  'Argentina',
#  'South Ossetia',
#  'New Caledonia',
#  'Paraguay',
#  'Oman',
#  'Chad',
#  'Norway',
#  'Turkmenistan',
#  'Christmas Island',
#  'Bolivia',
#  'Central African Republic',
#  'Gabon',
#  'Russia',
#  'Niue',
#  'Kazakhstan',
#  'Mauritania',
#  'Botswana',
#  'Libya',
#  'Canada',
#  'Suriname',
#  'Guyana',
#  'French Guiana',
#  'Iceland',
#  'Australia',
#  'Namibia',
#  'Western Sahara',
#  'Mongolia',
#  'Pitcairn Islands',
#  'Falkland Islands',
#  'Greenland']

# %% [markdown]
# - Display for each country its rank, density, population, area.

# %% [markdown]
# Let's start by looking at one row of the countries table :

# %%
trows = soup.find_all("tr")
trows[1]
# Out:
# <tr>
# <td style="text-align:left"><span class="flagicon" style="display:inline-block;width:25px;text-align:left"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_Macau.svg/23px-Flag_of_Macau.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_Macau.svg/35px-Flag_of_Macau.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_Macau.svg/45px-Flag_of_Macau.svg.png 2x" width="23"/></span></span></span> <a href="/wiki/Demographics_of_Macau" title="Demographics of Macau">Macau</a> (<a href="/wiki/China" title="China">China</a>)</td>
# <td data-sort-value="7010543897503170560" style="text-align:right;">21,000
# </td>
# <td data-sort-value="7010543897503170560" style="text-align:right;">54,000</td>
# <td>704,150</td>
# <td style="text-align:right;">33
# </td>
# <td style="text-align:right;">13</td>
# <td>
# </td></tr>

# %% [markdown]
# we can see that of all the table rows existing in the page the 2nd one (index 1) corresponds to the 'Macau' row in the table which is the first country on the table.

# %% [markdown]
# We know that the information we're interested in begins from the second row of the trows list. To extract and display this data, we can simply loop through the rows (ignoring the first one). For each row, we use the find_all function to gather all the elements (<td> tags) in that row, which will give us access to the country name, population, area, and other related information.

# %%
len(countries)
# Out:
# 249

# %%
data = []
for row in trows[1:253]:
    cells = row.find_all('td')
    
    country = cells[0].text.strip()
    population = cells[1].text.strip()
    area_km2 = cells[2].text.strip()
    area_sq_mi = cells[3].text.strip()
    density = cells[4].text.strip()

    # Store the extracted data
    data.append({
        'Country': country,
        'Population': population,
        'Area (km²)': area_km2,
        'Area (sq mi)': area_sq_mi,
        'Density': density,
    })

# %%
data
# Out:
# [{'Country': 'Macau (China)',
#   'Population': '21,000',
#   'Area (km²)': '54,000',
#   'Area (sq mi)': '704,150',
#   'Density': '33'},
#  {'Country': 'Monaco',
#   'Population': '18,000',
#   'Area (km²)': '47,000',
#   'Area (sq mi)': '36,298',
#   'Density': '2.0'},
#  {'Country': 'Singapore',
#   'Population': '8,250',
#   'Area (km²)': '21,400',
#   'Area (sq mi)': '6,014,723',
#   'Density': '729'},
#  {'Country': 'Hong Kong (China)',
#   'Population': '6,725',
#   'Area (km²)': '17,420',
#   'Area (sq mi)': '7,491,609',
#   'Density': '1,114'},
#  {'Country': 'Gibraltar (UK)',
#   'Population': '4,800',
#   'Area (km²)': '12,000',
#   'Area (sq mi)': '32,688',
#   'Density': '6.8'},
#  {'Country': 'Bahrain',
#   'Population': '1,910',
#   'Area (km²)': '4,900',
#   'Area (sq mi)': '1,485,510',
#   'Density': '778'},
#  {'Country': 'Maldives',
#   'Population': '1,750',
#   'Area (km²)': '4,500',
#   'Area (sq mi)': '523,787',
#   'Density': '300'},
#  {'Country': 'Malta',
#   'Population': '1,700',
#   'Area (km²)': '4,400',
#   'Area (sq mi)': '535,065',
#   'Density': '315'},
#  {'Country': 'Vatican City',
#   'Population': '1,600',
#   'Area (km²)': '4,100',
#   'Area (sq mi)': '764',
#   'Density': '0.49'},
#  {'Country': 'Sint Maarten (NL)',
#   'Population': '1,300',
#   'Area (km²)': '3,400',
#   'Area (sq mi)': '44,222',
#   'Density': '34'},
#  {'Country': 'Bermuda (UK)',
#   'Population': '1,200',
#   'Area (km²)': '3,100',
#   'Area (sq mi)': '64,069',
#   'Density': '54'},
#  {'Country': 'Bangladesh',
#   'Population': '1,165',
#   'Area (km²)': '3,020',
#   'Area (sq mi)': '172,954,319',
#   'Density': '148,460'},
#  {'Country': 'Guernsey (UK)',
#   'Population': '990',
#   'Area (km²)': '2,600',
#   'Area (sq mi)': '63,544',
#   'Density': '64'},
#  {'Country': 'Jersey (UK)',
#   'Population': '964',
#   'Area (km²)': '2,500',
#   'Area (sq mi)': '111,803',
#   'Density': '116'},
#  {'Country': 'Mayotte (France)',
#   'Population': '913',
#   'Area (km²)': '2,360',
#   'Area (sq mi)': '335,995',
#   'Density': '368'},
#  {'Country': 'Palestine(Gaza Strip, West Bank)',
#   'Population': '892',
#   'Area (km²)': '2,310',
#   'Area (sq mi)': '5,371,230',
#   'Density': '6,020'},
#  {'Country': 'Taiwan',
#   'Population': '676',
#   'Area (km²)': '1,750',
#   'Area (sq mi)': '23,923,277',
#   'Density': '35,410'},
#  {'Country': 'Mauritius',
#   'Population': '657',
#   'Area (km²)': '1,700',
#   'Area (sq mi)': '1,300,557',
#   'Density': '1,979'},
#  {'Country': 'Barbados',
#   'Population': '654',
#   'Area (km²)': '1,690',
#   'Area (sq mi)': '281,996',
#   'Density': '431'},
#  {'Country': 'Nauru',
#   'Population': '610',
#   'Area (km²)': '1,600',
#   'Area (sq mi)': '12,780',
#   'Density': '21'},
#  {'Country': 'Saint Martin (France)',
#   'Population': '610',
#   'Area (km²)': '1,600',
#   'Area (sq mi)': '32,077',
#   'Density': '53'},
#  {'Country': 'Aruba (NL)',
#   'Population': '590',
#   'Area (km²)': '1,500',
#   'Area (sq mi)': '106,277',
#   'Density': '180'},
#  {'Country': 'San Marino',
#   'Population': '550',
#   'Area (km²)': '1,400',
#   'Area (sq mi)': '33,642',
#   'Density': '61'},
#  {'Country': 'Rwanda',
#   'Population': '535',
#   'Area (km²)': '1,390',
#   'Area (sq mi)': '14,094,683',
#   'Density': '26,338'},
#  {'Country': 'South Korea',
#   'Population': '516',
#   'Area (km²)': '1,340',
#   'Area (sq mi)': '51,784,059',
#   'Density': '100,413'},
#  {'Country': 'Lebanon',
#   'Population': '512',
#   'Area (km²)': '1,330',
#   'Area (sq mi)': '5,353,930',
#   'Density': '10,452'},
#  {'Country': 'Saint Barthélemy (France)',
#   'Population': '500',
#   'Area (km²)': '1,300',
#   'Area (sq mi)': '10,994',
#   'Density': '22'},
#  {'Country': 'Burundi',
#   'Population': '476',
#   'Area (km²)': '1,230',
#   'Area (sq mi)': '13,238,559',
#   'Density': '27,834'},
#  {'Country': 'Tuvalu',
#   'Population': '440',
#   'Area (km²)': '1,100',
#   'Area (sq mi)': '11,396',
#   'Density': '26'},
#  {'Country': 'India',
#   'Population': '435',
#   'Area (km²)': '1,130',
#   'Area (sq mi)': '1,428,627,663',
#   'Density': '3,287,263'},
#  {'Country': 'Curaçao (NL)',
#   'Population': '433',
#   'Area (km²)': '1,120',
#   'Area (sq mi)': '192,077',
#   'Density': '444'},
#  {'Country': 'Netherlands',
#   'Population': '436',
#   'Area (km²)': '1,130',
#   'Area (sq mi)': '18,092,525',
#   'Density': '41,543'},
#  {'Country': 'Haiti',
#   'Population': '423',
#   'Area (km²)': '1,100',
#   'Area (sq mi)': '11,724,764',
#   'Density': '27,750'},
#  {'Country': 'Israel',
#   'Population': '416',
#   'Area (km²)': '1,080',
#   'Area (sq mi)': '9,174,520',
#   'Density': '22,072'},
#  {'Country': 'Réunion (France)',
#   'Population': '391',
#   'Area (km²)': '1,010',
#   'Area (sq mi)': '981,796',
#   'Density': '2,510'},
#  {'Country': 'Philippines',
#   'Population': '391',
#   'Area (km²)': '1,010',
#   'Area (sq mi)': '117,337,368',
#   'Density': '300,000'},
#  {'Country': 'Belgium',
#   'Population': '383',
#   'Area (km²)': '990',
#   'Area (sq mi)': '11,686,140',
#   'Density': '30,528'},
#  {'Country': 'Comoros',
#   'Population': '381',
#   'Area (km²)': '990',
#   'Area (sq mi)': '852,075',
#   'Density': '2,235'},
#  {'Country': 'Grenada',
#   'Population': '366',
#   'Area (km²)': '950',
#   'Area (sq mi)': '126,184',
#   'Density': '345'},
#  {'Country': 'Puerto Rico (US)',
#   'Population': '361',
#   'Area (km²)': '930',
#   'Area (sq mi)': '3,205,691',
#   'Density': '8,868'},
#  {'Country': 'Martinique (France)',
#   'Population': '337',
#   'Area (km²)': '870',
#   'Area (sq mi)': '366,981',
#   'Density': '1,090'},
#  {'Country': 'Sri Lanka',
#   'Population': '334',
#   'Area (km²)': '870',
#   'Area (sq mi)': '21,893,579',
#   'Density': '65,610'},
#  {'Country': 'Japan',
#   'Population': '326',
#   'Area (km²)': '840',
#   'Area (sq mi)': '123,294,513',
#   'Density': '377,930'},
#  {'Country': 'Guam (US)',
#   'Population': '320',
#   'Area (km²)': '830',
#   'Area (sq mi)': '172,952',
#   'Density': '541'},
#  {'Country': 'El Salvador',
#   'Population': '303',
#   'Area (km²)': '780',
#   'Area (sq mi)': '6,364,943',
#   'Density': '21,041'},
#  {'Country': 'Pakistan',
#   'Population': '302',
#   'Area (km²)': '780',
#   'Area (sq mi)': '240,485,658',
#   'Density': '796,095'},
#  {'Country': 'Trinidad and Tobago',
#   'Population': '299',
#   'Area (km²)': '770',
#   'Area (sq mi)': '1,534,937',
#   'Density': '5,127'},
#  {'Country': 'Vietnam',
#   'Population': '298',
#   'Area (km²)': '770',
#   'Area (sq mi)': '98,858,950',
#   'Density': '331,340'},
#  {'Country': 'Saint Lucia',
#   'Population': '293',
#   'Area (km²)': '760',
#   'Area (sq mi)': '180,251',
#   'Density': '616'},
#  {'Country': 'U.S. Virgin Islands (US)',
#   'Population': '285',
#   'Area (km²)': '740',
#   'Area (sq mi)': '98,750',
#   'Density': '347'},
#  {'Country': 'United Kingdom',
#   'Population': '279',
#   'Area (km²)': '720',
#   'Area (sq mi)': '67,596,281',
#   'Density': '242,495'},
#  {'Country': 'Saint Vincent and the Grenadines',
#   'Population': '267',
#   'Area (km²)': '690',
#   'Area (sq mi)': '103,699',
#   'Density': '389'},
#  {'Country': 'Cayman Islands (UK)',
#   'Population': '263',
#   'Area (km²)': '680',
#   'Area (sq mi)': '69,310',
#   'Density': '264'},
#  {'Country': 'Jamaica',
#   'Population': '257',
#   'Area (km²)': '670',
#   'Area (sq mi)': '2,825,544',
#   'Density': '10,991'},
#  {'Country': 'Luxembourg',
#   'Population': '253',
#   'Area (km²)': '660',
#   'Area (sq mi)': '654,768',
#   'Density': '2,586'},
#  {'Country': 'Liechtenstein',
#   'Population': '247',
#   'Area (km²)': '640',
#   'Area (sq mi)': '39,585',
#   'Density': '160'},
#  {'Country': 'Gambia',
#   'Population': '246',
#   'Area (km²)': '640',
#   'Area (sq mi)': '2,773,168',
#   'Density': '11,295'},
#  {'Country': 'Nigeria',
#   'Population': '249',
#   'Area (km²)': '640',
#   'Area (sq mi)': '230,842,743',
#   'Density': '923,768'},
#  {'Country': 'Kuwait',
#   'Population': '242',
#   'Area (km²)': '630',
#   'Area (sq mi)': '4,310,108',
#   'Density': '17,818'},
#  {'Country': 'Guadeloupe (France)',
#   'Population': '242',
#   'Area (km²)': '630',
#   'Area (sq mi)': '395,839',
#   'Density': '1,639'},
#  {'Country': 'São Tomé and Príncipe',
#   'Population': '241',
#   'Area (km²)': '620',
#   'Area (sq mi)': '231,856',
#   'Density': '964'},
#  {'Country': 'Seychelles',
#   'Population': '236',
#   'Area (km²)': '610',
#   'Area (sq mi)': '107,660',
#   'Density': '457'},
#  {'Country': 'Qatar',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '2,716,391',
#   'Density': '11,637'},
#  {'Country': 'Germany',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '83,294,633',
#   'Density': '357,581'},
#  {'Country': 'Dominican Republic',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '11,332,973',
#   'Density': '48,671'},
#  {'Country': 'Marshall Islands',
#   'Population': '232',
#   'Area (km²)': '600',
#   'Area (sq mi)': '41,996',
#   'Density': '181'},
#  {'Country': 'Malawi',
#   'Population': '221',
#   'Area (km²)': '570',
#   'Area (sq mi)': '20,931,751',
#   'Density': '94,552'},
#  {'Country': 'American Samoa (US)',
#   'Population': '221',
#   'Area (km²)': '570',
#   'Area (sq mi)': '43,915',
#   'Density': '199'},
#  {'Country': 'North Korea',
#   'Population': '217',
#   'Area (km²)': '560',
#   'Area (sq mi)': '26,160,822',
#   'Density': '120,538'},
#  {'Country': 'Antigua and Barbuda',
#   'Population': '213',
#   'Area (km²)': '550',
#   'Area (sq mi)': '94,298',
#   'Density': '442'},
#  {'Country': 'Switzerland',
#   'Population': '213',
#   'Area (km²)': '550',
#   'Area (sq mi)': '8,796,669',
#   'Density': '41,291'},
#  {'Country': 'Nepal',
#   'Population': '210',
#   'Area (km²)': '540',
#   'Area (sq mi)': '30,896,590',
#   'Density': '147,181'},
#  {'Country': 'British Virgin Islands (UK)',
#   'Population': '209',
#   'Area (km²)': '540',
#   'Area (sq mi)': '31,538',
#   'Density': '151'},
#  {'Country': 'Uganda',
#   'Population': '201',
#   'Area (km²)': '520',
#   'Area (sq mi)': '48,582,334',
#   'Density': '241,550'},
#  {'Country': 'Italy',
#   'Population': '195',
#   'Area (km²)': '510',
#   'Area (sq mi)': '58,870,763',
#   'Density': '302,068'},
#  {'Country': 'Kiribati',
#   'Population': '184',
#   'Area (km²)': '480',
#   'Area (sq mi)': '133,515',
#   'Density': '726'},
#  {'Country': 'Saint Kitts and Nevis',
#   'Population': '183',
#   'Area (km²)': '470',
#   'Area (sq mi)': '47,755',
#   'Density': '261'},
#  {'Country': 'Anguilla (UK)',
#   'Population': '175',
#   'Area (km²)': '450',
#   'Area (sq mi)': '15,900',
#   'Density': '91'},
#  {'Country': 'Andorra',
#   'Population': '171',
#   'Area (km²)': '440',
#   'Area (sq mi)': '80,088',
#   'Density': '468'},
#  {'Country': 'Guatemala',
#   'Population': '166',
#   'Area (km²)': '430',
#   'Area (sq mi)': '18,092,026',
#   'Density': '108,889'},
#  {'Country': 'Micronesia',
#   'Population': '164',
#   'Area (km²)': '420',
#   'Area (sq mi)': '115,224',
#   'Density': '702'},
#  {'Country': 'Togo',
#   'Population': '159',
#   'Area (km²)': '410',
#   'Area (sq mi)': '9,053,799',
#   'Density': '56,785'},
#  {'Country': 'Tokelau (New Zealand)',
#   'Population': '158',
#   'Area (km²)': '410',
#   'Area (sq mi)': '1,893',
#   'Density': '12'},
#  {'Country': 'Kosovo',
#   'Population': '153',
#   'Area (km²)': '400',
#   'Area (sq mi)': '1,663,595',
#   'Density': '10,905'},
#  {'Country': 'China',
#   'Population': '149',
#   'Area (km²)': '390',
#   'Area (sq mi)': '1,425,671,352',
#   'Density': '9,600,000'},
#  {'Country': 'Cape Verde',
#   'Population': '148',
#   'Area (km²)': '380',
#   'Area (sq mi)': '598,682',
#   'Density': '4,033'},
#  {'Country': 'Isle of Man',
#   'Population': '148',
#   'Area (km²)': '380',
#   'Area (sq mi)': '84,710',
#   'Density': '572'},
#  {'Country': 'Indonesia',
#   'Population': '145',
#   'Area (km²)': '380',
#   'Area (sq mi)': '277,534,123',
#   'Density': '1,910,931'},
#  {'Country': 'Tonga',
#   'Population': '144',
#   'Area (km²)': '370',
#   'Area (sq mi)': '107,773',
#   'Density': '747'},
#  {'Country': 'Ghana',
#   'Population': '143',
#   'Area (km²)': '370',
#   'Area (sq mi)': '34,121,985',
#   'Density': '238,537'},
#  {'Country': 'Thailand',
#   'Population': '140',
#   'Area (km²)': '360',
#   'Area (sq mi)': '71,801,279',
#   'Density': '513,140'},
#  {'Country': 'Denmark',
#   'Population': '138',
#   'Area (km²)': '360',
#   'Area (sq mi)': '5,910,913',
#   'Density': '42,947'},
#  {'Country': 'Cyprus',
#   'Population': '136',
#   'Area (km²)': '350',
#   'Area (sq mi)': '1,260,138',
#   'Density': '9,251'},
#  {'Country': 'United Arab Emirates',
#   'Population': '134',
#   'Area (km²)': '350',
#   'Area (sq mi)': '9,516,871',
#   'Density': '71,024'},
#  {'Country': 'Transnistria',
#   'Population': '134',
#   'Area (km²)': '350',
#   'Area (sq mi)': '468,980',
#   'Density': '3,510'},
#  {'Country': 'Czech Republic',
#   'Population': '133',
#   'Area (km²)': '340',
#   'Area (sq mi)': '10,495,295',
#   'Density': '78,871'},
#  {'Country': 'Jordan',
#   'Population': '127',
#   'Area (km²)': '330',
#   'Area (sq mi)': '11,337,053',
#   'Density': '89,318'},
#  {'Country': 'Syria',
#   'Population': '125',
#   'Area (km²)': '320',
#   'Area (sq mi)': '23,227,014',
#   'Density': '185,180'},
#  {'Country': 'Sierra Leone',
#   'Population': '122',
#   'Area (km²)': '320',
#   'Area (sq mi)': '8,791,092',
#   'Density': '72,300'},
#  {'Country': 'Poland',
#   'Population': '120',
#   'Area (km²)': '310',
#   'Area (sq mi)': '37,691,000',
#   'Density': '313,931'},
#  {'Country': 'Azerbaijan',
#   'Population': '120',
#   'Area (km²)': '310',
#   'Area (sq mi)': '10,412,652',
#   'Density': '86,600'},
#  {'Country': 'Benin',
#   'Population': '119',
#   'Area (km²)': '310',
#   'Area (sq mi)': '13,712,828',
#   'Density': '114,763'},
#  {'Country': 'Slovakia',
#   'Population': '110',
#   'Area (km²)': '280',
#   'Area (sq mi)': '5,422,194',
#   'Density': '49,035'},
#  {'Country': 'France (metropolitan)',
#   'Population': '117',
#   'Area (km²)': '300',
#   'Area (sq mi)': '64,756,584',
#   'Density': '551,500'},
#  {'Country': 'Ethiopia',
#   'Population': '115',
#   'Area (km²)': '300',
#   'Area (sq mi)': '126,527,060',
#   'Density': '1,104,300'},
#  {'Country': 'Northern Cyprus',
#   'Population': '114',
#   'Area (km²)': '300',
#   'Area (sq mi)': '382,836',
#   'Density': '3,355'},
#  {'Country': 'Egypt',
#   'Population': '112',
#   'Area (km²)': '290',
#   'Area (sq mi)': '112,716,599',
#   'Density': '1,002,000'},
#  {'Country': 'Portugal',
#   'Population': '111',
#   'Area (km²)': '290',
#   'Area (sq mi)': '10,247,605',
#   'Density': '92,225'},
#  {'Country': 'Turkey',
#   'Population': '110',
#   'Area (km²)': '280',
#   'Area (sq mi)': '85,816,199',
#   'Density': '783,562'},
#  {'Country': 'Hungary',
#   'Population': '109',
#   'Area (km²)': '280',
#   'Area (sq mi)': '10,156,239',
#   'Density': '93,025'},
#  {'Country': 'Northern Mariana Islands (US)',
#   'Population': '109',
#   'Area (km²)': '280',
#   'Area (sq mi)': '49,796',
#   'Density': '457'},
#  {'Country': 'Austria',
#   'Population': '107',
#   'Area (km²)': '280',
#   'Area (sq mi)': '8,958,961',
#   'Density': '83,878'},
#  {'Country': 'Iraq',
#   'Population': '105',
#   'Area (km²)': '270',
#   'Area (sq mi)': '45,504,560',
#   'Density': '435,052'},
#  {'Country': 'Slovenia',
#   'Population': '105',
#   'Area (km²)': '270',
#   'Area (sq mi)': '2,119,675',
#   'Density': '20,273'},
#  {'Country': 'Malaysia',
#   'Population': '104',
#   'Area (km²)': '270',
#   'Area (sq mi)': '34,308,525',
#   'Density': '330,621'},
#  {'Country': 'Costa Rica',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '5,212,173',
#   'Density': '51,100'},
#  {'Country': 'Cuba',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '11,194,449',
#   'Density': '109,884'},
#  {'Country': 'Moldova',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '3,435,931',
#   'Density': '33,847'},
#  {'Country': 'France (metropolitan & overseas)',
#   'Population': '101',
#   'Area (km²)': '260',
#   'Area (sq mi)': '68,000,000',
#   'Density': '672,000'},
#  {'Country': 'Albania',
#   'Population': '99',
#   'Area (km²)': '260',
#   'Area (sq mi)': '2,832,439',
#   'Density': '28,748'},
#  {'Country': 'Dominica',
#   'Population': '97',
#   'Area (km²)': '250',
#   'Area (sq mi)': '73,040',
#   'Density': '750'},
#  {'Country': 'Spain',
#   'Population': '97',
#   'Area (km²)': '250',
#   'Area (sq mi)': '48,797,875',
#   'Density': '505,994'},
#  {'Country': 'Honduras',
#   'Population': '94',
#   'Area (km²)': '240',
#   'Area (sq mi)': '10,593,798',
#   'Density': '112,492'},
#  {'Country': 'Cambodia',
#   'Population': '94',
#   'Area (km²)': '240',
#   'Area (sq mi)': '16,944,826',
#   'Density': '181,039'},
#  {'Country': 'Armenia',
#   'Population': '93',
#   'Area (km²)': '240',
#   'Area (sq mi)': '2,777,971',
#   'Density': '29,743'},
#  {'Country': 'Kenya',
#   'Population': '93',
#   'Area (km²)': '240',
#   'Area (sq mi)': '55,100,587',
#   'Density': '591,958'},
#  {'Country': 'East Timor',
#   'Population': '91',
#   'Area (km²)': '240',
#   'Area (sq mi)': '1,360,596',
#   'Density': '14,919'},
#  {'Country': 'Senegal',
#   'Population': '90',
#   'Area (km²)': '230',
#   'Area (sq mi)': '17,763,163',
#   'Density': '196,712'},
#  {'Country': 'Ivory Coast',
#   'Population': '90',
#   'Area (km²)': '230',
#   'Area (sq mi)': '28,873,034',
#   'Density': '322,462'},
#  {'Country': 'Burkina Faso',
#   'Population': '86',
#   'Area (km²)': '220',
#   'Area (sq mi)': '23,251,485',
#   'Density': '270,764'},
#  {'Country': 'French Polynesia (France)',
#   'Population': '84',
#   'Area (km²)': '220',
#   'Area (sq mi)': '308,872',
#   'Density': '3,687'},
#  {'Country': 'Romania',
#   'Population': '83',
#   'Area (km²)': '210',
#   'Area (sq mi)': '19,892,812',
#   'Density': '238,398'},
#  {'Country': 'Caribbean Netherlands (Netherlands)',
#   'Population': '83',
#   'Area (km²)': '210',
#   'Area (sq mi)': '27,148',
#   'Density': '328'},
#  {'Country': 'North Macedonia',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '2,085,679',
#   'Density': '25,713'},
#  {'Country': 'Wallis and Futuna (France)',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '11,502',
#   'Density': '142'},
#  {'Country': 'Serbia',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '7,149,077',
#   'Density': '88,444'},
#  {'Country': 'Myanmar',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '54,577,997',
#   'Density': '676,577'},
#  {'Country': 'Samoa',
#   'Population': '79',
#   'Area (km²)': '200',
#   'Area (sq mi)': '225,681',
#   'Density': '2,842'},
#  {'Country': 'Brunei',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '452,524',
#   'Density': '5,765'},
#  {'Country': 'Greece',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '10,341,277',
#   'Density': '131,957'},
#  {'Country': 'Uzbekistan',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '35,163,944',
#   'Density': '448,969'},
#  {'Country': 'Lesotho',
#   'Population': '77',
#   'Area (km²)': '200',
#   'Area (sq mi)': '2,330,318',
#   'Density': '30,355'},
#  {'Country': 'Tunisia',
#   'Population': '76',
#   'Area (km²)': '200',
#   'Area (sq mi)': '12,458,223',
#   'Density': '163,610'},
#  {'Country': 'Ireland',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '5,056,935',
#   'Density': '69,825'},
#  {'Country': 'Cook Islands',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '17,044',
#   'Density': '236'},
#  {'Country': 'Tajikistan',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '10,143,543',
#   'Density': '141,400'},
#  {'Country': 'Tanzania',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '67,438,106',
#   'Density': '947,303'},
#  {'Country': 'Croatia',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '4,008,617',
#   'Density': '56,594'},
#  {'Country': 'Ecuador',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '18,190,484',
#   'Density': '257,215'},
#  {'Country': 'Eswatini',
#   'Population': '70',
#   'Area (km²)': '180',
#   'Area (sq mi)': '1,210,822',
#   'Density': '17,363'},
#  {'Country': 'Mexico',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '128,455,567',
#   'Density': '1,964,375'},
#  {'Country': 'Yemen',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '34,449,825',
#   'Density': '527,968'},
#  {'Country': 'Afghanistan',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '42,239,854',
#   'Density': '652,864'},
#  {'Country': 'Bosnia and Herzegovina',
#   'Population': '63',
#   'Area (km²)': '160',
#   'Area (sq mi)': '3,210,848',
#   'Density': '51,209'},
#  {'Country': 'Akrotiri and Dhekelia (UK)',
#   'Population': '62',
#   'Area (km²)': '160',
#   'Area (sq mi)': '15,700',
#   'Density': '254'},
#  {'Country': 'Equatorial Guinea',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '1,714,672',
#   'Density': '28,051'},
#  {'Country': 'Ukraine',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '36,744,634',
#   'Density': '603,500'},
#  {'Country': 'Bulgaria',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '6,687,717',
#   'Density': '110,372'},
#  {'Country': 'Cameroon',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '28,647,293',
#   'Density': '475,650'},
#  {'Country': 'World (excluding Antarctica)',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '8,045,311,448',
#   'Density': '134,740,000'},
#  {'Country': 'Guinea-Bissau',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '2,150,842',
#   'Density': '36,125'},
#  {'Country': 'Panama',
#   'Population': '59',
#   'Area (km²)': '150',
#   'Area (sq mi)': '4,468,087',
#   'Density': '75,320'},
#  {'Country': 'Guinea',
#   'Population': '58',
#   'Area (km²)': '150',
#   'Area (sq mi)': '14,190,612',
#   'Density': '245,836'},
#  {'Country': 'Norfolk Island (Australia)',
#   'Population': '57',
#   'Area (km²)': '150',
#   'Area (sq mi)': '2,220',
#   'Density': '39'},
#  {'Country': 'Iran',
#   'Population': '55',
#   'Area (km²)': '140',
#   'Area (sq mi)': '89,172,767',
#   'Density': '1,630,848'},
#  {'Country': 'Nicaragua',
#   'Population': '54',
#   'Area (km²)': '140',
#   'Area (sq mi)': '7,046,311',
#   'Density': '130,373'},
#  {'Country': 'World (all land)',
#   'Population': '54',
#   'Area (km²)': '140',
#   'Area (sq mi)': '8,045,311,448',
#   'Density': '148,940,000'},
#  {'Country': 'Georgia',
#   'Population': '53',
#   'Area (km²)': '140',
#   'Area (sq mi)': '3,728,282',
#   'Density': '69,700'},
#  {'Country': 'Morocco',
#   'Population': '53',
#   'Area (km²)': '140',
#   'Area (sq mi)': '37,984,655',
#   'Density': '710,850'},
#  {'Country': 'Madagascar',
#   'Population': '52',
#   'Area (km²)': '130',
#   'Area (sq mi)': '30,325,732',
#   'Density': '587,041'},
#  {'Country': 'Fiji',
#   'Population': '51',
#   'Area (km²)': '130',
#   'Area (sq mi)': '936,376',
#   'Density': '18,272'},
#  {'Country': 'South Africa',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '60,414,495',
#   'Density': '1,221,037'},
#  {'Country': 'Djibouti',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '1,136,455',
#   'Density': '23,200'},
#  {'Country': 'Liberia',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '5,418,377',
#   'Density': '111,369'},
#  {'Country': 'Turks and Caicos Islands (UK)',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '46,062',
#   'Density': '948'},
#  {'Country': 'Easter Island',
#   'Population': '47',
#   'Area (km²)': '120',
#   'Area (sq mi)': '7750',
#   'Density': '163.6'},
#  {'Country': 'Belarus',
#   'Population': '46',
#   'Area (km²)': '120',
#   'Area (sq mi)': '9,498,238',
#   'Density': '207,600'},
#  {'Country': 'Colombia',
#   'Population': '46',
#   'Area (km²)': '120',
#   'Area (sq mi)': '52,695,952',
#   'Density': '1,141,748'},
#  {'Country': 'Montenegro',
#   'Population': '45',
#   'Area (km²)': '120',
#   'Area (sq mi)': '626,485',
#   'Density': '13,888'},
#  {'Country': 'DR Congo',
#   'Population': '44',
#   'Area (km²)': '110',
#   'Area (sq mi)': '102,262,809',
#   'Density': '2,345,410'},
#  {'Country': 'Saint Helena, Ascension and Tristan da Cunha (UK)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '5,314',
#   'Density': '123'},
#  {'Country': 'Cocos (Keeling) Islands (Australia)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '602',
#   'Density': '14'},
#  {'Country': 'Zimbabwe',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '16,665,409',
#   'Density': '390,757'},
#  {'Country': 'Montserrat (UK)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '4,387',
#   'Density': '103'},
#  {'Country': 'Mozambique',
#   'Population': '42',
#   'Area (km²)': '110',
#   'Area (sq mi)': '33,897,354',
#   'Density': '799,380'},
#  {'Country': 'Lithuania',
#   'Population': '42',
#   'Area (km²)': '110',
#   'Area (sq mi)': '2,718,352',
#   'Density': '65,286'},
#  {'Country': 'Palau',
#   'Population': '39',
#   'Area (km²)': '100',
#   'Area (sq mi)': '18,058',
#   'Density': '459'},
#  {'Country': 'Faroe Islands (Denmark)',
#   'Population': '38',
#   'Area (km²)': '98',
#   'Area (sq mi)': '53,270',
#   'Density': '1,393'},
#  {'Country': 'United States',
#   'Population': '35',
#   'Area (km²)': '91',
#   'Area (sq mi)': '339,996,564',
#   'Density': '9,833,517'},
#  {'Country': 'Kyrgyzstan',
#   'Population': '34',
#   'Area (km²)': '88',
#   'Area (sq mi)': '6,735,348',
#   'Density': '199,949'},
#  {'Country': 'Laos',
#   'Population': '32',
#   'Area (km²)': '83',
#   'Area (sq mi)': '7,633,779',
#   'Density': '236,800'},
#  {'Country': 'Venezuela',
#   'Population': '31',
#   'Area (km²)': '80',
#   'Area (sq mi)': '28,838,499',
#   'Density': '929,690'},
#  {'Country': 'Eritrea',
#   'Population': '31',
#   'Area (km²)': '80',
#   'Area (sq mi)': '3,748,902',
#   'Density': '121,144'},
#  {'Country': 'Bahamas',
#   'Population': '30',
#   'Area (km²)': '78',
#   'Area (sq mi)': '412,624',
#   'Density': '13,940'},
#  {'Country': 'Angola',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '36,684,203',
#   'Density': '1,246,700'},
#  {'Country': 'Somaliland',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '4,914,100',
#   'Density': '167,283'},
#  {'Country': 'Estonia',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '1,322,766',
#   'Density': '45,399'},
#  {'Country': 'Somalia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '18,143,379',
#   'Density': '637,657'},
#  {'Country': 'Latvia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '1,862,700',
#   'Density': '64,594'},
#  {'Country': 'Abkhazia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '245,424',
#   'Density': '8,662'},
#  {'Country': 'Vanuatu',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '334,506',
#   'Density': '12,189'},
#  {'Country': 'Zambia',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '20,569,738',
#   'Density': '752,612'},
#  {'Country': 'Sudan',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '48,109,006',
#   'Density': '1,765,048'},
#  {'Country': 'Peru',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '34,352,719',
#   'Density': '1,285,216'},
#  {'Country': 'Chile',
#   'Population': '26',
#   'Area (km²)': '67',
#   'Area (sq mi)': '19,629,590',
#   'Density': '756,102'},
#  {'Country': 'Solomon Islands',
#   'Population': '26',
#   'Area (km²)': '67',
#   'Area (sq mi)': '740,425',
#   'Density': '28,896'},
#  {'Country': 'Brazil',
#   'Population': '25',
#   'Area (km²)': '65',
#   'Area (sq mi)': '216,422,446',
#   'Density': '8,510,346'},
#  {'Country': 'Sweden',
#   'Population': '24',
#   'Area (km²)': '62',
#   'Area (sq mi)': '10,612,086',
#   'Density': '438,574'},
#  {'Country': 'Saint Pierre and Miquelon (France)',
#   'Population': '24',
#   'Area (km²)': '62',
#   'Area (sq mi)': '5,840',
#   'Density': '242'},
#  {'Country': 'Papua New Guinea',
#   'Population': '22',
#   'Area (km²)': '57',
#   'Area (sq mi)': '10,329,931',
#   'Density': '462,840'},
#  {'Country': 'Niger',
#   'Population': '21',
#   'Area (km²)': '54',
#   'Area (sq mi)': '27,202,843',
#   'Density': '1,267,000'},
#  {'Country': 'Bhutan',
#   'Population': '21',
#   'Area (km²)': '54',
#   'Area (sq mi)': '787,425',
#   'Density': '38,394'},
#  {'Country': 'Uruguay',
#   'Population': '20',
#   'Area (km²)': '52',
#   'Area (sq mi)': '3,423,109',
#   'Density': '173,626'},
#  {'Country': 'New Zealand',
#   'Population': '20',
#   'Area (km²)': '52',
#   'Area (sq mi)': '5,228,100',
#   'Density': '268,107'},
#  {'Country': 'Algeria',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '45,606,481',
#   'Density': '2,381,741'},
#  {'Country': 'Åland (Finland)',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '30,237',
#   'Density': '1,583'},
#  {'Country': 'Mali',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '23,293,699',
#   'Density': '1,240,192'},
#  {'Country': 'Belize',
#   'Population': '18',
#   'Area (km²)': '47',
#   'Area (sq mi)': '410,825',
#   'Density': '22,965'},
#  {'Country': 'Congo',
#   'Population': '18',
#   'Area (km²)': '47',
#   'Area (sq mi)': '6,106,869',
#   'Density': '342,000'},
#  {'Country': 'South Sudan',
#   'Population': '17',
#   'Area (km²)': '44',
#   'Area (sq mi)': '11,088,796',
#   'Density': '658,841'},
#  {'Country': 'Saudi Arabia',
#   'Population': '17',
#   'Area (km²)': '44',
#   'Area (sq mi)': '36,947,025',
#   'Density': '2,206,714'},
#  {'Country': 'Finland',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '5,545,475',
#   'Density': '336,884'},
#  {'Country': 'Argentina',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '45,773,884',
#   'Density': '2,796,427'},
#  {'Country': 'South Ossetia',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '57,095',
#   'Density': '3,632'},
#  {'Country': 'New Caledonia (France)',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '292,991',
#   'Density': '19,100'},
#  {'Country': 'Paraguay',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '6,109,644',
#   'Density': '406,752'},
#  {'Country': 'Oman',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '4,644,384',
#   'Density': '309,980'},
#  {'Country': 'Chad',
#   'Population': '14',
#   'Area (km²)': '36',
#   'Area (sq mi)': '18,278,568',
#   'Density': '1,284,000'},
#  {'Country': 'Norway',
#   'Population': '14',
#   'Area (km²)': '36',
#   'Area (sq mi)': '5,474,360',
#   'Density': '385,207'},
#  {'Country': 'Turkmenistan',
#   'Population': '13',
#   'Area (km²)': '34',
#   'Area (sq mi)': '6,516,100',
#   'Density': '488,100'},
#  {'Country': 'Christmas Island (Australia)',
#   'Population': '12',
#   'Area (km²)': '31',
#   'Area (sq mi)': '1,692',
#   'Density': '136'},
#  {'Country': 'Bolivia',
#   'Population': '11',
#   'Area (km²)': '28',
#   'Area (sq mi)': '12,388,571',
#   'Density': '1,098,581'},
#  {'Country': 'Central African Republic',
#   'Population': '9',
#   'Area (km²)': '23',
#   'Area (sq mi)': '5,742,316',
#   'Density': '622,984'},
#  {'Country': 'Gabon',
#   'Population': '9',
#   'Area (km²)': '23',
#   'Area (sq mi)': '2,436,567',
#   'Density': '267,668'},
#  {'Country': 'Russia',
#   'Population': '8',
#   'Area (km²)': '21',
#   'Area (sq mi)': '144,444,359',
#   'Density': '17,098,246'},
#  {'Country': 'Niue',
#   'Population': '7',
#   'Area (km²)': '18',
#   'Area (sq mi)': '1,935',
#   'Density': '260'},
#  {'Country': 'Kazakhstan',
#   'Population': '7',
#   'Area (km²)': '18',
#   'Area (sq mi)': '19,606,634',
#   'Density': '2,724,902'},
#  {'Country': 'Mauritania',
#   'Population': '5',
#   'Area (km²)': '13',
#   'Area (sq mi)': '4,862,989',
#   'Density': '1,030,700'},
#  {'Country': 'Botswana',
#   'Population': '5',
#   'Area (km²)': '13',
#   'Area (sq mi)': '2,675,353',
#   'Density': '582,000'},
#  {'Country': 'Libya',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '6,888,388',
#   'Density': '1,676,198'},
#  {'Country': 'Canada',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '41,012,563',
#   'Density': '9,984,670'},
#  {'Country': 'Suriname',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '623,237',
#   'Density': '163,820'},
#  {'Country': 'Guyana',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '813,834',
#   'Density': '214,969'},
#  {'Country': 'French Guiana (France)',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '312,155',
#   'Density': '83,534'},
#  {'Country': 'Iceland',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '375,319',
#   'Density': '103,000'},
#  {'Country': 'Australia',
#   'Population': '3',
#   'Area (km²)': '7.8',
#   'Area (sq mi)': '26,439,112',
#   'Density': '7,692,024'},
#  {'Country': 'Namibia',
#   'Population': '3',
#   'Area (km²)': '7.8',
#   'Area (sq mi)': '2,604,172',
#   'Density': '825,229'},
#  {'Country': 'Western Sahara (disputed)',
#   'Population': '2',
#   'Area (km²)': '5.2',
#   'Area (sq mi)': '587,259',
#   'Density': '266,000'},
#  {'Country': 'Mongolia',
#   'Population': '2',
#   'Area (km²)': '5.2',
#   'Area (sq mi)': '3,447,157',
#   'Density': '1,564,116'},
#  {'Country': 'Pitcairn Islands (UK)',
#   'Population': '0.9',
#   'Area (km²)': '2.3',
#   'Area (sq mi)': '40',
#   'Density': '47'},
#  {'Country': 'Falkland Islands (UK)',
#   'Population': '0.3',
#   'Area (km²)': '0.78',
#   'Area (sq mi)': '3,791',
#   'Density': '12,173'},
#  {'Country': 'Greenland (Denmark)',
#   'Population': '0.03',
#   'Area (km²)': '0.078',
#   'Area (sq mi)': '56,643',
#   'Density': '2,166,086'}]

# %% [markdown]
# - Save the information obtained in a Python dictionary.

# %% [markdown]
# The point here is to use the countries and data lists to create a dictionary that will allow us to access a country’s information by its name. For that, we can just use the zip function to combine the two lists. The zip function takes each country from the countries list and pairs it with the corresponding data from the data list (which contains information like population, area, and density). The dictionary comprehension ```{country: info for country, info in zip(countries, data)}``` creates a dictionary where the country name is the key and the associated data dictionary ```(with population, area, and density)``` is the value.

# %%
C_info = {country: info for country, info in zip(countries, data)}
C_info
# Out:
# {'Macau': {'Country': 'Macau (China)',
#   'Population': '21,000',
#   'Area (km²)': '54,000',
#   'Area (sq mi)': '704,150',
#   'Density': '33'},
#  'Monaco': {'Country': 'Monaco',
#   'Population': '18,000',
#   'Area (km²)': '47,000',
#   'Area (sq mi)': '36,298',
#   'Density': '2.0'},
#  'Singapore': {'Country': 'Singapore',
#   'Population': '8,250',
#   'Area (km²)': '21,400',
#   'Area (sq mi)': '6,014,723',
#   'Density': '729'},
#  'Hong Kong': {'Country': 'Hong Kong (China)',
#   'Population': '6,725',
#   'Area (km²)': '17,420',
#   'Area (sq mi)': '7,491,609',
#   'Density': '1,114'},
#  'Gibraltar': {'Country': 'Gibraltar (UK)',
#   'Population': '4,800',
#   'Area (km²)': '12,000',
#   'Area (sq mi)': '32,688',
#   'Density': '6.8'},
#  'Bahrain': {'Country': 'Bahrain',
#   'Population': '1,910',
#   'Area (km²)': '4,900',
#   'Area (sq mi)': '1,485,510',
#   'Density': '778'},
#  'Maldives': {'Country': 'Maldives',
#   'Population': '1,750',
#   'Area (km²)': '4,500',
#   'Area (sq mi)': '523,787',
#   'Density': '300'},
#  'Malta': {'Country': 'Malta',
#   'Population': '1,700',
#   'Area (km²)': '4,400',
#   'Area (sq mi)': '535,065',
#   'Density': '315'},
#  'Vatican City': {'Country': 'Vatican City',
#   'Population': '1,600',
#   'Area (km²)': '4,100',
#   'Area (sq mi)': '764',
#   'Density': '0.49'},
#  'Sint Maarten': {'Country': 'Sint Maarten (NL)',
#   'Population': '1,300',
#   'Area (km²)': '3,400',
#   'Area (sq mi)': '44,222',
#   'Density': '34'},
#  'Bermuda': {'Country': 'Bermuda (UK)',
#   'Population': '1,200',
#   'Area (km²)': '3,100',
#   'Area (sq mi)': '64,069',
#   'Density': '54'},
#  'Bangladesh': {'Country': 'Bangladesh',
#   'Population': '1,165',
#   'Area (km²)': '3,020',
#   'Area (sq mi)': '172,954,319',
#   'Density': '148,460'},
#  'Guernsey': {'Country': 'Guernsey (UK)',
#   'Population': '990',
#   'Area (km²)': '2,600',
#   'Area (sq mi)': '63,544',
#   'Density': '64'},
#  'Jersey': {'Country': 'Jersey (UK)',
#   'Population': '964',
#   'Area (km²)': '2,500',
#   'Area (sq mi)': '111,803',
#   'Density': '116'},
#  'Mayotte': {'Country': 'Mayotte (France)',
#   'Population': '913',
#   'Area (km²)': '2,360',
#   'Area (sq mi)': '335,995',
#   'Density': '368'},
#  'Palestine': {'Country': 'Palestine(Gaza Strip, West Bank)',
#   'Population': '892',
#   'Area (km²)': '2,310',
#   'Area (sq mi)': '5,371,230',
#   'Density': '6,020'},
#  'Taiwan': {'Country': 'Taiwan',
#   'Population': '676',
#   'Area (km²)': '1,750',
#   'Area (sq mi)': '23,923,277',
#   'Density': '35,410'},
#  'Mauritius': {'Country': 'Mauritius',
#   'Population': '657',
#   'Area (km²)': '1,700',
#   'Area (sq mi)': '1,300,557',
#   'Density': '1,979'},
#  'Barbados': {'Country': 'Barbados',
#   'Population': '654',
#   'Area (km²)': '1,690',
#   'Area (sq mi)': '281,996',
#   'Density': '431'},
#  'Nauru': {'Country': 'Nauru',
#   'Population': '610',
#   'Area (km²)': '1,600',
#   'Area (sq mi)': '12,780',
#   'Density': '21'},
#  'Saint Martin': {'Country': 'Saint Martin (France)',
#   'Population': '610',
#   'Area (km²)': '1,600',
#   'Area (sq mi)': '32,077',
#   'Density': '53'},
#  'Aruba': {'Country': 'Aruba (NL)',
#   'Population': '590',
#   'Area (km²)': '1,500',
#   'Area (sq mi)': '106,277',
#   'Density': '180'},
#  'San Marino': {'Country': 'San Marino',
#   'Population': '550',
#   'Area (km²)': '1,400',
#   'Area (sq mi)': '33,642',
#   'Density': '61'},
#  'Rwanda': {'Country': 'Rwanda',
#   'Population': '535',
#   'Area (km²)': '1,390',
#   'Area (sq mi)': '14,094,683',
#   'Density': '26,338'},
#  'South Korea': {'Country': 'South Korea',
#   'Population': '516',
#   'Area (km²)': '1,340',
#   'Area (sq mi)': '51,784,059',
#   'Density': '100,413'},
#  'Lebanon': {'Country': 'Lebanon',
#   'Population': '512',
#   'Area (km²)': '1,330',
#   'Area (sq mi)': '5,353,930',
#   'Density': '10,452'},
#  'Saint Barthélemy': {'Country': 'Saint Barthélemy (France)',
#   'Population': '500',
#   'Area (km²)': '1,300',
#   'Area (sq mi)': '10,994',
#   'Density': '22'},
#  'Burundi': {'Country': 'Burundi',
#   'Population': '476',
#   'Area (km²)': '1,230',
#   'Area (sq mi)': '13,238,559',
#   'Density': '27,834'},
#  'Tuvalu': {'Country': 'Tuvalu',
#   'Population': '440',
#   'Area (km²)': '1,100',
#   'Area (sq mi)': '11,396',
#   'Density': '26'},
#  'India': {'Country': 'India',
#   'Population': '435',
#   'Area (km²)': '1,130',
#   'Area (sq mi)': '1,428,627,663',
#   'Density': '3,287,263'},
#  'Curaçao': {'Country': 'Curaçao (NL)',
#   'Population': '433',
#   'Area (km²)': '1,120',
#   'Area (sq mi)': '192,077',
#   'Density': '444'},
#  'Netherlands': {'Country': 'Netherlands',
#   'Population': '436',
#   'Area (km²)': '1,130',
#   'Area (sq mi)': '18,092,525',
#   'Density': '41,543'},
#  'Haiti': {'Country': 'Haiti',
#   'Population': '423',
#   'Area (km²)': '1,100',
#   'Area (sq mi)': '11,724,764',
#   'Density': '27,750'},
#  'Israel': {'Country': 'Israel',
#   'Population': '416',
#   'Area (km²)': '1,080',
#   'Area (sq mi)': '9,174,520',
#   'Density': '22,072'},
#  'Réunion': {'Country': 'Réunion (France)',
#   'Population': '391',
#   'Area (km²)': '1,010',
#   'Area (sq mi)': '981,796',
#   'Density': '2,510'},
#  'Philippines': {'Country': 'Philippines',
#   'Population': '391',
#   'Area (km²)': '1,010',
#   'Area (sq mi)': '117,337,368',
#   'Density': '300,000'},
#  'Belgium': {'Country': 'Belgium',
#   'Population': '383',
#   'Area (km²)': '990',
#   'Area (sq mi)': '11,686,140',
#   'Density': '30,528'},
#  'Comoros': {'Country': 'Comoros',
#   'Population': '381',
#   'Area (km²)': '990',
#   'Area (sq mi)': '852,075',
#   'Density': '2,235'},
#  'Grenada': {'Country': 'Grenada',
#   'Population': '366',
#   'Area (km²)': '950',
#   'Area (sq mi)': '126,184',
#   'Density': '345'},
#  'Puerto Rico': {'Country': 'Puerto Rico (US)',
#   'Population': '361',
#   'Area (km²)': '930',
#   'Area (sq mi)': '3,205,691',
#   'Density': '8,868'},
#  'Martinique': {'Country': 'Martinique (France)',
#   'Population': '337',
#   'Area (km²)': '870',
#   'Area (sq mi)': '366,981',
#   'Density': '1,090'},
#  'Sri Lanka': {'Country': 'Sri Lanka',
#   'Population': '334',
#   'Area (km²)': '870',
#   'Area (sq mi)': '21,893,579',
#   'Density': '65,610'},
#  'Japan': {'Country': 'Japan',
#   'Population': '326',
#   'Area (km²)': '840',
#   'Area (sq mi)': '123,294,513',
#   'Density': '377,930'},
#  'Guam': {'Country': 'Guam (US)',
#   'Population': '320',
#   'Area (km²)': '830',
#   'Area (sq mi)': '172,952',
#   'Density': '541'},
#  'El Salvador': {'Country': 'El Salvador',
#   'Population': '303',
#   'Area (km²)': '780',
#   'Area (sq mi)': '6,364,943',
#   'Density': '21,041'},
#  'Pakistan': {'Country': 'Pakistan',
#   'Population': '302',
#   'Area (km²)': '780',
#   'Area (sq mi)': '240,485,658',
#   'Density': '796,095'},
#  'Trinidad and Tobago': {'Country': 'Trinidad and Tobago',
#   'Population': '299',
#   'Area (km²)': '770',
#   'Area (sq mi)': '1,534,937',
#   'Density': '5,127'},
#  'Vietnam': {'Country': 'Vietnam',
#   'Population': '298',
#   'Area (km²)': '770',
#   'Area (sq mi)': '98,858,950',
#   'Density': '331,340'},
#  'Saint Lucia': {'Country': 'Saint Lucia',
#   'Population': '293',
#   'Area (km²)': '760',
#   'Area (sq mi)': '180,251',
#   'Density': '616'},
#  'U.S. Virgin Islands': {'Country': 'U.S. Virgin Islands (US)',
#   'Population': '285',
#   'Area (km²)': '740',
#   'Area (sq mi)': '98,750',
#   'Density': '347'},
#  'United Kingdom': {'Country': 'United Kingdom',
#   'Population': '279',
#   'Area (km²)': '720',
#   'Area (sq mi)': '67,596,281',
#   'Density': '242,495'},
#  'Saint Vincent and the Grenadines': {'Country': 'Saint Vincent and the Grenadines',
#   'Population': '267',
#   'Area (km²)': '690',
#   'Area (sq mi)': '103,699',
#   'Density': '389'},
#  'Cayman Islands': {'Country': 'Cayman Islands (UK)',
#   'Population': '263',
#   'Area (km²)': '680',
#   'Area (sq mi)': '69,310',
#   'Density': '264'},
#  'Jamaica': {'Country': 'Jamaica',
#   'Population': '257',
#   'Area (km²)': '670',
#   'Area (sq mi)': '2,825,544',
#   'Density': '10,991'},
#  'Luxembourg': {'Country': 'Luxembourg',
#   'Population': '253',
#   'Area (km²)': '660',
#   'Area (sq mi)': '654,768',
#   'Density': '2,586'},
#  'Liechtenstein': {'Country': 'Liechtenstein',
#   'Population': '247',
#   'Area (km²)': '640',
#   'Area (sq mi)': '39,585',
#   'Density': '160'},
#  'Gambia': {'Country': 'Gambia',
#   'Population': '246',
#   'Area (km²)': '640',
#   'Area (sq mi)': '2,773,168',
#   'Density': '11,295'},
#  'Nigeria': {'Country': 'Nigeria',
#   'Population': '249',
#   'Area (km²)': '640',
#   'Area (sq mi)': '230,842,743',
#   'Density': '923,768'},
#  'Kuwait': {'Country': 'Kuwait',
#   'Population': '242',
#   'Area (km²)': '630',
#   'Area (sq mi)': '4,310,108',
#   'Density': '17,818'},
#  'Guadeloupe': {'Country': 'Guadeloupe (France)',
#   'Population': '242',
#   'Area (km²)': '630',
#   'Area (sq mi)': '395,839',
#   'Density': '1,639'},
#  'São Tomé and Príncipe': {'Country': 'São Tomé and Príncipe',
#   'Population': '241',
#   'Area (km²)': '620',
#   'Area (sq mi)': '231,856',
#   'Density': '964'},
#  'Seychelles': {'Country': 'Seychelles',
#   'Population': '236',
#   'Area (km²)': '610',
#   'Area (sq mi)': '107,660',
#   'Density': '457'},
#  'Qatar': {'Country': 'Qatar',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '2,716,391',
#   'Density': '11,637'},
#  'Germany': {'Country': 'Germany',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '83,294,633',
#   'Density': '357,581'},
#  'Dominican Republic': {'Country': 'Dominican Republic',
#   'Population': '233',
#   'Area (km²)': '600',
#   'Area (sq mi)': '11,332,973',
#   'Density': '48,671'},
#  'Marshall Islands': {'Country': 'Marshall Islands',
#   'Population': '232',
#   'Area (km²)': '600',
#   'Area (sq mi)': '41,996',
#   'Density': '181'},
#  'Malawi': {'Country': 'Malawi',
#   'Population': '221',
#   'Area (km²)': '570',
#   'Area (sq mi)': '20,931,751',
#   'Density': '94,552'},
#  'American Samoa': {'Country': 'American Samoa (US)',
#   'Population': '221',
#   'Area (km²)': '570',
#   'Area (sq mi)': '43,915',
#   'Density': '199'},
#  'North Korea': {'Country': 'North Korea',
#   'Population': '217',
#   'Area (km²)': '560',
#   'Area (sq mi)': '26,160,822',
#   'Density': '120,538'},
#  'Antigua and Barbuda': {'Country': 'Antigua and Barbuda',
#   'Population': '213',
#   'Area (km²)': '550',
#   'Area (sq mi)': '94,298',
#   'Density': '442'},
#  'Switzerland': {'Country': 'Switzerland',
#   'Population': '213',
#   'Area (km²)': '550',
#   'Area (sq mi)': '8,796,669',
#   'Density': '41,291'},
#  'Nepal': {'Country': 'Nepal',
#   'Population': '210',
#   'Area (km²)': '540',
#   'Area (sq mi)': '30,896,590',
#   'Density': '147,181'},
#  'British Virgin Islands': {'Country': 'British Virgin Islands (UK)',
#   'Population': '209',
#   'Area (km²)': '540',
#   'Area (sq mi)': '31,538',
#   'Density': '151'},
#  'Uganda': {'Country': 'Uganda',
#   'Population': '201',
#   'Area (km²)': '520',
#   'Area (sq mi)': '48,582,334',
#   'Density': '241,550'},
#  'Italy': {'Country': 'Italy',
#   'Population': '195',
#   'Area (km²)': '510',
#   'Area (sq mi)': '58,870,763',
#   'Density': '302,068'},
#  'Kiribati': {'Country': 'Kiribati',
#   'Population': '184',
#   'Area (km²)': '480',
#   'Area (sq mi)': '133,515',
#   'Density': '726'},
#  'Saint Kitts and Nevis': {'Country': 'Saint Kitts and Nevis',
#   'Population': '183',
#   'Area (km²)': '470',
#   'Area (sq mi)': '47,755',
#   'Density': '261'},
#  'Anguilla': {'Country': 'Anguilla (UK)',
#   'Population': '175',
#   'Area (km²)': '450',
#   'Area (sq mi)': '15,900',
#   'Density': '91'},
#  'Andorra': {'Country': 'Andorra',
#   'Population': '171',
#   'Area (km²)': '440',
#   'Area (sq mi)': '80,088',
#   'Density': '468'},
#  'Guatemala': {'Country': 'Guatemala',
#   'Population': '166',
#   'Area (km²)': '430',
#   'Area (sq mi)': '18,092,026',
#   'Density': '108,889'},
#  'Micronesia': {'Country': 'Micronesia',
#   'Population': '164',
#   'Area (km²)': '420',
#   'Area (sq mi)': '115,224',
#   'Density': '702'},
#  'Togo': {'Country': 'Togo',
#   'Population': '159',
#   'Area (km²)': '410',
#   'Area (sq mi)': '9,053,799',
#   'Density': '56,785'},
#  'Tokelau': {'Country': 'Tokelau (New Zealand)',
#   'Population': '158',
#   'Area (km²)': '410',
#   'Area (sq mi)': '1,893',
#   'Density': '12'},
#  'Kosovo': {'Country': 'Kosovo',
#   'Population': '153',
#   'Area (km²)': '400',
#   'Area (sq mi)': '1,663,595',
#   'Density': '10,905'},
#  'China': {'Country': 'China',
#   'Population': '149',
#   'Area (km²)': '390',
#   'Area (sq mi)': '1,425,671,352',
#   'Density': '9,600,000'},
#  'Cape Verde': {'Country': 'Cape Verde',
#   'Population': '148',
#   'Area (km²)': '380',
#   'Area (sq mi)': '598,682',
#   'Density': '4,033'},
#  'Isle of Man': {'Country': 'Isle of Man',
#   'Population': '148',
#   'Area (km²)': '380',
#   'Area (sq mi)': '84,710',
#   'Density': '572'},
#  'Indonesia': {'Country': 'Indonesia',
#   'Population': '145',
#   'Area (km²)': '380',
#   'Area (sq mi)': '277,534,123',
#   'Density': '1,910,931'},
#  'Tonga': {'Country': 'Tonga',
#   'Population': '144',
#   'Area (km²)': '370',
#   'Area (sq mi)': '107,773',
#   'Density': '747'},
#  'Ghana': {'Country': 'Ghana',
#   'Population': '143',
#   'Area (km²)': '370',
#   'Area (sq mi)': '34,121,985',
#   'Density': '238,537'},
#  'Thailand': {'Country': 'Thailand',
#   'Population': '140',
#   'Area (km²)': '360',
#   'Area (sq mi)': '71,801,279',
#   'Density': '513,140'},
#  'Denmark': {'Country': 'Denmark',
#   'Population': '138',
#   'Area (km²)': '360',
#   'Area (sq mi)': '5,910,913',
#   'Density': '42,947'},
#  'Cyprus': {'Country': 'Cyprus',
#   'Population': '136',
#   'Area (km²)': '350',
#   'Area (sq mi)': '1,260,138',
#   'Density': '9,251'},
#  'United Arab Emirates': {'Country': 'United Arab Emirates',
#   'Population': '134',
#   'Area (km²)': '350',
#   'Area (sq mi)': '9,516,871',
#   'Density': '71,024'},
#  'Transnistria': {'Country': 'Transnistria',
#   'Population': '134',
#   'Area (km²)': '350',
#   'Area (sq mi)': '468,980',
#   'Density': '3,510'},
#  'Czech Republic': {'Country': 'Czech Republic',
#   'Population': '133',
#   'Area (km²)': '340',
#   'Area (sq mi)': '10,495,295',
#   'Density': '78,871'},
#  'Jordan': {'Country': 'Jordan',
#   'Population': '127',
#   'Area (km²)': '330',
#   'Area (sq mi)': '11,337,053',
#   'Density': '89,318'},
#  'Syria': {'Country': 'Syria',
#   'Population': '125',
#   'Area (km²)': '320',
#   'Area (sq mi)': '23,227,014',
#   'Density': '185,180'},
#  'Sierra Leone': {'Country': 'Sierra Leone',
#   'Population': '122',
#   'Area (km²)': '320',
#   'Area (sq mi)': '8,791,092',
#   'Density': '72,300'},
#  'Poland': {'Country': 'Poland',
#   'Population': '120',
#   'Area (km²)': '310',
#   'Area (sq mi)': '37,691,000',
#   'Density': '313,931'},
#  'Azerbaijan': {'Country': 'Azerbaijan',
#   'Population': '120',
#   'Area (km²)': '310',
#   'Area (sq mi)': '10,412,652',
#   'Density': '86,600'},
#  'Benin': {'Country': 'Benin',
#   'Population': '119',
#   'Area (km²)': '310',
#   'Area (sq mi)': '13,712,828',
#   'Density': '114,763'},
#  'Slovakia': {'Country': 'Slovakia',
#   'Population': '110',
#   'Area (km²)': '280',
#   'Area (sq mi)': '5,422,194',
#   'Density': '49,035'},
#  'France': {'Country': 'France (metropolitan & overseas)',
#   'Population': '101',
#   'Area (km²)': '260',
#   'Area (sq mi)': '68,000,000',
#   'Density': '672,000'},
#  'Ethiopia': {'Country': 'Ethiopia',
#   'Population': '115',
#   'Area (km²)': '300',
#   'Area (sq mi)': '126,527,060',
#   'Density': '1,104,300'},
#  'Northern Cyprus': {'Country': 'Northern Cyprus',
#   'Population': '114',
#   'Area (km²)': '300',
#   'Area (sq mi)': '382,836',
#   'Density': '3,355'},
#  'Egypt': {'Country': 'Egypt',
#   'Population': '112',
#   'Area (km²)': '290',
#   'Area (sq mi)': '112,716,599',
#   'Density': '1,002,000'},
#  'Portugal': {'Country': 'Portugal',
#   'Population': '111',
#   'Area (km²)': '290',
#   'Area (sq mi)': '10,247,605',
#   'Density': '92,225'},
#  'Turkey': {'Country': 'Turkey',
#   'Population': '110',
#   'Area (km²)': '280',
#   'Area (sq mi)': '85,816,199',
#   'Density': '783,562'},
#  'Hungary': {'Country': 'Hungary',
#   'Population': '109',
#   'Area (km²)': '280',
#   'Area (sq mi)': '10,156,239',
#   'Density': '93,025'},
#  'Northern Mariana Islands': {'Country': 'Northern Mariana Islands (US)',
#   'Population': '109',
#   'Area (km²)': '280',
#   'Area (sq mi)': '49,796',
#   'Density': '457'},
#  'Austria': {'Country': 'Austria',
#   'Population': '107',
#   'Area (km²)': '280',
#   'Area (sq mi)': '8,958,961',
#   'Density': '83,878'},
#  'Iraq': {'Country': 'Iraq',
#   'Population': '105',
#   'Area (km²)': '270',
#   'Area (sq mi)': '45,504,560',
#   'Density': '435,052'},
#  'Slovenia': {'Country': 'Slovenia',
#   'Population': '105',
#   'Area (km²)': '270',
#   'Area (sq mi)': '2,119,675',
#   'Density': '20,273'},
#  'Malaysia': {'Country': 'Malaysia',
#   'Population': '104',
#   'Area (km²)': '270',
#   'Area (sq mi)': '34,308,525',
#   'Density': '330,621'},
#  'Costa Rica': {'Country': 'Costa Rica',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '5,212,173',
#   'Density': '51,100'},
#  'Cuba': {'Country': 'Cuba',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '11,194,449',
#   'Density': '109,884'},
#  'Moldova': {'Country': 'Moldova',
#   'Population': '102',
#   'Area (km²)': '260',
#   'Area (sq mi)': '3,435,931',
#   'Density': '33,847'},
#  'Albania': {'Country': 'Albania',
#   'Population': '99',
#   'Area (km²)': '260',
#   'Area (sq mi)': '2,832,439',
#   'Density': '28,748'},
#  'Dominica': {'Country': 'Dominica',
#   'Population': '97',
#   'Area (km²)': '250',
#   'Area (sq mi)': '73,040',
#   'Density': '750'},
#  'Spain': {'Country': 'Spain',
#   'Population': '97',
#   'Area (km²)': '250',
#   'Area (sq mi)': '48,797,875',
#   'Density': '505,994'},
#  'Honduras': {'Country': 'Honduras',
#   'Population': '94',
#   'Area (km²)': '240',
#   'Area (sq mi)': '10,593,798',
#   'Density': '112,492'},
#  'Cambodia': {'Country': 'Cambodia',
#   'Population': '94',
#   'Area (km²)': '240',
#   'Area (sq mi)': '16,944,826',
#   'Density': '181,039'},
#  'Armenia': {'Country': 'Armenia',
#   'Population': '93',
#   'Area (km²)': '240',
#   'Area (sq mi)': '2,777,971',
#   'Density': '29,743'},
#  'Kenya': {'Country': 'Kenya',
#   'Population': '93',
#   'Area (km²)': '240',
#   'Area (sq mi)': '55,100,587',
#   'Density': '591,958'},
#  'East Timor': {'Country': 'East Timor',
#   'Population': '91',
#   'Area (km²)': '240',
#   'Area (sq mi)': '1,360,596',
#   'Density': '14,919'},
#  'Senegal': {'Country': 'Senegal',
#   'Population': '90',
#   'Area (km²)': '230',
#   'Area (sq mi)': '17,763,163',
#   'Density': '196,712'},
#  'Ivory Coast': {'Country': 'Ivory Coast',
#   'Population': '90',
#   'Area (km²)': '230',
#   'Area (sq mi)': '28,873,034',
#   'Density': '322,462'},
#  'Burkina Faso': {'Country': 'Burkina Faso',
#   'Population': '86',
#   'Area (km²)': '220',
#   'Area (sq mi)': '23,251,485',
#   'Density': '270,764'},
#  'French Polynesia': {'Country': 'French Polynesia (France)',
#   'Population': '84',
#   'Area (km²)': '220',
#   'Area (sq mi)': '308,872',
#   'Density': '3,687'},
#  'Romania': {'Country': 'Romania',
#   'Population': '83',
#   'Area (km²)': '210',
#   'Area (sq mi)': '19,892,812',
#   'Density': '238,398'},
#  'North Macedonia': {'Country': 'Caribbean Netherlands (Netherlands)',
#   'Population': '83',
#   'Area (km²)': '210',
#   'Area (sq mi)': '27,148',
#   'Density': '328'},
#  'Wallis and Futuna': {'Country': 'North Macedonia',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '2,085,679',
#   'Density': '25,713'},
#  'Serbia': {'Country': 'Wallis and Futuna (France)',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '11,502',
#   'Density': '142'},
#  'Myanmar': {'Country': 'Serbia',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '7,149,077',
#   'Density': '88,444'},
#  'Samoa': {'Country': 'Myanmar',
#   'Population': '81',
#   'Area (km²)': '210',
#   'Area (sq mi)': '54,577,997',
#   'Density': '676,577'},
#  'Brunei': {'Country': 'Samoa',
#   'Population': '79',
#   'Area (km²)': '200',
#   'Area (sq mi)': '225,681',
#   'Density': '2,842'},
#  'Greece': {'Country': 'Brunei',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '452,524',
#   'Density': '5,765'},
#  'Uzbekistan': {'Country': 'Greece',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '10,341,277',
#   'Density': '131,957'},
#  'Lesotho': {'Country': 'Uzbekistan',
#   'Population': '78',
#   'Area (km²)': '200',
#   'Area (sq mi)': '35,163,944',
#   'Density': '448,969'},
#  'Tunisia': {'Country': 'Lesotho',
#   'Population': '77',
#   'Area (km²)': '200',
#   'Area (sq mi)': '2,330,318',
#   'Density': '30,355'},
#  'Ireland': {'Country': 'Tunisia',
#   'Population': '76',
#   'Area (km²)': '200',
#   'Area (sq mi)': '12,458,223',
#   'Density': '163,610'},
#  'Cook Islands': {'Country': 'Ireland',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '5,056,935',
#   'Density': '69,825'},
#  'Tajikistan': {'Country': 'Cook Islands',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '17,044',
#   'Density': '236'},
#  'Tanzania': {'Country': 'Tajikistan',
#   'Population': '72',
#   'Area (km²)': '190',
#   'Area (sq mi)': '10,143,543',
#   'Density': '141,400'},
#  'Croatia': {'Country': 'Tanzania',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '67,438,106',
#   'Density': '947,303'},
#  'Ecuador': {'Country': 'Croatia',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '4,008,617',
#   'Density': '56,594'},
#  'Eswatini': {'Country': 'Ecuador',
#   'Population': '71',
#   'Area (km²)': '180',
#   'Area (sq mi)': '18,190,484',
#   'Density': '257,215'},
#  'Mexico': {'Country': 'Eswatini',
#   'Population': '70',
#   'Area (km²)': '180',
#   'Area (sq mi)': '1,210,822',
#   'Density': '17,363'},
#  'Yemen': {'Country': 'Mexico',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '128,455,567',
#   'Density': '1,964,375'},
#  'Afghanistan': {'Country': 'Yemen',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '34,449,825',
#   'Density': '527,968'},
#  'Bosnia and Herzegovina': {'Country': 'Afghanistan',
#   'Population': '65',
#   'Area (km²)': '170',
#   'Area (sq mi)': '42,239,854',
#   'Density': '652,864'},
#  'Akrotiri and Dhekelia': {'Country': 'Bosnia and Herzegovina',
#   'Population': '63',
#   'Area (km²)': '160',
#   'Area (sq mi)': '3,210,848',
#   'Density': '51,209'},
#  'Equatorial Guinea': {'Country': 'Akrotiri and Dhekelia (UK)',
#   'Population': '62',
#   'Area (km²)': '160',
#   'Area (sq mi)': '15,700',
#   'Density': '254'},
#  'Ukraine': {'Country': 'Equatorial Guinea',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '1,714,672',
#   'Density': '28,051'},
#  'Bulgaria': {'Country': 'Ukraine',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '36,744,634',
#   'Density': '603,500'},
#  'Cameroon': {'Country': 'Bulgaria',
#   'Population': '61',
#   'Area (km²)': '160',
#   'Area (sq mi)': '6,687,717',
#   'Density': '110,372'},
#  'Guinea-Bissau': {'Country': 'Cameroon',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '28,647,293',
#   'Density': '475,650'},
#  'Panama': {'Country': 'World (excluding Antarctica)',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '8,045,311,448',
#   'Density': '134,740,000'},
#  'Guinea': {'Country': 'Guinea-Bissau',
#   'Population': '60',
#   'Area (km²)': '160',
#   'Area (sq mi)': '2,150,842',
#   'Density': '36,125'},
#  'Norfolk Island': {'Country': 'Panama',
#   'Population': '59',
#   'Area (km²)': '150',
#   'Area (sq mi)': '4,468,087',
#   'Density': '75,320'},
#  'Iran': {'Country': 'Guinea',
#   'Population': '58',
#   'Area (km²)': '150',
#   'Area (sq mi)': '14,190,612',
#   'Density': '245,836'},
#  'Nicaragua': {'Country': 'Norfolk Island (Australia)',
#   'Population': '57',
#   'Area (km²)': '150',
#   'Area (sq mi)': '2,220',
#   'Density': '39'},
#  'Georgia': {'Country': 'Iran',
#   'Population': '55',
#   'Area (km²)': '140',
#   'Area (sq mi)': '89,172,767',
#   'Density': '1,630,848'},
#  'Morocco': {'Country': 'Nicaragua',
#   'Population': '54',
#   'Area (km²)': '140',
#   'Area (sq mi)': '7,046,311',
#   'Density': '130,373'},
#  'Madagascar': {'Country': 'World (all land)',
#   'Population': '54',
#   'Area (km²)': '140',
#   'Area (sq mi)': '8,045,311,448',
#   'Density': '148,940,000'},
#  'Fiji': {'Country': 'Georgia',
#   'Population': '53',
#   'Area (km²)': '140',
#   'Area (sq mi)': '3,728,282',
#   'Density': '69,700'},
#  'South Africa': {'Country': 'Morocco',
#   'Population': '53',
#   'Area (km²)': '140',
#   'Area (sq mi)': '37,984,655',
#   'Density': '710,850'},
#  'Djibouti': {'Country': 'Madagascar',
#   'Population': '52',
#   'Area (km²)': '130',
#   'Area (sq mi)': '30,325,732',
#   'Density': '587,041'},
#  'Liberia': {'Country': 'Fiji',
#   'Population': '51',
#   'Area (km²)': '130',
#   'Area (sq mi)': '936,376',
#   'Density': '18,272'},
#  'Turks and Caicos Islands': {'Country': 'South Africa',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '60,414,495',
#   'Density': '1,221,037'},
#  'Easter Island': {'Country': 'Djibouti',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '1,136,455',
#   'Density': '23,200'},
#  'Belarus': {'Country': 'Liberia',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '5,418,377',
#   'Density': '111,369'},
#  'Colombia': {'Country': 'Turks and Caicos Islands (UK)',
#   'Population': '49',
#   'Area (km²)': '130',
#   'Area (sq mi)': '46,062',
#   'Density': '948'},
#  'Montenegro': {'Country': 'Easter Island',
#   'Population': '47',
#   'Area (km²)': '120',
#   'Area (sq mi)': '7750',
#   'Density': '163.6'},
#  'DR Congo': {'Country': 'Belarus',
#   'Population': '46',
#   'Area (km²)': '120',
#   'Area (sq mi)': '9,498,238',
#   'Density': '207,600'},
#  'Saint Helena, Ascension and Tristan da Cunha': {'Country': 'Colombia',
#   'Population': '46',
#   'Area (km²)': '120',
#   'Area (sq mi)': '52,695,952',
#   'Density': '1,141,748'},
#  'Cocos (Keeling) Islands': {'Country': 'Montenegro',
#   'Population': '45',
#   'Area (km²)': '120',
#   'Area (sq mi)': '626,485',
#   'Density': '13,888'},
#  'Zimbabwe': {'Country': 'DR Congo',
#   'Population': '44',
#   'Area (km²)': '110',
#   'Area (sq mi)': '102,262,809',
#   'Density': '2,345,410'},
#  'Montserrat': {'Country': 'Saint Helena, Ascension and Tristan da Cunha (UK)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '5,314',
#   'Density': '123'},
#  'Mozambique': {'Country': 'Cocos (Keeling) Islands (Australia)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '602',
#   'Density': '14'},
#  'Lithuania': {'Country': 'Zimbabwe',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '16,665,409',
#   'Density': '390,757'},
#  'Palau': {'Country': 'Montserrat (UK)',
#   'Population': '43',
#   'Area (km²)': '110',
#   'Area (sq mi)': '4,387',
#   'Density': '103'},
#  'Faroe Islands': {'Country': 'Mozambique',
#   'Population': '42',
#   'Area (km²)': '110',
#   'Area (sq mi)': '33,897,354',
#   'Density': '799,380'},
#  'United States': {'Country': 'Lithuania',
#   'Population': '42',
#   'Area (km²)': '110',
#   'Area (sq mi)': '2,718,352',
#   'Density': '65,286'},
#  'Kyrgyzstan': {'Country': 'Palau',
#   'Population': '39',
#   'Area (km²)': '100',
#   'Area (sq mi)': '18,058',
#   'Density': '459'},
#  'Laos': {'Country': 'Faroe Islands (Denmark)',
#   'Population': '38',
#   'Area (km²)': '98',
#   'Area (sq mi)': '53,270',
#   'Density': '1,393'},
#  'Venezuela': {'Country': 'United States',
#   'Population': '35',
#   'Area (km²)': '91',
#   'Area (sq mi)': '339,996,564',
#   'Density': '9,833,517'},
#  'Eritrea': {'Country': 'Kyrgyzstan',
#   'Population': '34',
#   'Area (km²)': '88',
#   'Area (sq mi)': '6,735,348',
#   'Density': '199,949'},
#  'Bahamas': {'Country': 'Laos',
#   'Population': '32',
#   'Area (km²)': '83',
#   'Area (sq mi)': '7,633,779',
#   'Density': '236,800'},
#  'Angola': {'Country': 'Venezuela',
#   'Population': '31',
#   'Area (km²)': '80',
#   'Area (sq mi)': '28,838,499',
#   'Density': '929,690'},
#  'Somaliland': {'Country': 'Eritrea',
#   'Population': '31',
#   'Area (km²)': '80',
#   'Area (sq mi)': '3,748,902',
#   'Density': '121,144'},
#  'Estonia': {'Country': 'Bahamas',
#   'Population': '30',
#   'Area (km²)': '78',
#   'Area (sq mi)': '412,624',
#   'Density': '13,940'},
#  'Somalia': {'Country': 'Angola',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '36,684,203',
#   'Density': '1,246,700'},
#  'Latvia': {'Country': 'Somaliland',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '4,914,100',
#   'Density': '167,283'},
#  'Abkhazia': {'Country': 'Estonia',
#   'Population': '29',
#   'Area (km²)': '75',
#   'Area (sq mi)': '1,322,766',
#   'Density': '45,399'},
#  'Vanuatu': {'Country': 'Somalia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '18,143,379',
#   'Density': '637,657'},
#  'Zambia': {'Country': 'Latvia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '1,862,700',
#   'Density': '64,594'},
#  'Sudan': {'Country': 'Abkhazia',
#   'Population': '28',
#   'Area (km²)': '73',
#   'Area (sq mi)': '245,424',
#   'Density': '8,662'},
#  'Peru': {'Country': 'Vanuatu',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '334,506',
#   'Density': '12,189'},
#  'Chile': {'Country': 'Zambia',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '20,569,738',
#   'Density': '752,612'},
#  'Solomon Islands': {'Country': 'Sudan',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '48,109,006',
#   'Density': '1,765,048'},
#  'Brazil': {'Country': 'Peru',
#   'Population': '27',
#   'Area (km²)': '70',
#   'Area (sq mi)': '34,352,719',
#   'Density': '1,285,216'},
#  'Sweden': {'Country': 'Chile',
#   'Population': '26',
#   'Area (km²)': '67',
#   'Area (sq mi)': '19,629,590',
#   'Density': '756,102'},
#  'Saint Pierre and Miquelon': {'Country': 'Solomon Islands',
#   'Population': '26',
#   'Area (km²)': '67',
#   'Area (sq mi)': '740,425',
#   'Density': '28,896'},
#  'Papua New Guinea': {'Country': 'Brazil',
#   'Population': '25',
#   'Area (km²)': '65',
#   'Area (sq mi)': '216,422,446',
#   'Density': '8,510,346'},
#  'Niger': {'Country': 'Sweden',
#   'Population': '24',
#   'Area (km²)': '62',
#   'Area (sq mi)': '10,612,086',
#   'Density': '438,574'},
#  'Bhutan': {'Country': 'Saint Pierre and Miquelon (France)',
#   'Population': '24',
#   'Area (km²)': '62',
#   'Area (sq mi)': '5,840',
#   'Density': '242'},
#  'Uruguay': {'Country': 'Papua New Guinea',
#   'Population': '22',
#   'Area (km²)': '57',
#   'Area (sq mi)': '10,329,931',
#   'Density': '462,840'},
#  'New Zealand': {'Country': 'Niger',
#   'Population': '21',
#   'Area (km²)': '54',
#   'Area (sq mi)': '27,202,843',
#   'Density': '1,267,000'},
#  'Algeria': {'Country': 'Bhutan',
#   'Population': '21',
#   'Area (km²)': '54',
#   'Area (sq mi)': '787,425',
#   'Density': '38,394'},
#  'Åland': {'Country': 'Uruguay',
#   'Population': '20',
#   'Area (km²)': '52',
#   'Area (sq mi)': '3,423,109',
#   'Density': '173,626'},
#  'Mali': {'Country': 'New Zealand',
#   'Population': '20',
#   'Area (km²)': '52',
#   'Area (sq mi)': '5,228,100',
#   'Density': '268,107'},
#  'Belize': {'Country': 'Algeria',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '45,606,481',
#   'Density': '2,381,741'},
#  'Congo': {'Country': 'Åland (Finland)',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '30,237',
#   'Density': '1,583'},
#  'South Sudan': {'Country': 'Mali',
#   'Population': '19',
#   'Area (km²)': '49',
#   'Area (sq mi)': '23,293,699',
#   'Density': '1,240,192'},
#  'Saudi Arabia': {'Country': 'Belize',
#   'Population': '18',
#   'Area (km²)': '47',
#   'Area (sq mi)': '410,825',
#   'Density': '22,965'},
#  'Finland': {'Country': 'Congo',
#   'Population': '18',
#   'Area (km²)': '47',
#   'Area (sq mi)': '6,106,869',
#   'Density': '342,000'},
#  'Argentina': {'Country': 'South Sudan',
#   'Population': '17',
#   'Area (km²)': '44',
#   'Area (sq mi)': '11,088,796',
#   'Density': '658,841'},
#  'South Ossetia': {'Country': 'Saudi Arabia',
#   'Population': '17',
#   'Area (km²)': '44',
#   'Area (sq mi)': '36,947,025',
#   'Density': '2,206,714'},
#  'New Caledonia': {'Country': 'Finland',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '5,545,475',
#   'Density': '336,884'},
#  'Paraguay': {'Country': 'Argentina',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '45,773,884',
#   'Density': '2,796,427'},
#  'Oman': {'Country': 'South Ossetia',
#   'Population': '16',
#   'Area (km²)': '41',
#   'Area (sq mi)': '57,095',
#   'Density': '3,632'},
#  'Chad': {'Country': 'New Caledonia (France)',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '292,991',
#   'Density': '19,100'},
#  'Norway': {'Country': 'Paraguay',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '6,109,644',
#   'Density': '406,752'},
#  'Turkmenistan': {'Country': 'Oman',
#   'Population': '15',
#   'Area (km²)': '39',
#   'Area (sq mi)': '4,644,384',
#   'Density': '309,980'},
#  'Christmas Island': {'Country': 'Chad',
#   'Population': '14',
#   'Area (km²)': '36',
#   'Area (sq mi)': '18,278,568',
#   'Density': '1,284,000'},
#  'Bolivia': {'Country': 'Norway',
#   'Population': '14',
#   'Area (km²)': '36',
#   'Area (sq mi)': '5,474,360',
#   'Density': '385,207'},
#  'Central African Republic': {'Country': 'Turkmenistan',
#   'Population': '13',
#   'Area (km²)': '34',
#   'Area (sq mi)': '6,516,100',
#   'Density': '488,100'},
#  'Gabon': {'Country': 'Christmas Island (Australia)',
#   'Population': '12',
#   'Area (km²)': '31',
#   'Area (sq mi)': '1,692',
#   'Density': '136'},
#  'Russia': {'Country': 'Bolivia',
#   'Population': '11',
#   'Area (km²)': '28',
#   'Area (sq mi)': '12,388,571',
#   'Density': '1,098,581'},
#  'Niue': {'Country': 'Central African Republic',
#   'Population': '9',
#   'Area (km²)': '23',
#   'Area (sq mi)': '5,742,316',
#   'Density': '622,984'},
#  'Kazakhstan': {'Country': 'Gabon',
#   'Population': '9',
#   'Area (km²)': '23',
#   'Area (sq mi)': '2,436,567',
#   'Density': '267,668'},
#  'Mauritania': {'Country': 'Russia',
#   'Population': '8',
#   'Area (km²)': '21',
#   'Area (sq mi)': '144,444,359',
#   'Density': '17,098,246'},
#  'Botswana': {'Country': 'Niue',
#   'Population': '7',
#   'Area (km²)': '18',
#   'Area (sq mi)': '1,935',
#   'Density': '260'},
#  'Libya': {'Country': 'Kazakhstan',
#   'Population': '7',
#   'Area (km²)': '18',
#   'Area (sq mi)': '19,606,634',
#   'Density': '2,724,902'},
#  'Canada': {'Country': 'Mauritania',
#   'Population': '5',
#   'Area (km²)': '13',
#   'Area (sq mi)': '4,862,989',
#   'Density': '1,030,700'},
#  'Suriname': {'Country': 'Botswana',
#   'Population': '5',
#   'Area (km²)': '13',
#   'Area (sq mi)': '2,675,353',
#   'Density': '582,000'},
#  'Guyana': {'Country': 'Libya',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '6,888,388',
#   'Density': '1,676,198'},
#  'French Guiana': {'Country': 'Canada',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '41,012,563',
#   'Density': '9,984,670'},
#  'Iceland': {'Country': 'Suriname',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '623,237',
#   'Density': '163,820'},
#  'Australia': {'Country': 'Guyana',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '813,834',
#   'Density': '214,969'},
#  'Namibia': {'Country': 'French Guiana (France)',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '312,155',
#   'Density': '83,534'},
#  'Western Sahara': {'Country': 'Iceland',
#   'Population': '4',
#   'Area (km²)': '10',
#   'Area (sq mi)': '375,319',
#   'Density': '103,000'},
#  'Mongolia': {'Country': 'Australia',
#   'Population': '3',
#   'Area (km²)': '7.8',
#   'Area (sq mi)': '26,439,112',
#   'Density': '7,692,024'},
#  'Pitcairn Islands': {'Country': 'Namibia',
#   'Population': '3',
#   'Area (km²)': '7.8',
#   'Area (sq mi)': '2,604,172',
#   'Density': '825,229'},
#  'Falkland Islands': {'Country': 'Western Sahara (disputed)',
#   'Population': '2',
#   'Area (km²)': '5.2',
#   'Area (sq mi)': '587,259',
#   'Density': '266,000'},
#  'Greenland': {'Country': 'Mongolia',
#   'Population': '2',
#   'Area (km²)': '5.2',
#   'Area (sq mi)': '3,447,157',
#   'Density': '1,564,116'}}

# %% [markdown]
# - Using the previously saved Python dictionary, ask the user for a country, display the
# corresponding information.

# %% [markdown]
# Before writing this part of the code, we need to take care of a couple of important things:
#
# 1. Handling invalid inputs: Although our database is designed to contain information about all countries, there is always a chance that a user might enter a misspelled or non-existent country name. This could lead to an error if not handled properly. So, we need to check if the entered country exists in the database and provide an error message if it doesn't.
#
# 2. Input format: Since country names in the database start with a capital letter, user inputs that are entirely lowercase or uppercase might not match the names correctly. To handle this, we can use the .title() method to automatically convert the user's input to title case (where the first letter of each word is capitalized), ensuring the country name matches the database format regardless of how the user types it.

# %%
country_info = input("Enter a Country name : ").title()
if country_info in C_info:
        print(f"{country_info}'s general informations are:\n"
              f"1. Population : {C_info[country_info]['Population']}\n"
              f"2. Area (km²) : {C_info[country_info]['Area (km²)']}\n"
              f"3. Area (sq mi) : {C_info[country_info]['Area (sq mi)']}\n"
              f"4. Density : {C_info[country_info]['Density']}")
else:
    print(f"Sorry, '{country_info}' is not in the database. Please try again.")
# Out:
# Japan's general informations are:
# 1. Population : 326
# 2. Area (km²) : 840
# 3. Area (sq mi) : 123,294,513
# 4. Density : 377,930

# %% [markdown]
# # Exercice 6 * - API Web

# %% [markdown]
# - Write a Python program that will make available a Web API allowing elementary calculations on
# integers.
#
# The APIs are accessible by GET and in the form:
# - /add/{integer1}/{integer2}: add integer1 and integer2
# - /sub/{integer1}/{integer2}: perform the subtraction of integer1 and integer2
# - /mul/{integer1}/{integer2}: carry out the multiplication of integer1 and integer2
# - /div/{integer1}/{integer2}: perform the integer division of integer1 by integer2
# - /mod/{integer1}/{integer2}: perform the remainder of the integer division of integer1
# by integer2

# %% [markdown]
# I will use the Flask module to solve this exercise, as I have some experience working with it.
#
# First, we'll import the Flask class from the Flask module. This class allows us to create a web application, represented by an instance of the Flask class. This app object is responsible for handling incoming requests and routing them to the appropriate functions. To define these routes, we use the @app.route() decorator, which specifies the URL path that will trigger a particular function. One of the services we want to offer via this app, is a functionality that adds two numbers, we will define a route using ```@app.route('/add/<int:integer1>/<int:integer2>')```. This route will handle requests to the /add URL with two integer parameters, a and b, and the associated function will perform the addition operation.
#
# We'll have to create individual routes for each operation and then run the app.

# %%
from flask import Flask



app = Flask(__name__)


@app.route('/add/<int:integer1>/<int:integer2>', methods=['GET'])
def add(integer1, integer2):
    result = integer1 + integer2
    return {'result': result}


@app.route('/sub/<int:integer1>/<int:integer2>', methods=['GET'])
def sub(integer1, integer2):
    result = integer1 - integer2
    return {'result': result}

@app.route('/mul/<int:integer1>/<int:integer2>', methods=['GET'])
def mul(integer1, integer2):
    result = integer1 * integer2
    return {'result': result}


@app.route('/div/<int:integer1>/<int:integer2>', methods=['GET'])
def div(integer1, integer2):
    if integer2 == 0:
        return {'error': 'Division by zero is not allowed'}, 400
    result = integer1 // integer2
    return {'result': result}

@app.route('/mod/<int:integer1>/<int:integer2>', methods=['GET'])
def mod(integer1, integer2):
    if integer2 == 0:
        return {'error': 'Division by zero is not allowed'}, 400
    result = integer1 % integer2
    return {'result': result}

# %% [markdown]
# I happen to know from previous experience that running a flask app on a jupiter notebook using 'app.run()' starts a web server that listens for incoming requests and serves responses. However, one thing to understand is that this Flask app runs in a blocking manner. Once we start the Flask server, it takes over the execution and waits indefinitely for incoming HTTP requests, meaning that if we're running Flask inside a Jupyter Notebook cell, no other cells can be executed until we manually stop the Flask server (by interrupting it).
#
# One way to handle this issue is to use threading (we're used to it from the first TME and MP). By using a separate thread for the Flask app, we allow the server to run independently without blocking the main program. The main thread can still execute other tasks (or cells) while the Flask server handles web requests in the background, tha way we can try the web app by using a GET request using requests.

# %%
from threading import Thread

def run_flask():
    app.run(host='localhost', port=8080, debug=False, use_reloader=False)

# Lancer le thread Flask
flask_thread = Thread(target=run_flask)
flask_thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:8080
# Press CTRL+C to quit

# %% [markdown]
# http://localhost:8080/mul/6/7
#
# http://localhost:8080/div/42/8
#
# http://localhost:8080/mod/42/8

# %% [markdown]
# - Write a Python program that will test the web API made available through the requests
# library.

# %% [markdown]
# We'll just use the requests to access the API's services with a GET method like wwe did thtough the whole TME and we should be able to print the result.

# %%
response = s.get("http://localhost:8080/mod/42/8")
print(response.text)
# Out:
# 127.0.0.1 - - [17/Oct/2024 21:36:55] "GET /mod/42/8 HTTP/1.1" 200 -
# {"result":2}

# %% [markdown]
# Let's try a second approach, that i leanred while reading the PROGRES lecture (web servers):
# Instead of running our app in the background of our notebook (using threading) we will create a Python file that contains our Flask application. This is done using the ```%%writefile``` magic command in Jupyter, which saves the code to a file named run.py.
#
# After saving the Flask app to run.py, we start the server by running the file and instead of running it in the same Jupyter Notebook (which could block other cells), we use the ```!wt python run.py``` command, which opens a new terminal window to execute run.py.

# %%
# %%writefile run.py
from flask import Flask

app = Flask(__name__)


@app.route('/add/<int:integer1>/<int:integer2>', methods=['GET'])
def add(integer1, integer2):
    result = integer1 + integer2
    return {'result': result}


@app.route('/sub/<int:integer1>/<int:integer2>', methods=['GET'])
def sub(integer1, integer2):
    result = integer1 - integer2
    return {'result': result}

@app.route('/mul/<int:integer1>/<int:integer2>', methods=['GET'])
def mul(integer1, integer2):
    result = integer1 * integer2
    return {'result': result}


@app.route('/div/<int:integer1>/<int:integer2>', methods=['GET'])
def div(integer1, integer2):
    if integer2 == 0:
        return {'error': 'Division by zero is not allowed'}, 400
    result = integer1 // integer2
    return {'result': result}

@app.route('/mod/<int:integer1>/<int:integer2>', methods=['GET'])
def mod(integer1, integer2):
    if integer2 == 0:
        return {'error': 'Division by zero is not allowed'}, 400
    result = integer1 % integer2
    return {'result': result}


app.run(host='localhost', port=8080)
# Out:
# Overwriting run.py

# %%
# !wt python run.py

# %%
response = s.get("http://localhost:8080/mod/42/8")
print(response.text)
# Out:
# {"result":2}
